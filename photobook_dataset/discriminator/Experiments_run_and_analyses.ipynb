# %%
import numpy as np
import pickle
import json
import copy
import pandas as pd
from tqdm import tqdm
import random

from perturbations import *
from helpers import *
from pos_tag_distribution_helpers import *
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\linda\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Initialising vocab from file.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\linda\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\linda\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package tagsets to
# [nltk_data]     C:\Users\linda\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\linda\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!

# %% [markdown]
# # Read in data
#
# Vocab

# %%
from Vocab import Vocab
vocab = Vocab('data/vocab.csv', 3)
# Out:
# Initialising vocab from file.

# %% [markdown]
# Segment data

# %%
from SegmentDataset import SegmentDataset

segment_test_set = SegmentDataset(
    data_dir='data/',
    segment_file='segments.json',
    vectors_file='vectors.json',
    split='test'
)

print("Testing the SegmentDataset class item getter...")
print("Dataset contains {} segment samples".format(len(segment_test_set)))
sample_id = 2
sample = segment_test_set[sample_id]
print("Segment {}:".format(sample_id))
print("Image set: {}".format(sample["image_set"]))
print("Target image index(es): {}".format(sample["targets"]))
# print("Target image Features: {}".format([segment_test_set.image_features[sample["image_set"][int(target)]] for target in sample["targets"]]))
print("Encoded segment: {}".format(sample["segment"]))
print("Decoded segment dialogue: {}".format(vocab.decode(sample["segment"])))
print("Segment length: ", sample["length"])
print("\nDone.")
# Out:
# Testing the SegmentDataset class item getter...
# Dataset contains 6801 segment samples
# Segment 2:
# Image set: ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757']
# Target image index(es): [6, 2, 3]
# Encoded segment: [4, 21, 11, 757, 18, 6, 26, 49, 10, 5, 41]
# Decoded segment dialogue: ['-A-', 'one', 'with', 'roses', 'and', 'a', 'white', 'laptop', '?', '-B-', 'nope']
# Segment length:  11
#
# Done.

# %% [markdown]
# Chain data

# %%
from ChainDataset import ChainDataset

print("Testing the ChainDataset class initialization...")

chain_test_set = ChainDataset(
    data_dir='data/',
    segment_file='segments.json',
    chain_file='test_chains.json',
    vectors_file='vectors.json',
    split='test'
)

print("Dataset contains {} cains.".format(len(chain_test_set.chains)))

sample_id = 5
sample = chain_test_set.chains[sample_id]

print("Chain {}:".format(sample_id))
print("Source Game ID: {}".format(sample["game_id"]))
print("Target image index: {}".format(sample["target"]))
print("Chain length: {}".format(len(sample["segments"])))
print("Segment IDs: {}".format(sample["segments"]))
print("Segment lengths: ", sample["lengths"])
print("First segment encoding: {}".format(chain_test_set.segments[sample["segments"][0]]["segment"]))
print("First segment decoded dialogue: {}".format(vocab.decode(chain_test_set.segments[sample["segments"][0]]["segment"])))
print("Second segment decoded dialogue: {}".format(vocab.decode(chain_test_set.segments[sample["segments"][1]]["segment"])))
# print("third segment decoded dialogue: {}".format(vocab.decode(chain_test_set.segments[sample["segments"][2]]["segment"])))

print("Reference chain and segments' associated image sets:")
for segment in sample["segments"]:
    print(vocab.decode(chain_test_set.segments[segment]["segment"]))
    print(chain_test_set.segments[segment]["image_set"])
print("\nDone.")

print("Testing the ChainDataset class item getter...")
# Out:
# Testing the ChainDataset class initialization...
# Dataset contains 2811 cains.
# Chain 5:
# Source Game ID: 3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO
# Target image index: 522129
# Chain length: 4
# Segment IDs: [3, 10, 12, 15]
# Segment lengths:  [23, 23, 21, 19]
# First segment encoding: [5, 38, 191, 23, 127, 11, 6, 120, 23, 127, 15, 9, 314, 10, 4, 13, 5, 80, 14, 128, 68, 22, 10]
# First segment decoded dialogue: ['-B-', 'two', 'plates', 'of', 'food', 'with', 'a', 'bowl', 'of', 'food', 'in', 'the', 'middle', '?', '-A-', 'no', '-B-', 'okay', '.', 'how', 'about', 'you', '?']
# Second segment decoded dialogue: ['-A-', 'do', 'you', 'have', 'the', 'one', 'with', 'two', 'plates', 'and', 'the', 'salsa', 'in', 'the', 'middle', '?', '-B-', 'i', 'do', "n't", 'have', 'that', 'one']
# Reference chain and segments' associated image sets:
# ['-B-', 'two', 'plates', 'of', 'food', 'with', 'a', 'bowl', 'of', 'food', 'in', 'the', 'middle', '?', '-A-', 'no', '-B-', 'okay', '.', 'how', 'about', 'you', '?']
# ['468357', '522129', '93469', '380128', '14238', '259745', '341060', '483794', '96757', '82894']
# ['-A-', 'do', 'you', 'have', 'the', 'one', 'with', 'two', 'plates', 'and', 'the', 'salsa', 'in', 'the', 'middle', '?', '-B-', 'i', 'do', "n't", 'have', 'that', 'one']
# ['468357', '522129', '420523', '380128', '14238', '259745', '341060', '96757', '82894']
# ['-A-', 'do', 'you', 'have', 'two', 'plates', 'of', 'food', 'with', 'salsa', 'in', 'the', 'middle', '?', '-B-', 'i', 'do', "n't", 'have', 'that', 'one']
# ['468357', '522129', '93469', '420523', '380128', '259745', '524866', '483794']
# ['-B-', 'you', 'go', 'can', 'fo', 'first', '-A-', 'two', 'plates', 'with', 'sauce', 'in', 'the', 'middle', '?', '-B-', 'can', '<unk>', 'yes']
# ['468357', '522129', '93469', '420523', '14238', '524866', '96757', '82894']
#
# Done.
# Testing the ChainDataset class item getter...

# %% [markdown]
# Game ids

# %%
with open('data/test_ids.json') as json_file:
    game_ids = json.load(json_file)
game_ids
# Out:
# ['3Z7EFSHGNACKCBAG5WMPCIYUZO6XCI39JEC7537VZS8M5L5HL7OX19JDYVCD',
#  '3RWE2M8QWI8V6P1WRA6WJF5VNDKN0Z33JKGHPFYDSS9383GFTUHCC8QGLNMA',
#  '3A1PQ49WVIF33I03KVFJS0R96RAH1C3018Q3ZVOJOCM0R6CJK6H5MIXUERA7',
#  '3SB5N7Y3O42PWXKA46T1TVWYJIZ0G031EUONYN2W1THB2OVMUYJXVQ400OV0',
#  '39PAAFCODNY9U37WR3GXD71D47STV13DY46V3X3QGQB7HRKGGM6T10BG855J',
#  '3XUHV3NRVLW2R01MLIHVVQ4QGP05H13YDTZAI2WYE9R6C85OV0YBI5Z4941W',
#  '3CTOC39K38OD5AAVXBZD5NY1JJ97JO3VHP9MDGROI3CPJV52G36BYNROHCFJ',
#  '3KKG4CDWKJWRGBF391ATDH0O33G9493P529IW9KZJWFTD1IF929UOASN6LF6',
#  '3NL0RFNU0GLBX7YUDY1I3QE4AIDK413OSWBBLG1FVUH3GU5SH0WOGCJ4LDXW',
#  '31T4R4OBOTEQXW4PNJIRIJL6VO47CU3OE22WJIGJMWP8Q459CXCGO77E7UQT',
#  '3JMSRU9HQJS75KPZ18R2EL1C6WIEVC39DD6S19JQ9OE4U925G5ZRE8U7OEZC',
#  '3KRVW3HTZOJPPG08OBAGG6MEE4HMSO3OLQQLKKNTNYEPP5KJDJBXQI9JEJEH',
#  '35GMH2SV3FFCF0G20W5OJT748FDOEY3RKNTXVS3NW5LUP817OT9CB869G4AA',
#  '3A4TN5196LGNQLA10S439WA0AJHCH3304SM51WA42T6PWBXMK72QBK190BSI',
#  '3KKG4CDWKJWRGBF391ATDH0O3DB94O3ERET4BTVN7CUD46UTX9KYPK0Z39KG',
#  '3ZSANO2JCG5JJ68R2O63LG25G7LSFA3TXD01ZLD5FP03367C5K9DN2CEY4UF',
#  '3I7DHKZYGOYID4AGQSTVS5SD06S5F03IO1LGZLKAV5HT07NXXUAJPR9XJ68T',
#  '36TFCYNS458BTJLWRO0QN9VA9OGXH93Z9WI9EOZ0M59JMPS5L1XFN8DF2HK5',
#  '3DZQRBDBSMDO3USYIT51K7D8CPVS3V3WQ3B2KGE9ETC5XHK35N6POBAHW1BC',
#  '3ERET4BTVN7CUD46UTX9KYPKVNQ9KA31Q0U3WYDQD6ATUR7MT71N2FRR071R',
#  '3IHR8NYAM8ZC8YVAQQ6QZ7035CL4PT3OVR4I9USQHX8AWPQ3LFZCQDA874QK',
#  '36TFCYNS458BTJLWRO0QN9VAC81HXL3P59JYT76MI0XC9U3TWMB242ATUT2V',
#  '34Q075JO1YBSSIU7MN8YM8SSLRF1003SPJ0334221WKU6WKKPDI0IYRLTYJ1',
#  '37ZHEEHM6XK2KW86UQ7QPGHCOAD37B3WJEQKOXA90OTVSPEP5RBE45RY5A1H',
#  '3B3WTRP3DC0HDX0G5NR5K23QHDL29H3M0BCWMB8WUMD6DKHRU8ZFE59KJBWI',
#  '37UEWGM5HU6GSCE6G0RD64TFR2HR1U3NKQQ8O39Z320ZMZ0N6DCHH8NYODUA',
#  '34BBWHLWHB9W0ERQN1MPL2II0YXWIE3OLQQLKKNTNYEPP5KJDJBXQI69JJEZ',
#  '3TXD01ZLD5FP03367C5K9DN2FXZU4B3TYCR1GOTDH2KA41JR39CM4S318ZLX',
#  '3L0KT67Y8FEPJXPM7EYRA19LK4TYS13A9AA95ATXKU4HZA4VP04Z6H2FIP5W',
#  '3LBXNTKX0STIED3DTCCYASXMSRIX9R3WAKVUDHUXEMJQLP9A3RCP7C3JE7UY',
#  '3NC5L260MPK4LEGYV7PU1BS4M1SOFO3TPWUS5F8AZ5NB5QVRQ3AZKNSQ2CWG',
#  '34HJIJKLP6UPDIS6C2FP5ZPLQRL4VU3OUYGIZWR8WV9AD97PJON4AQNRWP06',
#  '3B1NLC6UG0USKEOULR8R8WX6VT7PG23NL0RFNU0GLBX7YUDY1I3QE4BET4KU',
#  '3KJYX6QCMA9FG0BRF92TB1E46ZLVJ63W92K5RLWVF791W6Q7YZARVZOYJ5VN',
#  '39N5ACM9HFLD541M7L2HGFBJQRG9PK3PXX5PX6LYWP6TAHGMYGHQHEF5JABF',
#  '3EF8EXOTT2TZUOVT8VI44D7OLDL1JY3OSWBBLG1FVUH3GU5SH0WOGCL83DXO',
#  '3B2X28YI3XDOJRYEQ9H41LFSK8P6BQ3X31TUMD7YK5PEJTBGUHKSKGORNL1U',
#  '3D4CH1LGEBR7SR8N42CUM6XRP1Y9GN3QIYRE09Y4FVDEMENTAWXKO5S1S1NA',
#  '39KFRKBFIOTAL5XT0XHIQWZKO46YOZ32UTUBMZ7HU9YHDFRHPCDDVRZONBV1',
#  '3L4PIM1GQUEDIIP9SPYMKR4OVYCRYV3VP0C6EFSHUK2I2BHY7DF1QLQ1MM64',
#  '3WETL7AQWU6NXSUN6XSTRW3FUGD53C3IXEICO793HOFDSVQV8P1FLDKA3T6Z',
#  '3N4BPTXIO9QAE5S9S4S0GUCY8O8KUG3R6P78PK7L9QC6H128HBD6Y3ITKTGV',
#  '32XVDSJFP0VWKHJAUWVAPO9AIYCM2T3LOZAJ85YEB7ETIE83XJ05P8P2Z2XW',
#  '3LBXNTKX0STIED3DTCCYASXMV869XS3NG53N1RLWHDRZIC2TW3GJG893IP8Y',
#  '33NF62TLXK010PHFG5OM9S3NR38KJ83P59JYT76MI0XC9U3TWMB24285D2T9',
#  '3OF2M9AATHMR04MJYRR8XMRD94FKZS32N49TQG3HG4F78NL3PGI2BLGHEVAN',
#  '3IUZPWIU1P5N69HEN471YIXVV2VWK13DEL4X4EL7JXFEBL1O4E99QD2JAYXR',
#  '3KYQYYSHYW57NU2241U4DBPJBF9DOI3TR2532VIQSU1AWQE1ULZ9Y5VZCJ6D',
#  '3H0W84IWBL0FCD8ISOMSDOC9I3AREO392CY0QWG2PKRC86DVG6QAZRIIY4IS',
#  '3JAOYWH7VJ2NEJMOFT9AZY2ZM41L9V37U1UTWH9WKY3CYRFL0SLEGN8Q9R83',
#  '3WQQ9FUS6BSBN5H2JOE2LZBJPE9B8W3TU5ZICBREZYRBJR26BSGO6IBEA8Q5',
#  '3I33IC7ZWG0VIGALXT55GXEAIGW2AQ3C2NJ6JBKBF22Z4A6XAA23YAHNON2O',
#  '32ZKVD547GLPM8BW77J6UI387593BC33F859I567B4GGIVMS88YC4IQARBHR',
#  '39K0FND3AIDLPKEE7BOPV6S8RYTAMY3SKEMFQBZ43CG8LWP1RVK2U9C5SK8T',
#  '3018Q3ZVOJOCM0R6CJK6H5MIV1PRAU3I3WADAZ9R2CJHN9PVCLFZ1RS055OU',
#  '3FE7TXL1LJLN5WH2MP2R6XTFNREQ243STRJBFXOXPVESDKSZ2QBYQWOYZKTY',
#  '3BEFOD78W7R6NVYXYAEYI368ZY14M535USIKEBNSEQK0NBTZMDSGFM0FL6NW',
#  '37TD41K0AI7CGUOHBMG2DAH2K90SC131UV0MXWNRA2NVC6R0ZGV255JUCI5R',
#  '3OF2M9AATHMR04MJYRR8XMRD9UCKZ53IFS6Q0HJJH3TXAH3WCOODFXUBNSIX',
#  '3WEV0KO0ONQMLMUVBIBDXGZK3SZSDO31UV0MXWNRA2NVC6R0ZGV255HD05I2',
#  '3RUIQRXJBCMIFLNX4QC047TUKJALLO35L9RVQFCPGJCFR1MJP332W6GTWUHM',
#  '3R6BYFZZP8ARFNUQWYCQKOJXU55XF636V4Q8R5ZLYDC0LVW7LBL67DU3RQM6',
#  '3MAOD8E57R833F77UMV3STS6YHINX23F1567XTNX3Y5G217YH6GK1TWPEQ99',
#  '3WEV0KO0ONQMLMUVBIBDXGZK5QLSD83B1NLC6UG0USKEOULR8R8WX6VYVPG0',
#  '3UWN2HHPUZ3V7YL80CPGTLBEJNINS23VAR3R6G1QZV6Z6BNTJORJBIX3GO8I',
#  '3DR23U6WE6CSSSLAWDRND3DR5XVETT3SNVL38CI5QESBB96D70MOQS18RCKS',
#  '3KWTYT087114DWKCC3WTNIXX2QPL5D3A1PQ49WVIF33I03KVFJS0R99TC1H5',
#  '3VD82FOHKRMXI2WO45ZTT571N36COZ3MYYFCXHJ456VL2BN7G35YMB44YG43',
#  '3CCZ6YKWR8H9CUJ3N6T3I9622W89543PJ71Z61R50AOCIKMJRRFJTLQG419F',
#  '3EJJQNKU9S3RWNZKIPUYYR9ME5FRHT3LQ8PUHQFMQE3OW1S20PKZ8VR9XIHH',
#  '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO',
#  '378XPAWRUDBZT1ONMWQX3DLQ5C7AIJ3X65QVEQI1LPCHTRRDJ11O36MJOLCC',
#  '3YMTUJH0DTEA0QOH77FA4H10VQG4TV333U7HK6IADTMJB5OO2Z5F8XA1IDJC',
#  '3HHRAGRYX93VK4PLSLP2RF6THARO923U4J9857OF97NRCJ9JMW7ZFOFKG7BZ',
#  '3WYP994K18PKWZRP01VO9WDT6RQY6131QTRG6Q2UBS659UFXUXFW4A1WGYP7',
#  '3RU7GD8VPPRVAJXLGR28XAG9JZUPS53WOKGM4L72EDOA18SP69Y450E2I0OF',
#  '3MHW492WW1B5H8HCI6FLRT6K7VUVMN3U088ZLJVLRLTJAAJBXJFYILB1TW0L',
#  '36DSNE9QZ6WKQG2UEXGFG9KWBXOOJG3PEIJLRY6URTQ9GLMNMQOC5XPXVXWI',
#  '3Q5ZZ9ZEVPD9YP0TIENPIDBRGR285Q33M4IA01QHZOIDZZNTCK1DXGZHYXRX',
#  '35USIKEBNSEQK0NBTZMDSGFMYWFN6332N49TQG3HG4F78NL3PGI2BLGI7VAI',
#  '3IAEQB9FMFIFS3B4VNLEU5258U3DW9336YQZE83WCOJE2XCFX8NVCMXBUM5M',
#  '3TGOYF991YKOH1XLMIW2MHLWEZ1UUQ3EG49X351VAVWU1FV59MQI6K5V0X6J',
#  '3QL2OFSM97GF0HWC3QZGEG7WWSQCN63Z4AIRP3C7B0P80IPZX5VMF3U9A1XQ',
#  '3NKQQ8O39Z320ZMZ0N6DCHH7K9EUDY3H0W84IWBL0FCD8ISOMSDOC8DMBER7',
#  '3DZQRBDBSMDO3USYIT51K7D8EBWS363OUYGIZWR8WV9AD97PJON4AQOF60P4',
#  '34Z02EIMITBT126GO6S8SEBM6UWT0M37TRT2X24RP07MDLASBTAPKWZW2JBT',
#  '34QN5IT0T0PA3IESL8HD1IF0Z5308H30LB5CDZND8PNEFFUYHQE2C4YEA0ZM',
#  '3L0KT67Y8FEPJXPM7EYRA19LLERSYE326O153BMJWLB3PDANR88ZV52ZDDER',
#  '3NVC2EB65RXLZG47HZXQ2T19VSTY3J3UXUOQ9OKFV24H7R35M0COVIX3DA7R',
#  '3WJEQKOXA90OTVSPEP5RBE45SBO1AI3G2UL9A02EC1HFVODS5OWJTWZEY67U',
#  '39PAAFCODNY9U37WR3GXD71D6QRTV43C6FJU71TRR5YAHQWJTRP2R97L0UY5',
#  '30MVJZJNHNBHJTYOC8XXJJP7GGDJ983LO69W1SU4B2TT9WTZFKRFOMOIDGLY',
#  '3Y54SXRO1MJ9HOIWMD6SHLZURWSTUE3BV8HQ2ZZXZJ0HTMKVH86AVM0LQA69',
#  '32SVAV9L3G7K3Y641TJAZ7J2VK5A353BGYGHDBBYI6DDFHKECQAFVCDIX22Z',
#  '3EICBYG645UJHR5ROS7OL9QFM0BCJB323Q6SJS8JEUTXUBRUU4H2V36LYHFL',
#  '3FTF2T8WLSG3PDYNJ7GC89JFLLHW9W3IQ1VMJRYUI6I0VKI2KKQKMOT2F9AZ',
#  '3TOK3KHVJUGR6L1SDORIDJFNLYC7O93R9WASFE20EGKIU5XG0BH9Z83QYFZN',
#  '3BWI6RSP7H75UUO3JAOM87L9GOK7E23OVHNO1VE7ZJMYG96A5LT9WNQ5XZDU',
#  '37TRT2X24RP07MDLASBTAPKX7PCJBZ3I02618YA14BPWPP5WX8CBYX59PPUM',
#  '3FTF2T8WLSG3PDYNJ7GC89JFK8C9WD384PI804XTZSM2T1Z6NII9F1BSP0SI',
#  '3K2755HG5T1DHHP95YBEQHG5IOBDF831IBVUNM9TXZBYPVWJB8W3MCIVFFV9',
#  '3YW4XOSQKRJ8846NKUMIBFGZZQFU1A3A7Y0R2P2PM7KPGMFO3BZMBPNPWXJ9',
#  '3OE22WJIGJMWP8Q459CXCGO771DQU5324G5B4FB4663499B3P7NIJ5MMG70K',
#  '32Z9ZLUT1MIOZA74QXDU4W4HY5DHOX3MX2NQ3YCASZDQ11QMZHYCSK50T5XB',
#  '32ZKVD547GLPM8BW77J6UI38ARI3BW33IZTU6J82Z0JSZC2ICPRN2CLA4SXL',
#  '3VHHR074H4FJ00YV0WBQL2BTRTVL7V3WMOAN2SRCVBZQ2CU7UL48VLI62NVR',
#  '3VW04L3ZLU48F9LBWSICQVJ40W4XXA3IO1LGZLKAV5HT07NXXUAJPRCJX86K',
#  '30BUDKLTXETQ7QAKVH9PAN7DT6H5ET36WLNQG7808SW6RTWR02D975323EB3',
#  '3MRNMEIQW64ZH9Z5R9ECLULPDNILDA3LO69W1SU4B2TT9WTZFKRFOMQFYLGK',
#  '3K9FOBBF2IH83LQIG3SFHZXJONBNLA3WZ36BJEV4EULP9QMMPXCV761BLBTE',
#  '3WQ3B2KGE9ETC5XHK35N6POB9UDB1S369J354OFE8KA86P6V9I2W6PXIMG6D',
#  '3XUHV3NRVLW2R01MLIHVVQ4QJOAH5O3NLZY2D53QNT6I3AWVKWLTSOW15LQB',
#  '3K772S5NP992NJUFWJAYZKA3SK7EHM308XBLVESJ2H5AWYIXK2CG6OCVPBRB',
#  '3NKQQ8O39Z320ZMZ0N6DCHH8OJODUH3HRMW88U17OPO7GWF9RW60GVH8K0MR',
#  '3Y5140Z9DYE6G5UPBF8UT8AMB44IPP3I0BTBYZAYJPIO5AYCF70V32TFPY03',
#  '3DZQRBDBSMDO3USYIT51K7D8EF93S23QAVNHZ3EN21J2WT7ZNAVTDJSVTLA2',
#  '3YWRV122CTXQJ4Q8JFVXQP37GYNU833QY5DC2MXSIZYJ0VRT130HKT320UFK',
#  '39O5D9O87UQ8WD32L7F1529QUMDC3T3AWETUDC93Q0U9WVYO6WK6C0MM4ZIN',
#  '3OXV7EAXLFOJGWU1BG2YJ2HGTBG36N3S0TNUHWKUG422FMXK58GPZJQJR8D8',
#  '34YB12FSQZMMZBRHTBGZRS3BP0BGMZ3BF51CHDTW83WTFLOCBJEV8Z1XNH0O',
#  '3EJJQNKU9S3RWNZKIPUYYR9MDSGRH339GHHAVOMGPGMNSCVD162BERY614J3',
#  '3I02618YA14BPWPP5WX8CBYX2T8PU638BQUHLA9XYARO8FHUT7W1CDF2BMOW',
#  '3BEFOD78W7R6NVYXYAEYI3680O64MR3OWEPKL08AA9O01GC9R5YUFIWG6N7U',
#  '36TFCYNS458BTJLWRO0QN9VACNXHXB30X31N5D64OONFRJR8KB7FREKD5ASL',
#  '3TESA3PJ328MRLN34EEU4XN8MONMMI3DL65MZB8EDB6BJZARWXOTDNJ8SEC3',
#  '3ZDAD0O1T2B1YSCRRIHF1SYYOT2TXW3YZ8UPK3VUKSV7GL0RB2SBZQ6PLCU4',
#  '3TYCR1GOTDH2KA41JR39CM4S2GMZL43K9FOBBF2IH83LQIG3SFHZXJS2FLNA',
#  '3ZWFC4W1UV57IR8ENZ6YV6X9SQ3RFQ3S4AW7T80CGMHDGCYYDJIQRJX864LQ',
#  '3IFS6Q0HJJH3TXAH3WCOODFXU6BIS13Z4XG4ZF49PI08K3OK6KAW2B6P98XS',
#  '3COPXFW7XCAXM0KDBIT66OPZZ0RPKL3VE8AYVF8NV10MTIOQ0Y4P242UFF8U',
#  '3TAYZSBPLM6ZICWFETRW1X8G6YG2SP3CFJTT4SXUOHAZQPFTEDTMJ18G07II',
#  '3Z7ISHFUH1T753KIP2U57HIMGKY8Z835DR22AR5EIWZBEXC3BOJFU0SY83XE',
#  '3LJ7UR74RIBC5DJXABTYVIV8553N4F3N1FSUEFL6Y3J1SKLHFVZDJER12D4O',
#  '3EO896NRAXT03872AE2EAJQJ9KJTJE358010RM5FRGBKGGWDHU2AMJH3AVXG',
#  '3OVR4I9USQHX8AWPQ3LFZCQD9PU4Q43LYA37P8IRLVI6J3SDB5B4KAKBJBKP',
#  '3LBXNTKX0STIED3DTCCYASXMU8J9X43MHW492WW1B5H8HCI6FLRT6LEXMVMS',
#  '3PB5A5BD0W43E8KUP5EA8A6LVUM7GO3SKRO2GZ72PU581BQGIG5S71ZP31KO',
#  '3VJ40NV2QJLE4JYZQRUJIF75BEQTOX3ZGVPD4G6UFQ3NC6S050YDE9VITTZZ',
#  '3L4D84MIL0QAYZG7AKLPW0NVZBFJHS3L6L49WXW1V8FODR6BXC11VMC5Z456',
#  '31QTRG6Q2UBS659UFXUXFW4AXLYYPZ3GDTJDAPVV976WLZAD4BZFMDZ1M8M1',
#  '3DH6GAKTYZNMK9B026SZ6U6OA3RYZB38BQUHLA9XYARO8FHUT7W1CDHPAMO7',
#  '39KFRKBFIOTAL5XT0XHIQWZKOO4OYR33F859I567B4GGIVMS88YC4IRT8HBH',
#  '3N4BPTXIO9QAE5S9S4S0GUCY97WKU73EA3QWIZ4JT48XNWSWHEYIBJYP3TIH',
#  '3137ONMDKH3ONNZ4CDSGEKY2EBZGED3VHHR074H4FJ00YV0WBQL2BTO5HL72',
#  '3GD6L00D3TVPVW1EBSVWK5Z5MGI1MJ3JZQSN0I3R8GT1Z07OCMW2J2R4OGFQ',
#  '3Z2R0DQ0JICY8TRXDY7RCG415KF2EM3J88R45B2HW360JKA18VWIX1W0HPX4',
#  '3Z4AIRP3C7B0P80IPZX5VMF2PV51XM3FDJT1UU756TTQ2UR3KS8IKH5205KO',
#  '32Q90QCQ1TJTP9VN24DVCCQVNCQKE03QFUFYSY9ZD0HL6GCNALNDMZ2RGF4O',
#  '3PMBY0YE281UBFSI2GGBWFCCR8OC9W3IAS3U3I0GE01QFD3751B8YG3HEB2W',
#  '3X4MXAO0BHM9TDU9DOGYZUJ9MX2RW43IRIK4HM3BI7TWQK49DZC5LAYRA6CA',
#  '37WLF8U1WQOPCU28WMUX0OYI5MS6K63AMYWKA6YCK82LNNUEMQ75FRPR2O68',
#  '3FDJT1UU756TTQ2UR3KS8IKIB73K5O3UOUJI6MTECGY5RGRN7P6OK06XBXU8',
#  '3JWH6J9I9TBWQC46PQ3L3W1EDTDNB4386PBUZZXGVCKVZX150NOSG2G3MJLJ',
#  '3CP1TO84PUZYCAY42XEO8MYNNPS52P3R9WASFE20EGKIU5XG0BH9Z7XS5FZQ',
#  '34Z02EIMITBT126GO6S8SEBNG9A0TD33JKGHPFYDSS9383GFTUHCC8UUOMN8',
#  '3EICBYG645UJHR5ROS7OL9QFOZ8JCF3N8OEVH1FSOYRRTRUA8KO51IC89OOA',
#  '3GS6S824SRVOEF2HKHZHQAEZN5PNW03P1L2B7AD2NQL6QUHISSWOXOF8ROLO',
#  '3EA3QWIZ4JT48XNWSWHEYIBJZD5ITL3MD9PLUKKJCS8A7MV4JOPE8H68MNZN',
#  '3OONKJ5DKDHE8X4IQ53YIL1J6AFBOL3ZPBJO59KQZXVDGF0OZET2SIX9DHDA',
#  '3AAPLD8UCDF4C2CCMEZTY6A4X6AHTL3X87C8JFV79GAVY0G4HXXF6JMA1SQC',
#  '3WYP994K18PKWZRP01VO9WDT6RMY6X3DIP6YHAPDQ9U8TMTFGSM7H4UA8E8L',
#  '3V26SBZTBECMPZL5YSUIK1FQHPNZZG3IXQG4FA2UWB1A0COGKGLV6UBJDB97',
#  '3RSDURM96BKO9EK46JEMLK56MDYYEH3MB8LZR5BGR7VF5FJQ0ZP7GFXVQLKW',
#  '31LVTDXBL88TIJIA9A9WQJ2TTYBRL93SPJ0334221WKU6WKKPDI0IYSWMJY2',
#  '32ZKVD547GLPM8BW77J6UI38AN8B3M3B2X28YI3XDOJRYEQ9H41LFSKEAB6S',
#  '3R08VXYT7DTZBUAU4AISUDS9QUFW7433CKWXB73KISZ7FPI6CY0DB2RV711E',
#  '3H7Z272LX858662VWI57LO2ENF3PLO3G2UL9A02EC1HFVODS5OWJTWXQ967R',
#  '3BF51CHDTW83WTFLOCBJEV8ZYK2H0A3YWRV122CTXQJ4Q8JFVXQP37BRRU8O',
#  '39L1G8WVWRPO9AT45AQHO6QZNGP31C36TFCYNS458BTJLWRO0QN9VAB0MHXP',
#  '3EWIJTFFVP5RCJOJYB3DTSBM9BTE0R3AAJC4I4FHQWPKG1G6RWW7R0WQ8JZ9',
#  '3QXNC7EIPJTAHNX2Q0NR1EABIKX9083U5JL4WY5L7HH7X1CHG7TKM66Z3X4U',
#  '39DD6S19JQ9OE4U925G5ZRE8RKTZEP3R9WASFE20EGKIU5XG0BH9Z83L8ZF7',
#  '3KWTYT087114DWKCC3WTNIXWU2WL5Y3WJEQKOXA90OTVSPEP5RBE44O9L1A5',
#  '374TNBHA8CTD6HA9FA9MF1UK4QEYQ439U1BHVTDMPPIU5D7TARUC9UFWK3TJ',
#  '3T111IHZ5FOYHHH1KD66LABYRCX9RB3NL0RFNU0GLBX7YUDY1I3QE4ASP4KH',
#  '3E13VNJ1NOT3ZDBNQDX4SCSO613I1E3M23Y66PO35N0DFG1V3ZRAPSNALS6E',
#  '3ZSY5X72NY91O4L7M2POI06NMBIRO63WEV0KO0ONQMLMUVBIBDXGZK4ZVDSK',
#  '32VNZTT0A82XKBBP3IAF420I47N4RN3FE7TXL1LJLN5WH2MP2R6XTFO6H2QE',
#  '386PBUZZXGVCKVZX150NOSG2LUPJL93NLZY2D53QNT6I3AWVKWLTSOZPHQL7',
#  '3I7DHKZYGOYID4AGQSTVS5SD3BVF5Q32Z9ZLUT1MIOZA74QXDU4W4H0LDHOV',
#  '3DI28L7YXBCRJ891UU7D7XUWDUF1EE3G2UL9A02EC1HFVODS5OWJTWZIR76W',
#  '3JV9LGBJWUCAZECT6RVCJWSGIE3OGP3NKQQ8O39Z320ZMZ0N6DCHH8N8BDUH',
#  '35LDD5557B2R1XN0J21EPKV3QKMKMY3K3R2QNK8C1QX99IO71BQLYHSCDU96',
#  '3IAEQB9FMFIFS3B4VNLEU5258OMWDZ3HMIGG0U4M470DADTGSMTA9K85NY8S',
#  '3QAPZX2QN5BZH3C35R8CRR2XANC20E3B3WTRP3DC0HDX0G5NR5K23QDR692X',
#  '3X31TUMD7YK5PEJTBGUHKSKGN2GL183LOZAJ85YEB7ETIE83XJ05P8MH3X2M',
#  '31QNSG6A5SROLTEC672MGXPN6P578V3A1PQ49WVIF33I03KVFJS0R96MVH1N',
#  '36TFCYNS458BTJLWRO0QN9VAENBXH73N4BPTXIO9QAE5S9S4S0GUCYCMYUKG',
#  '3PQ8K71NHYIKNJ5PA8YKMFX8XNGAA23LKC68YZ3B16W02TLWZU5ZE4ENNOWQ',
#  '30H4UDGLT3GSCOKGWU6ML1H3UYQPMM3P4RDNWND64AUURRG23AWCOA4Q0JI0',
#  '3UJ1CZ6IZINRH9F2WCTUZ4BSQ1W5S432ZKVD547GLPM8BW77J6UI388HJ3BB',
#  '3WYGZ5XF3XDUZS053ZX01TUAP0QSKV3ZAK8W07I5C81FL5OBIIXAXPWZ60UE',
#  '31QTRG6Q2UBS659UFXUXFW4AZ54YPB3D3VGR7TA1DC2FSL345WUX8CRMY3R3',
#  '3018Q3ZVOJOCM0R6CJK6H5MI1ZSARI3VAR3R6G1QZV6Z6BNTJORJBI0O8O8J',
#  '3TMSXRD2X7YL08VSFU1JT31WL5Q1WF3EWIJTFFVP5RCJOJYB3DTSBM99D0ET',
#  '3TESA3PJ328MRLN34EEU4XN8KG9MMM37Q970SNZF6STREJVPRIWEYBEUX1S6',
#  '3P529IW9KZJWFTD1IF929UOANADFLC3M23Y66PO35N0DFG1V3ZRAPSM5RS69',
#  '37UEWGM5HU6GSCE6G0RD64TFXDH1RW3O6CYIULEEZ195MQHIB3456T0PTUWR',
#  '3CFJTT4SXUOHAZQPFTEDTMJ18I9I763EJJQNKU9S3RWNZKIPUYYR9M9HQHRD',
#  '3E337GFOLA6SHTCH5CVZ47SBTBYGNH36NEMU28XGBIWXHH8GKHDVPZI9EWMW',
#  '32EYX73OY17W1954IO1XH6YC5NOURL3PS7W85Z800BXWUTO2B1LPCGGNB9TM',
#  '3Z2R0DQ0JICY8TRXDY7RCG415N32EG3L70J4KAZHKILQ81UIPMCG5EHZUDA5',
#  '3NG53N1RLWHDRZIC2TW3GJG87N98PA3S3AMIZX3V36E55ZEWLDIBV2JVSCD7',
#  '3C6FJU71TRR5YAHQWJTRP2R990NUYO3ATPCQ38J98LJ13SQEC0P1FF2XVYAG',
#  '3FE2ERCCZY6GCR5S9ALZD568K7FPOO3QL2OFSM97GF0HWC3QZGEG7WVEVCNI',
#  '32AT8R96GM782O5HXD127G37KZKSUV3L0KT67Y8FEPJXPM7EYRA19KGNVSYT',
#  '37Q970SNZF6STREJVPRIWEYBI5KS1A326O153BMJWLB3PDANR88ZV56BFDEL',
#  '382M9COHEID7S50ZWIHXIZZTQ7DUE53YOH7BII0A5ARKH9XU25CGEHOBJKV5',
#  '3VP0C6EFSHUK2I2BHY7DF1QMWEAM6Q3QILPRALQ6TDOE6ZMEJBCUBD7Z0N83',
#  '33OOO72IVIJDVU1W0MLSNFDOOWOCTU3KJYX6QCMA9FG0BRF92TB1E4B1EJVW',
#  '3JWH6J9I9TBWQC46PQ3L3W1EITUNBQ3U0SRXB7CE3J6JLVLNPB3B6I0FXNR3',
#  '3JPSL1DZ5TXR72ZEJC3P8LH8XEWAN83ERET4BTVN7CUD46UTX9KYPKX19K9Y',
#  '32KTQ2V7RED7K149F5APZBHOM66M973R2PKQ87NX60V2XCJZG2C4GR5WTMIQ',
#  '3DYGAII7PM6JX3I8OND32A1814YQPS3U8YCDAGXQEG9MEO72YDN900TWN0QW',
#  '320DUZ38G8KWY3LWQE37B0BUPMBJGT3LBXNTKX0STIED3DTCCYASXMW7W9XH',
#  '3V0Z7YWSIZYFA4DJ8OW1CKSN4PXV2J3MB8LZR5BGR7VF5FJQ0ZP7GFURIKLC',
#  '3HRMW88U17OPO7GWF9RW60GVM1DM0X3Z4XG4ZF49PI08K3OK6KAW2BC39X8F',
#  '3OXV7EAXLFOJGWU1BG2YJ2HGXQO36T3J2UYBXQQMANZ4V4STKFH4J9UE260Z',
#  '31UV0MXWNRA2NVC6R0ZGV255JUE5IG3H8DHMCCWA9OX3HN692B6U8AOF1DK7',
#  '3FPRZHYEPZ54VM92COA6VUXFCO6V3B3LJ7UR74RIBC5DJXABTYVIV84L04NO',
#  '3WOKGM4L72EDOA18SP69Y450DN1O0R358010RM5FRGBKGGWDHU2AMJJNJXVX',
#  '3HL8HNGX46Z1ERCSTI6C4LXFPY59FK3A4TN5196LGNQLA10S439WA0BYLCH2',
#  '3BWI6RSP7H75UUO3JAOM87L9GCRE7S3NPFYT4IZD2XTNQL7II829J9VLLXGN',
#  '3XC1O3LBOTK6YYV2DZERQY3BFRXLTJ31UV0MXWNRA2NVC6R0ZGV255IKH5IY',
#  '3MD9PLUKKJCS8A7MV4JOPE8H3ZRZNJ3RWE2M8QWI8V6P1WRA6WJF5VLS8N0F',
#  '33LKR6A5KFIT8RRYKPW86JUXJFLT143LS2AMNW5GO1C3679N0ODAWISJPOQ1',
#  '3T3IWE1XG7LHPVBF54MN7K25QFCTQ93CCZ6YKWR8H9CUJ3N6T3I9620CN95D',
#  '35GCEFQ6I6ML46ECDLZ9G0AB4EJ3ZO3UN61F00HXNFGUFPHNTP9U6W9TS5RO',
#  '3YWRV122CTXQJ4Q8JFVXQP37GXLU8Z3D8YOU6S9FI3FQ7KQ0YZ6B7GA3W6US',
#  '3JMSRU9HQJS75KPZ18R2EL1C1UWVEY3OWEPKL08AA9O01GC9R5YUFIT39N74',
#  '3YMU66OBIO607XQ62E0MZNVF9Q5GH83K5TEWLKGW9JLPRLXRHTZ0Z4WI8IVS',
#  '39K0FND3AIDLPKEE7BOPV6S8ULGMAA323Q6SJS8JEUTXUBRUU4H2V3AFUHF9',
#  '34T446B1C1CCFL452KXI34BJQ0IC023SUWZRL0MZBMQUAY00JU2TLDOFHE6Y',
#  '3TY7ZAOG5GIUYJGTUXEGRNORTHE0K43LYA37P8IRLVI6J3SDB5B4KAKLBBK1',
#  '34T446B1C1CCFL452KXI34BJQ0I0CQ39GXDJN2OUCQWJF8O552MB5QU59V86',
#  '3YDGXNSEO0SR26WT494FDL5DH9B48E3N2BF7Y2VRS0Z7MSDHYHCSFC6JMHM1',
#  '30LB5CDZND8PNEFFUYHQE2C3S2KZ0Z35LDD5557B2R1XN0J21EPKV3RW7KM8',
#  '3U088ZLJVLRLTJAAJBXJFYIMH4P0WZ34Z02EIMITBT126GO6S8SEBNDA6T01',
#  '3X4MXAO0BHM9TDU9DOGYZUJ9PDKRWL39N5ACM9HFLD541M7L2HGFBJQUBP91',
#  '38SKSKU7R2VGPKFRJNFNCR125UPLIF3Z3ZLGNNSJSCQEDLQPGWP7Y7WIFQ39',
#  '3Z4XG4ZF49PI08K3OK6KAW2B6428XF3TEM0PF1Q6VMKDAJ2GSTNAT17OCD0T',
#  '338JKRMM27XZX6D3GE8C31KC7ZEHAN3B3WTRP3DC0HDX0G5NR5K23QC0U922',
#  '3OF2M9AATHMR04MJYRR8XMRDD6JZKJ3IX2EGZR7CHNNTUA6PXJA4P1P01JRC',
#  '3SNLUL3WO5LLYBARD441VUPDZF3LUU34V1S5K3GTZ5VYJHSP38AFK2WZ496J',
#  '3P1L2B7AD2NQL6QUHISSWOXOGDPLOU3WI0P0II62QAK7UIWTB876UOIR7RDT',
#  '31LM9EDVOMQ28V2IDIG21KKRNU3JNW3YJ6NA41JCE2BGEVTXTU59PMN94JPS',
#  '373ERPL3YP6H1WQFIJBNCACALA0TRD3JV9LGBJWUCAZECT6RVCJWSGKT8OGQ',
#  '34HJIJKLP6UPDIS6C2FP5ZPLP4W4VU3LUY3GC630Y9RLDTSO4X2JKDUIJP7C',
#  '3VAR3R6G1QZV6Z6BNTJORJBIYCSO8D3IXQG4FA2UWB1A0COGKGLV6UBJR9BJ',
#  '35GCEFQ6I6ML46ECDLZ9G0AB1BS3ZO3TMSXRD2X7YL08VSFU1JT31WMPA1W4',
#  '3018Q3ZVOJOCM0R6CJK6H5MIZNDRAU3FTYUGLFSVJLFKWKZMY545PSS8MD55',
#  '3P59JYT76MI0XC9U3TWMB2429TVT2V3AQF3RZ559GEW8AUVB30KB6DYPQF6R',
#  '3907X2AHF1325KGNMCN26S35KNY2PH3F0BG9B9MQL30Z5UJB0GFADPZ8N7YW',
#  '3S96KQ6I9N2N0M7A0IG37LV66G8DT430IQTZXKAL40IJF0TGT5HHWTPNO0XI',
#  '3LUY3GC630Y9RLDTSO4X2JKDV367PO3NC5L260MPK4LEGYV7PU1BS4JMTFOJ',
#  '3X87C8JFV79GAVY0G4HXXF6JMYSSQF3N1FSUEFL6Y3J1SKLHFVZDJEP324DH',
#  '3WYP994K18PKWZRP01VO9WDT5HBY6132KTQ2V7RED7K149F5APZBHOM85M9A',
#  '35USIKEBNSEQK0NBTZMDSGFMYLG6N13B2X28YI3XDOJRYEQ9H41LFSHW26BC',
#  '30X31N5D64OONFRJR8KB7FREKNWASW3JMSRU9HQJS75KPZ18R2EL1C46OEV0',
#  '3EFVCAY5L47H5OFE7GRJJNUWY6T8J03NG53N1RLWHDRZIC2TW3GJG875Z8P0',
#  '33L7PJKHCHWBJRBJJA5NLTH5TYO8TM3QAPZX2QN5BZH3C35R8CRR2XANX20Z',
#  '36DSNE9QZ6WKQG2UEXGFG9KWBEBOJ131UV0MXWNRA2NVC6R0ZGV255H4E5IY',
#  '3S96KQ6I9N2N0M7A0IG37LV68BITDM34PGFRQONP9SVPBW5J7PX3XIHPXWJT',
#  '3FK0YFF9P0EO7VBLWYGCEPPY53ZVV03137ONMDKH3ONNZ4CDSGEKY2IT8GEQ',
#  '3T3IWE1XG7LHPVBF54MN7K25QMXTQ83VHP9MDGROI3CPJV52G36BYNVYPFCI',
#  '3GU1KF0O4JZWTXGJ55GD7L69CB1BPG3E1QT0TDFQ7LADV8PY6J7MFWIRII89',
#  '3Z7ISHFUH1T753KIP2U57HIMFSS8ZH358010RM5FRGBKGGWDHU2AMJIQXXVG',
#  '37M28K1J0RBVOC8T4EBXFE0RON9JAH3SEPORI8WOXLORDXM0EJ38OH7LLZAH',
#  '3JZQSN0I3R8GT1Z07OCMW2J2TB2GFK3EO896NRAXT03872AE2EAJQJCCSJT0',
#  '35BLDD71I7V5GFGVXV5FZV2UQ53ZVH3L0KT67Y8FEPJXPM7EYRA19LL76YSL',
#  '32AT8R96GM782O5HXD127G38QTKUST3EF8EXOTT2TZUOVT8VI44D7OJD9J12',
#  '3TUI152ZZCLGGBZ63L2D1EJAVXIQ1T3SITXWYCNW7126IARWQU1YSCECWXBG',
#  '3LYA37P8IRLVI6J3SDB5B4KAKBOBKU37Z929RLGA6T2BQSX8BS2KH67C0TSI',
#  '3TVRFO09GLDDFF4MI9FOF1OHTEWXL83KWTYT087114DWKCC3WTNIXX0FN5L7',
#  '39L1G8WVWRPO9AT45AQHO6QZODF31X3QBD8R3Z22HUNYJ9BQTBA7VDVOLO4Q',
#  '388U7OUMF8ZGLNTOKHNDSZA5O06R043LJ7UR74RIBC5DJXABTYVIV84FY4NA',
#  '36V4Q8R5ZLYDC0LVW7LBL67DVGJQMP33TIN5LC0587EITNY8Y0T64VUQR9YA',
#  '3QY7M81QH8K8GUGDFWZP62YE1UV7KK3CPLWGV3MPXD2JP9R6PPCQ6OQFON9H',
#  '3J4Q2Z4UTZ19HCF909RYU494R5JWQG3XUHV3NRVLW2R01MLIHVVQ4QGLL5HE',
#  '324G5B4FB4663499B3P7NIJ4I9A70I32SCWG5HII2QNLZO9EZ5W5KGV62P68',
#  '3SB5N7Y3O42PWXKA46T1TVWYL2MG093P529IW9KZJWFTD1IF929UOANLXLFO',
#  '32Z9ZLUT1MIOZA74QXDU4W4HXJLHOW3JAOYWH7VJ2NEJMOFT9AZY2ZJ1A9LJ',
#  '3LYA37P8IRLVI6J3SDB5B4KAL1BBKY33SA9F9TRYSKK9P4RIWY0NKQB5XWEF',
#  '3ND9UOO81L0YQFZW84J2DIAAKKAWLE3ZGVPD4G6UFQ3NC6S050YDE9VZ0ZTA',
#  '34HJIJKLP6UPDIS6C2FP5ZPLO59V4Z3W92K5RLWVF791W6Q7YZARVZO14V54',
#  '3U84XHCDIDB6M2XGDZ4SQ52HF0G4ZG33PPO7FECWDXR8RZ66HZTETXW07IDA',
#  '31LVTDXBL88TIJIA9A9WQJ2TPDYLRG39PAAFCODNY9U37WR3GXD71D4WXTVK',
#  '3NS0A6KXC56MYIQ0806TZUZK5VGZG53WJ1OXY92BE64VCADAE6QORD8RX8AY',
#  '3OJSZ2ATDTU5YBVA89VJ4DFW89V57632Q90QCQ1TJTP9VN24DVCCQVRMTKER',
#  '3WRFBPLXRBMRNH0TAXOFLD32RXHN3O3300DTYQT3FF0CTIF9XS8Y24NXUQE5',
#  '3QHK8ZVMING62C1LDDN6Q4XP9FWLBI3QAPZX2QN5BZH3C35R8CRR2XCB920P',
#  '3TPWUS5F8AZ5NB5QVRQ3AZKNST7WCB39O5D9O87UQ8WD32L7F1529QU0DC3L',
#  '3M0BCWMB8WUMD6DKHRU8ZFE58HUWB73E13VNJ1NOT3ZDBNQDX4SCSO7U5I13',
#  '3NOKK93PR26Q393D6I2SEHDQ1VLEEV3KAKFY4PGV0Z9GP2DHBNG57L2Z43I4',
#  '3XIQGXAUMD6E0UFKEFEEWW6GWNM7XO3L4D84MIL0QAYZG7AKLPW0NVZS3JHE',
#  '3DI28L7YXBCRJ891UU7D7XUWCSBE1I35H6S234SBYMUBH5PZQRYZF07AX65C',
#  '3A9AA95ATXKU4HZA4VP04Z6H4SL5P738SKSKU7R2VGPKFRJNFNCR1244QILW',
#  '3U088ZLJVLRLTJAAJBXJFYIMGHCW0735GCEFQ6I6ML46ECDLZ9G0AB0V13Z0',
#  '3E47SOBEYRUNMGLL6AMO98BF8J5CID3IXEICO793HOFDSVQV8P1FLENEB6TX',
#  '3HQUKB7LNGCE7TLHMKI4KN7GNA3HHW3GD6L00D3TVPVW1EBSVWK5Z5N761MQ',
#  '3LJ7UR74RIBC5DJXABTYVIV818ZN4D3WSELTNVR40P2F4YG8P1HKN0IWETAK',
#  '3A4TN5196LGNQLA10S439WA09GMCH13NKQQ8O39Z320ZMZ0N6DCHH8OOTUDD',
#  '3X65QVEQI1LPCHTRRDJ11O37R0WLCP3GNCZX450JLRANBRZRGHCAM3W7DAPB',
#  '3EQHHY4HQTQOR46B1CZDAQSP39K5G532XVDSJFP0VWKHJAUWVAPO9AFL5M2T',
#  '3HVVDCPGTFQQYX21WE3HK657O5RTY73Q5C1WP23NZRNPG8JTEA33OJ1HX51V',
#  '3TAYZSBPLM6ZICWFETRW1X8G8Q22SX3Y5140Z9DYE6G5UPBF8UT8AMA3EIPW',
#  '3YGXWBAF71FTE9M6LLKKF71W6B7C4O3Z3ZLGNNSJSCQEDLQPGWP7Y7WQCQ3M',
#  '32Z9ZLUT1MIOZA74QXDU4W4HXI0HO93X73LLYYQ2C6HP7SPIDHP74C78VNH0',
#  '3DPNQGW4LMD4YSD5BU7HT79M8HN64Z3HMIGG0U4M470DADTGSMTA9K9D1Y8N',
#  '3DPNQGW4LMD4YSD5BU7HT79M9UZ4603QFUFYSY9ZD0HL6GCNALNDMZ2T24F3',
#  '35H6S234SBYMUBH5PZQRYZF0AS956Q3PDJHANYK6EYA410Q1R0NWIQF116H9',
#  '3FPRZHYEPZ54VM92COA6VUXFA2G3VJ3LPW2N6LKU07WM76LHOUE5TGARZ5UN',
#  '3D3VGR7TA1DC2FSL345WUX8CPY7R3M3U4J9857OF97NRCJ9JMW7ZFOCEQ7BU',
#  '3Q8GYXHFEQ0BASQ6ZQ3UKZ7A4ZTC523X08E93BHWGIDFHJUI0WQ5T048U66L',
#  '3QBD8R3Z22HUNYJ9BQTBA7VDVGHO4630X31N5D64OONFRJR8KB7FREKFIAS2',
#  '3WOKGM4L72EDOA18SP69Y450DFH0O33TK8OJTYM2JB2BEPAM7D8X0GHGPVP6',
#  '3VW04L3ZLU48F9LBWSICQVJ4XDWXXX39JEC7537VZS8M5L5HL7OX19GKTCV0',
#  '336KAV9KYRQWEY8ODZJLJJWHOJ2Y2Q3DPNQGW4LMD4YSD5BU7HT79M9N664V',
#  '3DQQ64TANHJOH0EU0WC9UZJUOPQWPG3FTF2T8WLSG3PDYNJ7GC89JFJL99WZ',
#  '3ZY8KE4ISK1W2NF4AZM282QQKYXVQP34T446B1C1CCFL452KXI34BJMNKC0A',
#  '3P529IW9KZJWFTD1IF929UO9JWEFLF3U8YCDAGXQEG9MEO72YDN90ZN0CQ0B',
#  '3DL65MZB8EDB6BJZARWXOTDMCAFECL338JKRMM27XZX6D3GE8C31KB4NMHA2',
#  '3LPW2N6LKU07WM76LHOUE5TGEU5U5S3EJJQNKU9S3RWNZKIPUYYR9MC4THRT',
#  '3B837J3LDPUGMWD0TJ6X25GND0GSRR3J88R45B2HW360JKA18VWIX0RXUXPC',
#  '3X1FV8S5JYP5PYLQ73HQEOMNAV7VGB3CTOC39K38OD5AAVXBZD5NY0G6J7J3',
#  '3L2IS5HSFBGBMBDCPHKG8MT24PTNUI3IRIK4HM3BI7TWQK49DZC5LA2ZYC6O',
#  '3D3VGR7TA1DC2FSL345WUX8CRIJ3RG3C44YUNSI2NP8UE3J17J2BU9HDKDPW',
#  '34MAJL3QP5L519QNSS9JM4X20PX4333LO69W1SU4B2TT9WTZFKRFOMQGXLGL',
#  '3WETL7AQWU6NXSUN6XSTRW3G17Q35E34Q075JO1YBSSIU7MN8YM8SSMF010Y',
#  '3M1CVSFP613CAZC6Z4V6CFCDZP1AQA3JV9LGBJWUCAZECT6RVCJWSGIJ3OGZ',
#  '39N5ACM9HFLD541M7L2HGFBJQKX9PN3JNQLM5FT5KCEZ1PUKUVPBULF4M2LQ',
#  '3TR2532VIQSU1AWQE1ULZ9Y5QGPJ6J3SKEMFQBZ43CG8LWP1RVK2U9B0H8KV',
#  '3ZSY5X72NY91O4L7M2POI06NLXGOR83WJEQKOXA90OTVSPEP5RBE45SIJA10',
#  '3VA45EW49OLDVZMQO8A9C9OAH021O733LKR6A5KFIT8RRYKPW86JUXG8UT1W',
#  '3P1L2B7AD2NQL6QUHISSWOXOE1COLU3EA3QWIZ4JT48XNWSWHEYIBJW50TI8',
#  '3570Y55XZQHMTSGVCE4ALNQI0QVYGB3KOPY89HM90V4R98VZWNS6MLJHHJ3U',
#  '3X87C8JFV79GAVY0G4HXXF6JPXTSQH3RWE2M8QWI8V6P1WRA6WJF5VPUO0NG',
#  '3MH9DQ757XA5CJWQ2D7LI2K54HJUG23MB8LZR5BGR7VF5FJQ0ZP7GFY7ALK5',
#  '3YT88D1N09WQFBFQDKWZTLMYYMW3KO3YWRV122CTXQJ4Q8JFVXQP37GZMU84',
#  '3OE22WJIGJMWP8Q459CXCGO7AWRQUC39O5D9O87UQ8WD32L7F1529QT463CC',
#  '324G5B4FB4663499B3P7NIJ5O6U7043OVHNO1VE7ZJMYG96A5LT9WNSOGDZV',
#  '3WS1NTTKEZAJIXOFTMNJBAWMJ0Y0FV3JC6VJ2SACHNHDT8FC73E4HM3S35AF',
#  '3EQHHY4HQTQOR46B1CZDAQSP5SM5GB3UNH76FOCT3ML2CHNH25YSAFWJ3YMT',
#  '36ZN444YTSWOV5IOWFVF485W1J3OID3NLZY2D53QNT6I3AWVKWLTSOXOIQL4',
#  '3I33IC7ZWG0VIGALXT55GXEAL0IA2R3HFNH7HEMICDKQP9L4NG81NGZ19QGX',
#  '3BGYGHDBBYI6DDFHKECQAFVC8X622X3PWWM24LHTWHZSH60VLRK68FUXY280',
#  '3VD82FOHKRMXI2WO45ZTT571NROCOT3OJSZ2ATDTU5YBVA89VJ4DFW5LS57O',
#  '3ATTHHXXWBMBPEWGX6IBNLWPA7WIX13Z9WI9EOZ0M59JMPS5L1XFN8ELMKH5',
#  '3MH9DQ757XA5CJWQ2D7LI2K52M6GUJ3M81GAB8A1HHT9HY5IV27QWJJO6QB5',
#  '3A4NIXBJ77X2L35I42DF4K8JM2ZMLK34QN5IT0T0PA3IESL8HD1IF0ZZ4086',
#  '39GAF6DQWSY8LJVNPKWN71IID9R1VX3NG53N1RLWHDRZIC2TW3GJG85RVP8J',
#  '3MAOD8E57R833F77UMV3STS6XA9XNO32KTQ2V7RED7K149F5APZBHOLH9M9V',
#  '3Q8GYXHFEQ0BASQ6ZQ3UKZ7A40U5CY3YOH7BII0A5ARKH9XU25CGEHMX4VK7',
#  '32VNZTT0A82XKBBP3IAF420I5I5R4F3OB0CAO74IN0TOB6WKMS6N2JDA6HYT',
#  '3WZ36BJEV4EULP9QMMPXCV767CNTB63BWI6RSP7H75UUO3JAOM87L9LCC7EB',
#  '3BC8WZX3V4U4LHDNEU6SCVBSWJSRRA31IBVUNM9TXZBYPVWJB8W3MCE1XVFF',
#  '3GFK2QRXXAFKOQWBGH3VWTEDYUB5W035H6S234SBYMUBH5PZQRYZF0ASI650',
#  '39L1G8WVWRPO9AT45AQHO6QZMRU3123RXCAC0YISN7EMPDZA6GMA2G437G8B',
#  '3IXEICO793HOFDSVQV8P1FLEQGW6TP39GAF6DQWSY8LJVNPKWN71IIFQS1VY',
#  '39KFRKBFIOTAL5XT0XHIQWZKPVTOYV3O6CYIULEEZ195MQHIB3456TW9HWUH',
#  '3E4GGUZ1T9P1UTJ79KIUABH6S7V2K93J88R45B2HW360JKA18VWIX1ZQ1XPF',
#  '3HPZF4IVNNR9CG0QAS8RVW533M6CYV3COPXFW7XCAXM0KDBIT66OPZ4QCKPM',
#  '3C44YUNSI2NP8UE3J17J2BU9JU0PDO3SUWZRL0MZBMQUAY00JU2TLDO1DE62',
#  '3MX2NQ3YCASZDQ11QMZHYCSK77J5XH3E7TUJ2EGDK4G7YW2CBMGLUUDLQD9E',
#  '3OCHAWUVGPI2V9M4X93N01B25G9XKS3HMIGG0U4M470DADTGSMTA9KCMA8YR',
#  '30OG32W0SV9UXFGQZH5B447ZG3FNEJ3EF8EXOTT2TZUOVT8VI44D7OIA7J1T',
#  '3X66WABAJXGLDPJ7NTBKVTU5QAJG3B3EA3QWIZ4JT48XNWSWHEYIBJZMOITM',
#  '3ZWFC4W1UV57IR8ENZ6YV6X9VS5RFZ3SEPORI8WOXLORDXM0EJ38OH7TBZAN',
#  '3GS6S824SRVOEF2HKHZHQAEZOFCWNH3GD6L00D3TVPVW1EBSVWK5Z5NCUM19',
#  '32RIADZIST29LQB2I7AKUC5EQPB4SC3X87C8JFV79GAVY0G4HXXF6JMHTSQI',
#  '3E337GFOLA6SHTCH5CVZ47SBT77GNI379J5II41PE49FD5N4PWRC3ABWSELX',
#  '3PB5A5BD0W43E8KUP5EA8A6LW637GU3XUHV3NRVLW2R01MLIHVVQ4QK0LH5O',
#  '30OG32W0SV9UXFGQZH5B447ZFTKNE33EICBYG645UJHR5ROS7OL9QFLX1CJU',
#  '3LPW2N6LKU07WM76LHOUE5TGBTA5U3304SM51WA42T6PWBXMK72QBK0SBBSU']

# %% [markdown]
# # Models

# %% [markdown]
# Load model

# %%
from get_predictions import get_predictions
from helpers import *

# %%
# Get the datasets for experiment split
dataset_pred_no_hist, dataset_pred_hist_cp = get_pred_datasets(split='test')

# %%
# Pickle the dataset for easier use
# # pickle.dump( dataset_pred_no_hist, open( "dataset_pred_no_hist.p", "wb" ) )
# # pickle.dump( dataset_pred_hist_cp, open( "dataset_pred_hist_cp.p", "wb" ) )
# dataset_pred_no_hist = pickle.load(open( "dataset_pred_no_hist.p", "rb" ) )
# dataset_pred_hist_cp = pickle.load(open( "dataset_pred_hist_cp.p", "rb" ) )

# %%
# First index
ind = 24
print('Endocing of this segment is', dataset_pred_no_hist[ind]['segment'])
print('Decoded segment is', vocab.decode(dataset_pred_no_hist[ind]['segment']))
print('Length of the segment is', dataset_pred_no_hist[ind]['length'])
print('Images in the round of this segment is', dataset_pred_no_hist[ind]['image_set'])
print('Target of this segment is', dataset_pred_no_hist[ind]['targets'])
print('Rank (e.g. first time or third time this image was referenced in this game)', dataset_pred_no_hist[ind]['ranks'])
print('Predictions of the model on the segment is', dataset_pred_no_hist[ind]['preds'])
print('Loss of the predictions', dataset_pred_no_hist[ind]['loss'])

print(len(dataset_pred_no_hist))
# Out:
# Endocing of this segment is [5, 38, 59, 415, 23, 249, 18, 690, 10, 4, 17]
# Decoded segment is ['-B-', 'two', 'pink', 'bowls', 'of', 'rice', 'and', 'broccoli', '?', '-A-', 'yes']
# Length of the segment is 11
# Images in the round of this segment is ['132002', '310714', '100022', '492731', '356290', '395097', '144797', '86285']
# Target of this segment is [7, 2]
# Rank (e.g. first time or third time this image was referenced in this game) [1, 1]
# Predictions of the model on the segment is tensor([[[0.],
#          [0.],
#          [1.],
#          [0.],
#          [0.],
#          [0.],
#          [0.],
#          [0.]]])
# Loss of the predictions tensor(12.6820)
# 6801

# %% [markdown]
# ## Sort segments into conditions

# %% [markdown]
# The following things have been taken into account when creating the dataframes:
# - Only the predictions where there was only one target image given a segment (and thus not multiple target images given a segment)
# - Only the predictions where the model predicts one image (and thus not multiple images given a segment)
#
# correct_prediction = 1 when the model predicts correctly, 0 when the model predicts wrong

# %%
dataframe = get_pred_dataframe(dataset_pred_no_hist, dataset_pred_hist_cp)
# Out:
#  20%|███████████████▎                                                           | 1384/6801 [00:00<00:00, 13740.00it/s]
# [4, 12, 22, 7, 21, 11, 294, 16, 9, 945, 10, 5, 13, 8, 12, 31] [4, 12, 22, 7, 21, 11, 294, 16, 9, 945, 10, 5, 13, 8, 12, 31]
# No history
# 100%|███████████████████████████████████████████████████████████████████████████| 6801/6801 [00:00<00:00, 17314.97it/s]
#  31%|███████████████████████▍                                                   | 2130/6801 [00:00<00:00, 21137.84it/s]
# History
# 100%|███████████████████████████████████████████████████████████████████████████| 6801/6801 [00:00<00:00, 12486.74it/s]

# %% [markdown]
# Sort the segments in their conditions (whether the history/no history dataset predicted them correctly)
#
# hT_nhF - history True, no-history False (so it was correctly predicted with history, incorrectly without)

# %% [markdown]
# Conditions_inds is a dictionary of lists, {'condition': [segment indices for this condition]}

# %%
conditions_inds = get_conditions_inds(dataframe)

print("Number of segments in conditions")
counter = 0
for key in conditions_inds:
    print(key, len(conditions_inds[key]))
    counter +=len(conditions_inds[key])
counter
# Out:
# Number of segments in conditions
# hT_nhT 1702
# hT_nhF 112
# hF_nhT 121
# hF_nhF 248
# only_h 681
# only_nh 787
# nothing 3150
# all 6801
# h_nh_all 2183
# 15785

# %%
print("The number of segments per condition that have a history:")
# For each condition
for condition in conditions_inds:
    counter = 0
#     for seg_id in range(len(dataset_pred_hist_cp)):
    # Iterate over the indices in this condition
    for seg_id in conditions_inds[condition]:
        # For each chain that this segment belongs to
        for chain_i in range(len(dataset_pred_hist_cp[seg_id]['chains'])):
            # Add counter if the segment is not the first round
            if dataset_pred_hist_cp[seg_id]['rounds'][chain_i] > 0:
                counter += 1
                break
    print(condition, counter)
# Out:
# The number of segments per condition that have a history:
# hT_nhT 1144
# hT_nhF 84
# hF_nhT 61
# hF_nhF 154
# only_h 419
# only_nh 548
# nothing 2439
# all 4849
# h_nh_all 1443

# %%
results_hist_orig, results_nohist_orig, accs_hist_orig, accs_nohist_orig = get_accuracies(conditions_inds, dataframe)
print("history accuracy")
print(accs_hist_orig)
print("no history accuracy")
print(accs_nohist_orig)
# Out:
# history accuracy
# {'hT_nhT': 1.0, 'hT_nhF': 1.0, 'hF_nhT': 0.0, 'hF_nhF': 0.0, 'only_h': 0.7430249632892805, 'only_nh': nan, 'nothing': nan, 'all': 0.8100558659217877, 'h_nh_all': 0.8309665597801191}
# no history accuracy
# {'hT_nhT': 1.0, 'hT_nhF': 0.0, 'hF_nhT': 1.0, 'hF_nhF': 0.0, 'only_h': nan, 'only_nh': 0.7306226175349428, 'nothing': nan, 'all': 0.8074074074074075, 'h_nh_all': 0.8350893266147503}
# C:\Users\linda\Documents\Projects\CDM\photobook_dataset\discriminator\helpers.py:279: RuntimeWarning: invalid value encountered in double_scalars
#   accs_nohist[condition] = res.sum()/len(res)
# C:\Users\linda\Documents\Projects\CDM\photobook_dataset\discriminator\helpers.py:277: RuntimeWarning: invalid value encountered in double_scalars
#   accs_hist[condition] = res.sum()/len(res)

# %% [markdown]
# ## Combine segments with first in the chain for analyses
# Create a dict with the first segment and current segment of a condition

# %%
condition_seg_hist = get_condition_seg_hist(conditions_inds, dataset_pred_hist_cp)

# %%
seg_id = 11
condition_seg_hist['hT_nhT'][13]
# Out:
# {2: {'first_id': 2,
#   'first_seg': [4, 21, 11, 757, 18, 6, 26, 49, 10, 5, 41],
#   'current_id': 13,
#   'current_seg': [5, 549, 23, 435, 51, 29, 26, 49, 10, 4, 13, 5, 80],
#   'round': 1}}

# %% [markdown]
# ## leaving out pos tags

# %%
def run_pos_tag_exp(tag, perc_remove):
    

    
    percentage_remove = perc_remove / 100
    
    from ChainDataset import ChainDataset

    chain_test_set = ChainDataset(
        data_dir='data/',
        segment_file='segments.json',
        chain_file='test_chains.json',
        vectors_file='vectors.json',
        split='test'
    )
    from collections import Counter
    import nltk
    import pickle
    from nltk import word_tokenize
    from nltk.tag import pos_tag
    nltk.download('punkt')
    nltk.download('averaged_perceptron_tagger')
    nltk.download('tagsets')
    nltk.download('universal_tagset')

    from Vocab import Vocab
    vocab = Vocab('data/vocab.csv', 3)
    with open('oov_dictionary.pickle', 'rb') as f:
        oov_dict = pickle.load(f)
    
    history_dict = create_history_dict(chain_test_set.chains)

    # Remove tags from nouns
    segment_test_set_cp, chain_test_set_cp = import_dialogue_data()
    
    
    print("EERST", segment_test_set_cp[8])
    segment_test_set = remove_tag(tag, segment_test_set_cp, percentage_remove)
    print("DAARNA", segment_test_set[8])
    chain_data = update_history_dataset(segment_test_set, history_dict, chain_test_set_cp)
    
    print("IN CHAIN", chain_data[0])
    dump_json_files(chain_data, segment_test_set, tag, perc_remove)
    
    return None

# %% [markdown]
# ## Perturbations

# %% [markdown]
# If we make a new perturbation:
#
#     * create a new segment and chain file, even if one of them is the same as the test file. Leave vocab file just as it is.
#     * Make sure the file format is split+_chains.json and split+segments.json, where split is e.g. 'test_shuffle'. Split can be used to indicate the experiment that is run
#     * Also let these files be put into the '/data' folder
#     * When shuffeling files based on chain_test_set or segments_test set, make a deep copy first!!
#     * If you change the segments in the chains json file, make sure you also update the lengths
#
#     * add the experiment and the correspnding segment and chain files in the experiment_names dictionary

# %% [markdown]
# ##### extra info
# The training model takes these files as input.
#
# Change chains if we want to switch up the segments (i.e. from other games or change the order)
#
# Change segments if we want to change things within the utterances

# %%
# For later analyses
experiment_names = {
                    "standard":{'segments_file':'data/test_chains.json',
                                'chains_file':'data/test_segments.json',
                                'split':'test'},
                   "shuffle":{'segments_file':'data/test_shuffle_chains.json',
                                'chains_file':'data/test_shuffle_segments.json',
                                'split':'test_shuffle'},
                    
                    "pos_tag_noun":{'segments_file':'data/test_noun_segments.json',
                                'chains_file':'data/test_noun_chains.json',
                                'split':'test_noun'},
                    "pos_tag_verb":{'segments_file':'data/test_verb_segments.json',
                                'chains_file':'data/test_verb_chains.json',
                                'split':'test_verb'},
                    "pos_tag_adj":{'segments_file':'data/test_adj_segments.json',
                                'chains_file':'data/test_adj_chains.json',
                                'split':'test_adj'},
                    "pos_tag_adv":{'segments_file':'data/test_adv_segments.json',
                                'chains_file':'data/test_adv_chains.json',
                                'split':'test_adv'},
                    
                    "pos_tag_noun":{'segments_file':'data/test_NOUN_100_segments.json',
                                'chains_file':'data/test_NOUN_100_chains.json',
                                'split':'test_noun'},
                    "pos_tag_verb":{'segments_file':'data/test_VERB_100_segments.json',
                            'chains_file':'data/test_VERB_100_chains.json',
                            'split':'test_verb'},
                    "pos_tag_adj":{'segments_file':'data/test_ADJ_100_segments.json',
                            'chains_file':'data/test_ADJ_100_chains.json',
                            'split':'test_adj'},
                    "pos_tag_adv":{'segments_file':'data/test_ADV_100_segments.json',
                            'chains_file':'data/test_ADV_100_chains.json',
                            'split':'test_adv'},
    
                    "pos_tag_noun":{'segments_file':'data/test_NOUN_50_segments.json',
                            'chains_file':'data/test_NOUN_50_chains.json',
                            'split':'test_noun'},
                    "pos_tag_verb":{'segments_file':'data/test_VERB_50_segments.json',
                            'chains_file':'data/test_VERB_50_chains.json',
                            'split':'test_verb'},
                    "pos_tag_adj":{'segments_file':'data/test_ADJ_50_segments.json',
                            'chains_file':'data/test_ADJ_50_chains.json',
                            'split':'test_adj'},
                    "pos_tag_adv":{'segments_file':'data/test_ADV_50_segments.json',
                            'chains_file':'data/test_ADV_50_chains.json',
                            'split':'test_adv'},

                    
                   "games_0":{'segments_file':'data/test_games_0_segments.json',
                                'chains_file':'data/test_games_0_chains.json',
                                'split':'test_games_0'},
                   "games_1":{'segments_file':'data/test_games_1_segments.json',
                                'chains_file':'data/test_games_1_chains.json',
                                'split':'test_games_1'},
                   "games_2":{'segments_file':'data/test_games_2_segments.json',
                                'chains_file':'data/test_games_2_chains.json',
                                'split':'test_games_2'},
                   "games_3":{'segments_file':'data/test_games_3_segments.json',
                                'chains_file':'data/test_games_3_chains.json',
                                'split':'test_games_3'},
                   "games_4":{'segments_file':'data/test_games_4_segments.json',
                                'chains_file':'data/test_games_4_chains.json',
                                'split':'test_games_4'},
                    
                   "imgs_0":{'segments_file':'data/test_imgs_0_segments.json',
                                'chains_file':'data/test_imgs_0_chains.json',
                                'split':'test_imgs_0'},   
                   "imgs_1":{'segments_file':'data/test_imgs_1_segments.json',
                                'chains_file':'data/test_imgs_1_chains.json',
                                'split':'test_imgs_1'},   
                   "imgs_2":{'segments_file':'data/test_imgs_2_segments.json',
                                'chains_file':'data/test_imgs_2_chains.json',
                                'split':'test_imgs_2'},   
                   "imgs_3":{'segments_file':'data/test_imgs_3_segments.json',
                                'chains_file':'data/test_imgs_3_chains.json',
                                'split':'test_imgs_3'},   
                   "imgs_4":{'segments_file':'data/test_imgs_4_segments.json',
                                'chains_file':'data/test_imgs_4_chains.json',
                                'split':'test_imgs_4'},   
                   }

for experiment in experiment_names:
    experiment_names[experiment]['accs_hist'] = []
    experiment_names[experiment]['accs_nohist'] = []
    experiment_names[experiment]['lengths'] = []
    experiment_names[experiment]['dataframe'] = []
    experiment_names[experiment]['changed_seg_ids'] = []

# %%
experiment_names
# Out:
# {'standard': {'segments_file': 'data/test_chains.json',
#   'chains_file': 'data/test_segments.json',
#   'split': 'test',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'shuffle': {'segments_file': 'data/test_shuffle_chains.json',
#   'chains_file': 'data/test_shuffle_segments.json',
#   'split': 'test_shuffle',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'pos_tag_noun': {'segments_file': 'data/test_NOUN_50_segments.json',
#   'chains_file': 'data/test_NOUN_50_chains.json',
#   'split': 'test_noun',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'pos_tag_verb': {'segments_file': 'data/test_VERB_50_segments.json',
#   'chains_file': 'data/test_VERB_50_chains.json',
#   'split': 'test_verb',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'pos_tag_adj': {'segments_file': 'data/test_ADJ_50_segments.json',
#   'chains_file': 'data/test_ADJ_50_chains.json',
#   'split': 'test_adj',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'pos_tag_adv': {'segments_file': 'data/test_ADV_50_segments.json',
#   'chains_file': 'data/test_ADV_50_chains.json',
#   'split': 'test_adv',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'games_0': {'segments_file': 'data/test_games_0_segments.json',
#   'chains_file': 'data/test_games_0_chains.json',
#   'split': 'test_games_0',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'games_1': {'segments_file': 'data/test_games_1_segments.json',
#   'chains_file': 'data/test_games_1_chains.json',
#   'split': 'test_games_1',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'games_2': {'segments_file': 'data/test_games_2_segments.json',
#   'chains_file': 'data/test_games_2_chains.json',
#   'split': 'test_games_2',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'games_3': {'segments_file': 'data/test_games_3_segments.json',
#   'chains_file': 'data/test_games_3_chains.json',
#   'split': 'test_games_3',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'games_4': {'segments_file': 'data/test_games_4_segments.json',
#   'chains_file': 'data/test_games_4_chains.json',
#   'split': 'test_games_4',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'imgs_0': {'segments_file': 'data/test_imgs_0_segments.json',
#   'chains_file': 'data/test_imgs_0_chains.json',
#   'split': 'test_imgs_0',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'imgs_1': {'segments_file': 'data/test_imgs_1_segments.json',
#   'chains_file': 'data/test_imgs_1_chains.json',
#   'split': 'test_imgs_1',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'imgs_2': {'segments_file': 'data/test_imgs_2_segments.json',
#   'chains_file': 'data/test_imgs_2_chains.json',
#   'split': 'test_imgs_2',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'imgs_3': {'segments_file': 'data/test_imgs_3_segments.json',
#   'chains_file': 'data/test_imgs_3_chains.json',
#   'split': 'test_imgs_3',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'imgs_4': {'segments_file': 'data/test_imgs_4_segments.json',
#   'chains_file': 'data/test_imgs_4_chains.json',
#   'split': 'test_imgs_4',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []}}

# %% [markdown]
# ### Shuffle experiment
# Change order of the segments in a chain

# %%
import copy
from perturbations import chain_shuffle

# Get a deepcopy of the chain list
chain_test_shuf_ch = copy.deepcopy(chain_test_set.chains)   

# Shuffle segment order
# Make sure output file ends with chains.json. So now 'test_shuf' is the split argument in following functions
data_chain_shuf, data_seg_shuf = chain_shuffle(chain_test_shuf_ch, chain_file='data/test_shuffle_chains.json', segment_file='data/test_shuffle_segments.json')

# %%
pert_sanity_check(test_chains_exp='data/test_shuffle_chains.json', test_segm_exp='data/test_shuffle_segments.json')
# Out:
# Sanity check
# original chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3279, 'target': '341060', 'segments': [0, 7, 8], 'lengths': [35, 15, 33]}
# experiment chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3279, 'target': '341060', 'segments': [8, 7, 0], 'lengths': [33, 15, 35]}
#
# original segments
# {'segment': [5, 212, 4, 166, 5, 12, 22, 782, 29, 234, 213, 10, 4, 416, 14, 12, 22, 7, 6, 49, 11, 6, 155, 295, 11, 6, 811, 16, 9, 95, 10, 5, 17, 8, 12], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [5], 'length': 35}
# experiment segments
# {'segment': [5, 212, 4, 166, 5, 12, 22, 782, 29, 234, 213, 10, 4, 416, 14, 12, 22, 7, 6, 49, 11, 6, 155, 295, 11, 6, 811, 16, 9, 95, 10, 5, 17, 8, 12], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [5], 'length': 35}
# -----------------------------------
# original chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3280, 'target': '93469', 'segments': [1, 5, 11, 16], 'lengths': [16, 14, 11, 10]}
# experiment chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3280, 'target': '93469', 'segments': [5, 11, 1, 16], 'lengths': [14, 11, 16, 10]}
#
# original segments
# {'segment': [4, 12, 22, 7, 21, 11, 294, 16, 9, 945, 10, 5, 13, 8, 12, 31], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [0], 'length': 16}
# experiment segments
# {'segment': [4, 12, 22, 7, 21, 11, 294, 16, 9, 945, 10, 5, 13, 8, 12, 31], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [0], 'length': 16}
# -----------------------------------
# original chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3281, 'target': '259745', 'segments': [2, 13], 'lengths': [11, 13]}
# experiment chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3281, 'target': '259745', 'segments': [2, 13], 'lengths': [11, 13]}
#
# original segments
# {'segment': [4, 21, 11, 757, 18, 6, 26, 49, 10, 5, 41], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [6, 2, 3], 'length': 11}
# experiment segments
# {'segment': [4, 21, 11, 757, 18, 6, 26, 49, 10, 5, 41], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [6, 2, 3], 'length': 11}
# -----------------------------------

# %% [markdown]
# ## Game exchange experiment
# For a certain round round_id, change the segment in that round for a segment on the same image from the same round but a random game

# %%
def pert_exchange_games(chain_copy, segment_test_set, round_id, chain_file_start='data/test_games_', segment_file_start='data/test_games_', output=True):
    """ 
    Chain_copy is a deepcopy of chain_test_set.chains
    Changes the segements in round round_id for another segment on the same image another game (including its target). 
    Returns the new chain, segment and list of the segment ids that were changed
    """
    
    chain_test_game_n, segment_test_set, changed_seg_ids = exchange_games(chain_copy, segment_test_set, round_id)
    segment_list = [segment_test_set[i] for i in range(len(segment_test_set))]

    # Write new chains and segment file
    if output:
        with open(chain_file_start+str(round_id)+'_chains.json', 'w') as json_file:
            json.dump(chain_test_game_n, json_file)
        with open(segment_file_start+str(round_id)+'_segments.json', 'w') as json_file:
            json.dump(segment_list, json_file)
    return chain_test_game_n, segment_list, changed_seg_ids


def get_seg2chains(chains, segment_test_set):
    """
    chains is chain_test_set.chains
    returns a dict that gives a list of chainids for each segment id
    """
    seg2chains = {seg_id:[] for seg_id in range(len(segment_test_set))}
    for chain_id in range(len(chains)):
        for seg_id in chains[chain_id]['segments']:
            seg2chains[seg_id].append(chain_id)
    return seg2chains


def exchange_games(chains, segment_test_set, round_id):
    """
    chains is chain_test_set.chains
    round_id is the round that we want to change

    Changes the segements in round round_id for another segments text on the same image another game
    
    Returns the new chain test set and the segment indices of the new segments in the chains.
    """
    # Get a deepcopy of the chain list  
    chain_test_game_n = copy.deepcopy(chains) 
    segment_test_set_cp =copy.deepcopy(segment_test_set)   

    img_dict = get_img_dict(chains)
    seg2chains = get_seg2chains(chains, segment_test_set)
    changed_seg_ids = []
    
    # Shuffle the chain indices so that each segment still occurs once
    for img_id in img_dict:
        if round_id in img_dict[img_id]:
            random.shuffle(img_dict[img_id][round_id]['chain_ids_shuf'])

    # Iterate over the indices in the chain set
    for chain_id in range(len(chain_test_game_n)):
        img_id = chain_test_game_n[chain_id]['target']

        # Check if there are at least round_id rounds in this chain
        if len(chain_test_game_n[chain_id]['segments']) <= round_id:
            continue
        # Check if there are other games to change segment texts with
        if len(set(img_dict[img_id][round_id]['game_ids'])) == 1:
            continue
        # Check if the segment occurs in only one chain, otherwise the perturbations are unclear
        current_segid = chain_test_game_n[chain_id]['segments'][round_id]
        if len(seg2chains[current_segid]) > 1:
            continue
        
        # Get index of the new segment, given the shuffled chain ids
        new_seg_ind = img_dict[img_id][round_id]['chain_ids_shuf'].index(chain_id)
        new_seg_id = img_dict[img_id][round_id]['segments'][new_seg_ind]

        # Change segment text in round_id to the new_seg_id
        # Change the text of this segment to the new seg id text in the segmentstestset
        segment_test_set_cp[current_segid]['segment'] = segment_test_set[new_seg_id]['segment']
        segment_test_set_cp[current_segid]['length'] = segment_test_set[new_seg_id]['length']
        # Change the length in the chain it occurs in 
        chain_test_game_n[chain_id]['lengths'][round_id] = len(segment_test_set_cp[current_segid]['segment'])

        # Save new segment id for analysis
        changed_seg_ids.append(current_segid)
    return chain_test_game_n, segment_test_set_cp, changed_seg_ids

def get_img_dict(chains):
    """
    chains is chain_test_set.chains
    Return a dictionary of
    {img_id:{'round_id':'segments':[segids],
                        'lengths':[seglengths],
                        'game_ids':[gameids],
                        'chain_ids':[chainids],
                        'chain_ids_shuf':[chainids]}}
    where img_id is the image id of the target of the segments
    round_id is the round/rank, i.e. the i'th time the image is being talked about
    segid is the segment id
    seglength is the length of the segment with the corresponding index
    gameid is the gameid to which the segment with the corresponding index belongs
    chain_ids is the chain_ids to which the segment with the corresponding index belongs
    chain_ids_shuf can be shuffled so that the index of the chainid can be used to shuffle the segments
    """
    img_dict = {}
    # Get segments, lengths and gameids
    for chain_id in range(len(chains)):
        image_ind = chains[chain_id]['target']
        game_id = chains[chain_id]['game_id']
        # Add target image index to the img_dict
        if image_ind not in img_dict:
            img_dict[image_ind] = {}

        # Iterate over the rounds/segments
        for round_ind in range(len(chains[chain_id]['segments'])):

            # Add round to the dict for this target image
            if round_ind not in img_dict[image_ind]:
                img_dict[image_ind][round_ind] = {'segments':[],
                                                  'lengths':[],
                                                 'game_ids':[],
                                                 'chain_ids':[],
                                                 'chain_ids_shuf':[]}

            # Add segment with the length and gameid info to this round dict
            img_dict[image_ind][round_ind]['segments'].append(chains[chain_id]['segments'][round_ind])
            img_dict[image_ind][round_ind]['lengths'].append(chains[chain_id]['lengths'][round_ind])
            img_dict[image_ind][round_ind]['game_ids'].append(game_id)
            img_dict[image_ind][round_ind]['chain_ids'].append(chain_id)
            img_dict[image_ind][round_ind]['chain_ids_shuf'].append(chain_id)

    return img_dict

# %%
chain_copy = copy.deepcopy(chain_test_set.chains)
chain_test_img_n, segments, changed_seg_ids = pert_exchange_games(chain_copy, segment_test_set, 0, chain_file_start='data/test_games_', segment_file_start='data/test_games_', output=True)

# %%
pert_sanity_check(test_chains_exp='data/test_games_0_chains.json', test_segm_exp='data/test_games_0_segments.json')
# Out:
# Sanity check
# original chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3279, 'target': '341060', 'segments': [0, 7, 8], 'lengths': [35, 15, 33]}
# experiment chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3279, 'target': '341060', 'segments': [0, 7, 8], 'lengths': [22, 15, 33]}
#
# original segments
# {'segment': [5, 212, 4, 166, 5, 12, 22, 782, 29, 234, 213, 10, 4, 416, 14, 12, 22, 7, 6, 49, 11, 6, 155, 295, 11, 6, 811, 16, 9, 95, 10, 5, 17, 8, 12], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [5], 'length': 35}
# experiment segments
# {'segment': [4, 8, 7, 6, 286, 98, 11, 6, 389, 18, 295, 23, 263, 154, 143, 51, 29, 30, 5, 8, 7, 20], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [5], 'length': 22}
# -----------------------------------
# original chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3280, 'target': '93469', 'segments': [1, 5, 11, 16], 'lengths': [16, 14, 11, 10]}
# experiment chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3280, 'target': '93469', 'segments': [1, 5, 11, 16], 'lengths': [19, 14, 11, 10]}
#
# original segments
# {'segment': [4, 12, 22, 7, 21, 11, 294, 16, 9, 945, 10, 5, 13, 8, 12, 31], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [0], 'length': 16}
# experiment segments
# {'segment': [4, 8, 142, 71, 14, 110, 22, 10, 5, 13, 12, 22, 7, 6, 49, 11, 294, 18, 2049], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [0], 'length': 19}
# -----------------------------------
# original chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3281, 'target': '259745', 'segments': [2, 13], 'lengths': [11, 13]}
# experiment chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3281, 'target': '259745', 'segments': [2, 13], 'lengths': [11, 13]}
#
# original segments
# {'segment': [4, 21, 11, 757, 18, 6, 26, 49, 10, 5, 41], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [6, 2, 3], 'length': 11}
# experiment segments
# {'segment': [4, 21, 11, 757, 18, 6, 26, 49, 10, 5, 41], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [6, 2, 3], 'length': 11}
# -----------------------------------

# %% [markdown]
# ## Image exchange experiment
# For a round_id, change the segment for another segment on another target image but from the same game

# %%
def pert_exchange_imgs(chain_copy, segment_test_set, round_id, chain_file_start='data/test_imgs_', segment_file_start='data/test_imgs_', output=True):
    """ 
    Chain_copy is a deepcopy of chain_test_set.chains
    """
    
    chain_test_game_n, segment_test_set, changed_seg_ids = exchange_images(chain_copy, segment_test_set, round_id)
    segment_list = [segment_test_set[i] for i in range(len(segment_test_set))]

    # Write new chains file
    if output:
        with open(chain_file_start+str(round_id)+'_chains.json', 'w') as json_file:
            json.dump(chain_test_game_n, json_file)
        # Keep segment file the same
        with open(segment_file_start+str(round_id)+'_segments.json', 'w') as json_file:
            json.dump(segment_list, json_file)
    return chain_test_game_n, segment_list, changed_seg_ids

def get_seg2chains(chains, segment_test_set):
    """
    chains is chain_test_set.chains
    returns a dict that gives a list of chainids for each segment id
    """
    seg2chains = {seg_id:[] for seg_id in range(len(segment_test_set))}
    for chain_id in range(len(chains)):
        for seg_id in chains[chain_id]['segments']:
            seg2chains[seg_id].append(chain_id)
    return seg2chains

def exchange_images(chains, segment_test_set, round_id):
    """
    chains is chain_test_set.chains
    round_id is the round that we want to change

    Changes the segements in round round_id for another segment of the same game but another image (including its target). 
    Returns the new chain test set and the segment indices of the new segments in the chains.
    """
    # Get a deepcopy of the chain list
    chain_test_game_n = copy.deepcopy(chains)
    segment_test_set_cp =copy.deepcopy(segment_test_set)
    
    game_dict = get_game_dict(chains)
    seg2chains = get_seg2chains(chains, segment_test_set)
    changed_seg_ids = []
    
    # Shuffle the target indices
    for game_id in game_dict:
        if round_id in game_dict[game_id]:
            random.shuffle(game_dict[game_id][round_id]['chain_ids_shuf'])

    # Iterate over the indices in the chain set
    for chain_id in range(len(chain_test_game_n)):
        game_id = chain_test_game_n[chain_id]['game_id']

        # Check if there are at least round_id rounds in this chain
        if len(chain_test_game_n[chain_id]['segments']) <= round_id:
            continue
        # Check if there are other images to change segment text with
        if len(set(game_dict[game_id][round_id]['targets'])) == 1:
            continue
        # Check if the segment occurs in only one chain, otherwise the perturbations are unclear
        current_segid = chain_test_game_n[chain_id]['segments'][round_id]
        if len(seg2chains[current_segid]) > 1:
            continue

        # Get index of the new segment, given the shuffled chain ids
        new_seg_ind = game_dict[game_id][round_id]['chain_ids_shuf'].index(chain_id)
        new_seg_id = game_dict[game_id][round_id]['segments'][new_seg_ind]


        # Change segment text in round_id to the new_seg_id
        # Change the text of this segment to the new seg id text in the segmentstestset
        segment_test_set_cp[current_segid]['segment'] = segment_test_set[new_seg_id]['segment']
        segment_test_set_cp[current_segid]['length'] = segment_test_set[new_seg_id]['length']
        # Change the length in the chain it occurs in 
        chain_test_game_n[chain_id]['lengths'][round_id] = len(segment_test_set_cp[current_segid]['segment'])

        # Save new segment id for analysis
        changed_seg_ids.append(current_segid)
    return chain_test_game_n, segment_test_set_cp, changed_seg_ids


def get_game_dict(chains):
    """
    chains is chain_test_set.chains
    Return a dictionary of
    {game_id:{'round_id':'segments':[segids],
                        'lengths':[seglengths],
                        'game_ids':[gameids]}}
    where game_id is the game_id of the chain
    round_id is the round/rank, i.e. the i'th time the image is being talked about
    segid is the segment id
    seglength is the length of the segment with the corresponding index
    gameid is the gameid to which the segment with the corresponding index belongs

    Used for exchange_images()
    """
    game_dict = {}
    # Get segments, lengths and gameids
    for chain_id in range(len(chains)):
        image_ind = chains[chain_id]['target']
        game_id = chains[chain_id]['game_id']
        # Add gameid to the game_dict    
        if game_id not in game_dict:
            game_dict[game_id] = {}

        # Iterate over the rounds/segments
        for round_ind in range(len(chains[chain_id]['segments'])):

            # Add round to the dict for this target image
            if round_ind not in game_dict[game_id]:
                game_dict[game_id][round_ind] = {'segments':[],
                                                  'lengths':[],
                                                 'game_ids':[],
                                                 'targets':[],
                                                 'chain_ids':[],
                                                 'chain_ids_shuf':[]}

            # Add segment with the length and gameid info to this round dict
            game_dict[game_id][round_ind]['segments'].append(chains[chain_id]['segments'][round_ind])
            game_dict[game_id][round_ind]['lengths'].append(chains[chain_id]['lengths'][round_ind])
            game_dict[game_id][round_ind]['game_ids'].append(game_id)
            game_dict[game_id][round_ind]['targets'].append(image_ind)
            game_dict[game_id][round_ind]['chain_ids'].append(chain_id)
            game_dict[game_id][round_ind]['chain_ids_shuf'].append(chain_id)

    return game_dict

# %%
for round_id in [0, 1, 2, 3, 4]:
    chain_copy = copy.deepcopy(chain_test_set.chains)   
    chain_test_game_n, segments, changed_seg_ids = pert_exchange_imgs(chain_copy, segment_test_set, round_id, chain_file_start='data/test_imgs_', segment_file_start='data/test_imgs_', output=True)

# %%
pert_sanity_check(test_chains_exp='data/test_imgs_0_chains.json', test_segm_exp='data/test_imgs_0_segments.json')
# Out:
# Sanity check
# original chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3279, 'target': '341060', 'segments': [0, 7, 8], 'lengths': [35, 15, 33]}
# experiment chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3279, 'target': '341060', 'segments': [0, 7, 8], 'lengths': [19, 15, 33]}
#
# original segments
# {'segment': [5, 212, 4, 166, 5, 12, 22, 782, 29, 234, 213, 10, 4, 416, 14, 12, 22, 7, 6, 49, 11, 6, 155, 295, 11, 6, 811, 16, 9, 95, 10, 5, 17, 8, 12], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [5], 'length': 35}
# experiment segments
# {'segment': [5, 748, 310, 11, 6, 349, 19, 49, 19, 18, 6, 102, 23, 127, 4, 17, 8, 7, 20], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [5], 'length': 19}
# -----------------------------------
# original chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3280, 'target': '93469', 'segments': [1, 5, 11, 16], 'lengths': [16, 14, 11, 10]}
# experiment chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3280, 'target': '93469', 'segments': [1, 5, 11, 16], 'lengths': [11, 14, 11, 10]}
#
# original segments
# {'segment': [4, 12, 22, 7, 21, 11, 294, 16, 9, 945, 10, 5, 13, 8, 12, 31], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [0], 'length': 16}
# experiment segments
# {'segment': [4, 21, 11, 757, 18, 6, 26, 49, 10, 5, 41], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [0], 'length': 11}
# -----------------------------------
# original chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3281, 'target': '259745', 'segments': [2, 13], 'lengths': [11, 13]}
# experiment chains
# {'game_id': '3R2UR8A0IBELL07JV1VG7ISBNQAOX23WMINLGALC18GY2NUMUBSANWXRHCAO', 'chain_id': 3281, 'target': '259745', 'segments': [2, 13], 'lengths': [11, 13]}
#
# original segments
# {'segment': [4, 21, 11, 757, 18, 6, 26, 49, 10, 5, 41], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [6, 2, 3], 'length': 11}
# experiment segments
# {'segment': [4, 21, 11, 757, 18, 6, 26, 49, 10, 5, 41], 'image_set': ['93469', '380128', '14238', '259745', '524866', '341060', '483794', '96757'], 'targets': [6, 2, 3], 'length': 11}
# -----------------------------------

# %% [markdown]
# ## Run perturbation predictions
# Get the accuracies per condition for an experiment.
# The experiments will be saved in the experiment_names dictionary.

# %%
def experiment_accs(conditions_inds, split='test'):
    # Get dataframes
    dataset_pred_no_hist_exp, dataset_pred_hist_cp_exp = get_pred_datasets(split=split)
    # Get predictions of the segments
    dataframe_exp = get_pred_dataframe(dataset_pred_no_hist_exp, dataset_pred_hist_cp_exp)
    # Get the accuracy dict
    results_hist, results_nohist, accs_hist, accs_nohist = get_accuracies(conditions_inds, dataframe_exp)
    
    return accs_hist, accs_nohist, dataframe_exp, dataset_pred_hist_cp_exp, dataset_pred_no_hist_exp
    
def run_experiment(experiment, conditions_inds):

    split = experiment_names[experiment]['split']
    accs_hist, accs_nohist, dataframe_exp, dataset_pred_hist_cp_exp, dataset_pred_no_hist_exp = experiment_accs(conditions_inds, split=split)

    print(f"Experiment{experiment} accuracies:")
    print("history:")
    print(accs_hist)
    print("No history")
    print(accs_nohist)

    return accs_hist, accs_nohist, dataframe_exp

def new_changed_seg(changed_seg_ids):
    new_changed_seg_ids = []
    for item in changed_seg_ids:
        if changed_seg_ids.count(item)==1:
            new_changed_seg_ids.append(item)
    return new_changed_seg_ids

def run_exp_games_imgs(conditions_inds, segment_test_set, round_id, chains, split, exp='games'):
    """
    chains = chain_test_set.chains
    """
    # Create new segment and chain file
    chain_copy = copy.deepcopy(chains)
    if exp == 'games':
        chain_test_game_n, segments, changed_seg_ids = pert_exchange_games(chain_copy, segment_test_set, round_id, chain_file_start='data/test_games_', segment_file_start='data/test_games_', output=True)
    elif exp == 'imgs':
        chain_test_img_n, segments, changed_seg_ids = pert_exchange_imgs(chain_copy, segment_test_set, round_id, chain_file_start='data/test_imgs_', segment_file_start='data/test_imgs_', output=True)

    # Remove segments that have their history changed multiple times
    changed_seg_ids = new_changed_seg(changed_seg_ids)
    # TODO: Create new conditions_inds
        
    # Get dataframes
    dataset_pred_no_hist_exp, dataset_pred_hist_cp_exp = get_pred_datasets(split=split)

    # Get predictions of the segments
    dataframe_exp = get_pred_dataframe(dataset_pred_no_hist_exp, dataset_pred_hist_cp_exp)
    
    # Get accuracies
    results_hist, results_nohist, accs_hist, accs_nohist = get_accuracies_seg(conditions_inds, dataframe_exp, changed_seg_ids)
    # Get the number of segments that were changed per condition
    lengths = check_lengths(changed_seg_ids, conditions_inds)
    
    return accs_hist, accs_nohist, results_hist, results_nohist, lengths, dataframe_exp, changed_seg_ids

# %%
def experiment_results(experiment_names, chains, segment_test_set, conditions_inds, experiment, remove_prob=0, tag=""):
    """
    Run an experiment [standard, shuffle, pos_tag_noun..., games_0..., imgs_0...]
    round_id is the round for the games and imgs experiments
    prop is the proportion of the pos tags that are to be removed
    n is number of times 
    """
    split = experiment_names[experiment]['split']
    chains = copy.deepcopy(chains)
    
    if experiment == "standard":
        accs_hist, accs_nohist, dataframe = run_experiment(experiment, conditions_inds)
        lengths = {condition: len(conditions_inds[condition])for condition in conditions_inds}
        changed_seg_ids = []
    
    elif experiment == "shuffle":
        # Shuffle segment order
        data_chain_shuf, data_seg_shuf = chain_shuffle(chain_test_shuf_ch, chain_file='data/test_shuffle_chains.json', segment_file='data/test_shuffle_segments.json')

        accs_hist, accs_nohist, dataframe = run_experiment(experiment, conditions_inds)
        lengths = {condition: len(conditions_inds[condition])for condition in conditions_inds}
        changed_seg_ids = []

    # POS experiments
    # TODO: ADD CREATION OF FILES HERE
    # TODO: ADD PERCENTAGE HERE
    elif experiment == "pos_tag_noun":
        
        run_pos_tag_exp(tag, remove_prob)
        
        accs_hist, accs_nohist, dataframe = run_experiment(experiment, conditions_inds)
        lengths = {condition: len(conditions_inds[condition])for condition in conditions_inds}
        changed_seg_ids = []

    elif experiment == "pos_tag_verb":
        run_pos_tag_exp(tag, remove_prob)
        accs_hist, accs_nohist, dataframe = run_experiment(experiment, conditions_inds)
        lengths = {condition: len(conditions_inds[condition])for condition in conditions_inds}
        changed_seg_ids = []

    elif experiment == "pos_tag_adj":
        run_pos_tag_exp(tag, remove_prob)
        accs_hist, accs_nohist, dataframe = run_experiment(experiment, conditions_inds)
        lengths = {condition: len(conditions_inds[condition])for condition in conditions_inds}
        changed_seg_ids = []

    elif experiment == "pos_tag_adv":
        run_pos_tag_exp(tag, remove_prob)
        accs_hist, accs_nohist, dataframe = run_experiment(experiment, conditions_inds)
        lengths = {condition: len(conditions_inds[condition])for condition in conditions_inds}
        changed_seg_ids = []

    # Game exchange
    elif experiment.startswith('games'):
        round_id = int(experiment[-1])
        accs_hist, accs_nohist, results_hist, results_nohist, lengths, dataframe, changed_seg_ids = run_exp_games_imgs(conditions_inds, segment_test_set, round_id, chains, split, exp='games')
    
    # Imgs exchange
    elif experiment.startswith('imgs'):
        round_id = int(experiment[-1])
        accs_hist, accs_nohist, results_hist, results_nohist, lengths, dataframe, changed_seg_ids = run_exp_games_imgs(conditions_inds, segment_test_set, round_id, chains, split, exp='imgs')
    
    
    # Save the accuracies to the experiment_names dict
    experiment_names[experiment]['accs_hist'].append(accs_hist)
    experiment_names[experiment]['accs_nohist'].append(accs_nohist)
    experiment_names[experiment]['lengths'].append(lengths)
    experiment_names[experiment]['dataframe'].append(dataframe)
    experiment_names[experiment]['changed_seg_ids'].append(changed_seg_ids)

    return experiment_names, accs_hist, accs_nohist, lengths

# %% [markdown]
# ### Run experiments multiple times

# %% [markdown]
# ### POS tag perturbations

# %% [markdown]
# Remove all instances of a pos tag

# %%
n_exp = 1
for i in range(n_exp):
    chain_copy = copy.deepcopy(chain_test_set.chains)
    experiment_names, accs_hist, accs_nohist, lengths = experiment_results(experiment_names, chains=chain_copy, conditions_inds=conditions_inds,
                                                                           experiment='pos_tag_noun', remove_prob = 100, tag = "NOUN")
pickle.dump( experiment_names, open( "experiment_remove_noun_100.p", "wb" ))
print("DONE NOUN")
n_exp = 1
for i in range(n_exp):
    chain_copy = copy.deepcopy(chain_test_set.chains)
    experiment_names, accs_hist, accs_nohist, lengths = experiment_results(experiment_names, chains=chain_copy, conditions_inds=conditions_inds,
                                                                           experiment='pos_tag_verb', remove_prob = 100, tag = "VERB")
pickle.dump( experiment_names, open( "experiment_remove_verb_100.p", "wb" ))
print("DONE VERB")
n_exp = 1
for i in range(n_exp):
    chain_copy = copy.deepcopy(chain_test_set.chains)
    experiment_names, accs_hist, accs_nohist, lengths = experiment_results(experiment_names, chains=chain_copy, conditions_inds=conditions_inds,
                                                                           experiment='pos_tag_adj', remove_prob = 100, tag = "ADJ")
pickle.dump( experiment_names, open( "experiment_remove_adj_100.p", "wb" ))
print("DONE ADJ")
n_exp = 1
for i in range(n_exp):
    chain_copy = copy.deepcopy(chain_test_set.chains)
    experiment_names, accs_hist, accs_nohist, lengths = experiment_results(experiment_names, chains=chain_copy, conditions_inds=conditions_inds,
                                                                           experiment='pos_tag_adv', remove_prob = 100, tag = "ADV")
pickle.dump( experiment_names, open( "experiment_remove_adv_100.p", "wb" ))
print("DONE ADV")

# %% [markdown]
# Remove half of the instances

# %%
n_exp = 1
for i in range(n_exp):
    chain_copy = copy.deepcopy(chain_test_set.chains)
    experiment_names, accs_hist, accs_nohist, lengths = experiment_results(experiment_names, chains=chain_copy, conditions_inds=conditions_inds,
                                                                           experiment='pos_tag_noun', remove_prob = 50, tag = "NOUN")
pickle.dump( experiment_names, open( "experiment_remove_noun_50.p", "wb" ))
print("DONE NOUN")
n_exp = 1
for i in range(n_exp):
    chain_copy = copy.deepcopy(chain_test_set.chains)
    experiment_names, accs_hist, accs_nohist, lengths = experiment_results(experiment_names, chains=chain_copy, conditions_inds=conditions_inds,
                                                                           experiment='pos_tag_verb', remove_prob = 50, tag = "VERB")
pickle.dump( experiment_names, open( "experiment_remove_verb_50.p", "wb" ))
print("DONE VERB")
n_exp = 1
for i in range(n_exp):
    chain_copy = copy.deepcopy(chain_test_set.chains)
    experiment_names, accs_hist, accs_nohist, lengths = experiment_results(experiment_names, chains=chain_copy, conditions_inds=conditions_inds,
                                                                           experiment='pos_tag_adj', remove_prob = 50, tag = "ADJ")
pickle.dump( experiment_names, open( "experiment_remove_adj_50.p", "wb" ))
print("DONE ADJ")
n_exp = 1
for i in range(n_exp):
    chain_copy = copy.deepcopy(chain_test_set.chains)
    experiment_names, accs_hist, accs_nohist, lengths = experiment_results(experiment_names, chains=chain_copy, conditions_inds=conditions_inds,
                                                                           experiment='pos_tag_adv', remove_prob = 50, tag = "ADV")
pickle.dump( experiment_names, open( "experiment_remove_adv_50.p", "wb" ))
print("DONE ADV")

# %% [markdown]
# ### Game perturbations

# %%
n_exp = 3
for i in range(n_exp):
    for round_id in range(5):
        chain_copy = copy.deepcopy(chain_test_set.chains)
        experiment_names, accs_hist, accs_nohist, lengths = experiment_results(experiment_names, chains=chain_copy, 
                                                                           segment_test_set=segment_test_set,
                                                                           conditions_inds=conditions_inds,
                                                                            experiment='games_'+str(round_id))
experiment_names

# %% [markdown]
# ### Image perturbations

# %%
n_exp = 3
for i in range(n_exp):
    for round_id in range(5):
        chain_copy = copy.deepcopy(chain_test_set.chains)
        experiment_names, accs_hist, accs_nohist, lengths = experiment_results(experiment_names, chains=chain_copy,
                                                                               segment_test_set=segment_test_set,
                                                                               conditions_inds=conditions_inds,
                                                                               experiment='imgs_'+str(round_id))
experiment_names

# %% [markdown]
# ### Shuffle chain perturbations

# %%
for i in range(3):
    chain_copy = copy.deepcopy(chain_test_set.chains)
    experiment_names, accs_hist, accs_nohist, lengths = experiment_results(experiment_names, chains=chain_copy,
                                                                           segment_test_set=segment_test_set,
                                                                           conditions_inds=conditions_inds,
                                                                           experiment='shuffle')
experiment_names

# %% [markdown]
# ## Analysis of the accuracies

# %%
import matplotlib.pyplot as plt
def print_accs(experiment, print_res=True):
    accs_hist = {condition:[] for condition in experiment_names[experiment]['accs_hist'][0]}
    accs_nohist = {condition:[] for condition in experiment_names[experiment]['accs_nohist'][0]}
    lengths = {condition:[] for condition in experiment_names[experiment]['lengths'][0]}

    # Put values together per condition
    for run in range(len(experiment_names[experiment]['accs_hist'])):
        for condition in experiment_names[experiment]['accs_hist'][run]:
            accs_hist[condition].append(experiment_names[experiment]['accs_hist'][run][condition])
            accs_nohist[condition].append(experiment_names[experiment]['accs_nohist'][run][condition])
            lengths[condition].append(experiment_names[experiment]['lengths'][run][condition])

    # Make numpy array from the lists
    accs_hist = {condition:np.array(accs_hist[condition]) for condition in accs_hist}
    accs_nohist = {condition:np.array(accs_nohist[condition]) for condition in accs_nohist}
    lengths = {condition:np.array(lengths[condition]) for condition in lengths}

    # Print mean and stds
    if print_res:
        print("-------------------------")
        print("Experiment:", experiment)
        print("-------------------------")
        print("History accuracies:")
        for condition in accs_hist:
            print(f"{condition}: mean={accs_hist[condition].mean()}, std={accs_hist[condition].std()}")

        print("\nNo history accuracies:")
        for condition in accs_nohist:
            print(f"{condition}: mean={accs_nohist[condition].mean()}, std={accs_nohist[condition].std()}")

        print("\nNumber of items per condition:")
        for condition in lengths:
            print(f"{condition}: mean={lengths[condition].mean()}, std={lengths[condition].std()}")

        print("-------------------------")
        
    return accs_hist, accs_nohist, lengths

# %% [markdown]
# Load the experiment_names variables with the POS tag perturbation results

# %%
# POS distribution results
experiment_names = pickle.load(open( "experiment_remove_pos_50.p", "rb" ) )
experiment_names
# Out:
# {'pos_tag_noun': {'segments_file': 'data/test_NOUN_50_segments.json',
#   'chains_file': 'data/test_NOUN_50_chains.json',
#   'split': 'test_NOUN_50',
#   'accs_hist': [{'hT_nhT': 0.8329764453961456,
#     'hT_nhF': 0.7647058823529411,
#     'hF_nhT': 0.10714285714285714,
#     'hF_nhF': 0.10628019323671498,
#     'only_h': 0.5772200772200772,
#     'only_nh': 0.45098039215686275,
#     'nothing': 0.4742647058823529,
#     'all': 0.6347368421052632,
#     'h_nh_all': 0.7013850415512466},
#    {'hT_nhT': 0.8333333333333334,
#     'hT_nhF': 0.7191011235955056,
#     'hF_nhT': 0.1574074074074074,
#     'hF_nhF': 0.07179487179487179,
#     'only_h': 0.6058823529411764,
#     'only_nh': 0.4921259842519685,
#     'nothing': 0.44569288389513106,
#     'all': 0.6418654325382699,
#     'h_nh_all': 0.703037120359955},
#    {'hT_nhT': 0.8282608695652174,
#     'hT_nhF': 0.6947368421052632,
#     'hF_nhT': 0.16831683168316833,
#     'hF_nhF': 0.07881773399014778,
#     'only_h': 0.5910852713178295,
#     'only_nh': 0.48507462686567165,
#     'nothing': 0.46296296296296297,
#     'all': 0.6360748323332157,
#     'h_nh_all': 0.6981450252951096}],
#   'accs_nohist': [{'hT_nhT': 0.812457221081451,
#     'hT_nhF': 0.12087912087912088,
#     'hF_nhT': 0.6019417475728155,
#     'hF_nhF': 0.05687203791469194,
#     'only_h': 0.492,
#     'only_nh': 0.5896551724137931,
#     'nothing': 0.45977011494252873,
#     'all': 0.6280013527223537,
#     'h_nh_all': 0.6816720257234726},
#    {'hT_nhT': 0.7987679671457906,
#     'hT_nhF': 0.15,
#     'hF_nhT': 0.5612244897959183,
#     'hF_nhF': 0.06280193236714976,
#     'only_h': 0.5434782608695652,
#     'only_nh': 0.6229235880398671,
#     'nothing': 0.44680851063829785,
#     'all': 0.6295302013422819,
#     'h_nh_all': 0.669882100750268},
#    {'hT_nhT': 0.7891854893908282,
#     'hT_nhF': 0.16494845360824742,
#     'hF_nhT': 0.6020408163265306,
#     'hF_nhF': 0.0794392523364486,
#     'only_h': 0.5809128630705395,
#     'only_nh': 0.5914332784184514,
#     'nothing': 0.46757679180887374,
#     'all': 0.624709398870807,
#     'h_nh_all': 0.6657754010695187}],
#   'lengths': [{'hT_nhT': 1702,
#     'hT_nhF': 112,
#     'hF_nhT': 121,
#     'hF_nhF': 248,
#     'only_h': 681,
#     'only_nh': 787,
#     'nothing': 3150,
#     'all': 6801,
#     'h_nh_all': 2183},
#    {'hT_nhT': 1702,
#     'hT_nhF': 112,
#     'hF_nhT': 121,
#     'hF_nhF': 248,
#     'only_h': 681,
#     'only_nh': 787,
#     'nothing': 3150,
#     'all': 6801,
#     'h_nh_all': 2183},
#    {'hT_nhT': 1702,
#     'hT_nhF': 112,
#     'hF_nhT': 121,
#     'hF_nhF': 248,
#     'only_h': 681,
#     'only_nh': 787,
#     'nothing': 3150,
#     'all': 6801,
#     'h_nh_all': 2183}],
#   'dataframe': [{0: {'History': 0},
#     1: {'No history': 1, 'History': 1},
#     2: {},
#     3: {},
#     4: {'No history': 1, 'History': 0},
#     5: {},
#     6: {},
#     7: {'No history': 0, 'History': 0},
#     8: {},
#     9: {'No history': 0},
#     10: {},
#     11: {'No history': 1, 'History': 1},
#     12: {'No history': 1, 'History': 1},
#     13: {'No history': 1, 'History': 1},
#     14: {'No history': 1},
#     15: {'No history': 1, 'History': 1},
#     16: {'No history': 1, 'History': 1},
#     17: {'No history': 1, 'History': 1},
#     18: {'No history': 1},
#     19: {'No history': 1, 'History': 0},
#     20: {'No history': 0, 'History': 0},
#     21: {'No history': 0, 'History': 0},
#     22: {},
#     23: {'No history': 1, 'History': 1},
#     24: {},
#     25: {'No history': 1},
#     26: {'No history': 0, 'History': 1},
#     27: {},
#     28: {},
#     29: {'No history': 1},
#     30: {},
#     31: {'No history': 1, 'History': 1},
#     32: {},
#     33: {},
#     34: {},
#     35: {'No history': 0, 'History': 0},
#     36: {'History': 1},
#     37: {},
#     38: {'History': 0},
#     39: {'No history': 1, 'History': 1},
#     40: {'No history': 0, 'History': 0},
#     41: {'No history': 1, 'History': 1},
#     42: {'No history': 1, 'History': 1},
#     43: {'History': 1},
#     44: {'History': 0},
#     45: {'No history': 1, 'History': 1},
#     46: {'No history': 1},
#     47: {'No history': 1, 'History': 1},
#     48: {'History': 1},
#     49: {'No history': 1, 'History': 1},
#     50: {'No history': 1, 'History': 1},
#     51: {},
#     52: {},
#     53: {},
#     54: {'History': 1},
#     55: {'History': 0},
#     56: {},
#     57: {'No history': 1, 'History': 1},
#     58: {'History': 1},
#     59: {'No history': 1, 'History': 1},
#     60: {},
#     61: {'History': 0},
#     62: {},
#     63: {'No history': 1, 'History': 1},
#     64: {},
#     65: {'No history': 0, 'History': 0},
#     66: {},
#     67: {},
#     68: {},
#     69: {},
#     70: {'No history': 1, 'History': 1},
#     71: {'No history': 1, 'History': 1},
#     72: {'No history': 1},
#     73: {'History': 1},
#     74: {'No history': 1, 'History': 1},
#     75: {'No history': 0, 'History': 1},
#     76: {},
#     77: {'No history': 1, 'History': 0},
#     78: {'No history': 0, 'History': 0},
#     79: {'No history': 0},
#     80: {},
#     81: {},
#     82: {},
#     83: {},
#     84: {},
#     85: {'No history': 0, 'History': 1},
#     86: {},
#     87: {'No history': 0},
#     88: {},
#     89: {},
#     90: {},
#     91: {},
#     92: {'History': 1},
#     93: {'No history': 0},
#     94: {'No history': 1, 'History': 1},
#     95: {'No history': 1},
#     96: {},
#     97: {'No history': 1, 'History': 1},
#     98: {'No history': 0},
#     99: {'History': 1},
#     100: {'No history': 1},
#     101: {'History': 1},
#     102: {'No history': 1, 'History': 1},
#     103: {'No history': 1, 'History': 1},
#     104: {'No history': 1, 'History': 1},
#     105: {'No history': 1, 'History': 1},
#     106: {'No history': 1, 'History': 1},
#     107: {'No history': 1},
#     108: {'No history': 1, 'History': 1},
#     109: {'No history': 0, 'History': 0},
#     110: {},
#     111: {'History': 0},
#     112: {'No history': 0},
#     113: {},
#     114: {},
#     115: {'No history': 0},
#     116: {'No history': 1},
#     117: {},
#     118: {'No history': 1, 'History': 1},
#     119: {},
#     120: {},
#     121: {'History': 0},
#     122: {'No history': 0},
#     123: {'No history': 0, 'History': 0},
#     124: {},
#     125: {'History': 0},
#     126: {},
#     127: {},
#     128: {'No history': 1, 'History': 1},
#     129: {'History': 1},
#     130: {},
#     131: {'History': 0},
#     132: {'History': 1},
#     133: {'No history': 0},
#     134: {},
#     135: {'No history': 0, 'History': 0},
#     136: {'No history': 1, 'History': 1},
#     137: {'No history': 0, 'History': 1},
#     138: {},
#     139: {},
#     140: {'No history': 1, 'History': 1},
#     141: {'No history': 1, 'History': 1},
#     142: {},
#     143: {'No history': 1, 'History': 1},
#     144: {'No history': 1, 'History': 0},
#     145: {'No history': 0, 'History': 0},
#     146: {'No history': 0, 'History': 0},
#     147: {'History': 0},
#     148: {'No history': 1},
#     149: {'No history': 0, 'History': 0},
#     150: {'No history': 0, 'History': 0},
#     151: {'No history': 1, 'History': 0},
#     152: {'No history': 1, 'History': 1},
#     153: {'History': 0},
#     154: {},
#     155: {'No history': 0, 'History': 0},
#     156: {},
#     157: {'No history': 1, 'History': 1},
#     158: {'No history': 1},
#     159: {},
#     160: {'No history': 0, 'History': 1},
#     161: {'No history': 0, 'History': 1},
#     162: {'No history': 0},
#     163: {'No history': 0, 'History': 0},
#     164: {'No history': 1, 'History': 1},
#     165: {},
#     166: {},
#     167: {},
#     168: {'History': 1},
#     169: {'No history': 1},
#     170: {'History': 1},
#     171: {'No history': 0},
#     172: {'No history': 1, 'History': 1},
#     173: {'No history': 1},
#     174: {'No history': 0, 'History': 0},
#     175: {},
#     176: {'History': 1},
#     177: {'No history': 1},
#     178: {'No history': 1, 'History': 1},
#     179: {'No history': 1, 'History': 1},
#     180: {},
#     181: {},
#     182: {'No history': 1, 'History': 1},
#     183: {'No history': 0, 'History': 0},
#     184: {},
#     185: {'No history': 1},
#     186: {'No history': 0, 'History': 1},
#     187: {'No history': 1, 'History': 1},
#     188: {},
#     189: {'No history': 1, 'History': 1},
#     190: {'No history': 1, 'History': 0},
#     191: {},
#     192: {},
#     193: {},
#     194: {'History': 1},
#     195: {'No history': 0, 'History': 0},
#     196: {'No history': 0},
#     197: {'No history': 1, 'History': 1},
#     198: {'No history': 0, 'History': 1},
#     199: {'No history': 1, 'History': 1},
#     200: {'No history': 1, 'History': 1},
#     201: {'No history': 1},
#     202: {'History': 1},
#     203: {'No history': 1},
#     204: {'No history': 1},
#     205: {'No history': 0, 'History': 0},
#     206: {'History': 1},
#     207: {},
#     208: {},
#     209: {'No history': 0, 'History': 0},
#     210: {'No history': 1, 'History': 0},
#     211: {'History': 1},
#     212: {},
#     213: {},
#     214: {'No history': 0, 'History': 1},
#     215: {},
#     216: {},
#     217: {'No history': 0, 'History': 0},
#     218: {'No history': 0},
#     219: {},
#     220: {'No history': 0},
#     221: {'History': 0},
#     222: {'No history': 1, 'History': 1},
#     223: {},
#     224: {'No history': 0, 'History': 0},
#     225: {},
#     226: {'No history': 0, 'History': 0},
#     227: {'History': 1},
#     228: {'No history': 1, 'History': 0},
#     229: {},
#     230: {},
#     231: {'No history': 1},
#     232: {'No history': 1, 'History': 1},
#     233: {},
#     234: {},
#     235: {},
#     236: {},
#     237: {},
#     238: {},
#     239: {'History': 1},
#     240: {'No history': 0, 'History': 1},
#     241: {'No history': 1, 'History': 1},
#     242: {'No history': 1, 'History': 1},
#     243: {'No history': 1},
#     244: {'No history': 1},
#     245: {'No history': 1},
#     246: {},
#     247: {},
#     248: {'No history': 1, 'History': 1},
#     249: {'No history': 1, 'History': 1},
#     250: {'No history': 1, 'History': 1},
#     251: {'No history': 1, 'History': 1},
#     252: {},
#     253: {'No history': 1, 'History': 0},
#     254: {'No history': 1, 'History': 1},
#     255: {'No history': 1, 'History': 0},
#     256: {'No history': 1, 'History': 1},
#     257: {},
#     258: {'History': 1},
#     259: {'No history': 0, 'History': 0},
#     260: {},
#     261: {'History': 1},
#     262: {'No history': 1, 'History': 1},
#     263: {'No history': 1, 'History': 1},
#     264: {},
#     265: {},
#     266: {'No history': 1, 'History': 1},
#     267: {'No history': 1, 'History': 0},
#     268: {'History': 1},
#     269: {'No history': 1, 'History': 1},
#     270: {'No history': 1, 'History': 1},
#     271: {'No history': 1, 'History': 1},
#     272: {'No history': 0, 'History': 1},
#     273: {'No history': 1, 'History': 1},
#     274: {},
#     275: {},
#     276: {},
#     277: {'History': 0},
#     278: {'History': 0},
#     279: {'No history': 0, 'History': 0},
#     280: {},
#     281: {'No history': 0},
#     282: {'History': 1},
#     283: {'No history': 0, 'History': 0},
#     284: {'No history': 0, 'History': 0},
#     285: {'No history': 1},
#     286: {},
#     287: {},
#     288: {'No history': 1, 'History': 1},
#     289: {'No history': 1},
#     290: {'No history': 0},
#     291: {'No history': 0, 'History': 0},
#     292: {},
#     293: {'No history': 0},
#     294: {'No history': 0, 'History': 1},
#     295: {'No history': 0, 'History': 1},
#     296: {'History': 1},
#     297: {'No history': 0},
#     298: {'No history': 1},
#     299: {'No history': 1, 'History': 1},
#     300: {'History': 0},
#     301: {},
#     302: {'No history': 0, 'History': 1},
#     303: {},
#     304: {},
#     305: {'No history': 1, 'History': 1},
#     306: {'No history': 1, 'History': 0},
#     307: {'No history': 1, 'History': 1},
#     308: {'No history': 1},
#     309: {'History': 1},
#     310: {'No history': 1, 'History': 1},
#     311: {'History': 1},
#     312: {'No history': 0, 'History': 1},
#     313: {'No history': 1},
#     314: {'No history': 1, 'History': 1},
#     315: {'History': 1},
#     316: {'No history': 1},
#     317: {},
#     318: {'No history': 1, 'History': 1},
#     319: {'History': 1},
#     320: {'No history': 1},
#     321: {'No history': 1, 'History': 1},
#     322: {},
#     323: {},
#     324: {},
#     325: {},
#     326: {},
#     327: {'No history': 0},
#     328: {},
#     329: {},
#     330: {},
#     331: {'No history': 0, 'History': 0},
#     332: {},
#     333: {'No history': 0, 'History': 0},
#     334: {},
#     335: {},
#     336: {},
#     337: {},
#     338: {'History': 1},
#     339: {'No history': 1, 'History': 1},
#     340: {'No history': 1, 'History': 1},
#     341: {},
#     342: {},
#     343: {},
#     344: {'No history': 0, 'History': 0},
#     345: {'History': 0},
#     346: {'No history': 0, 'History': 1},
#     347: {'No history': 1, 'History': 1},
#     348: {},
#     349: {},
#     350: {},
#     351: {'No history': 1},
#     352: {'No history': 0, 'History': 0},
#     353: {'History': 0},
#     354: {},
#     355: {'No history': 1, 'History': 1},
#     356: {'History': 0},
#     357: {},
#     358: {},
#     359: {'No history': 0, 'History': 0},
#     360: {},
#     361: {},
#     362: {'No history': 0},
#     363: {},
#     364: {'History': 1},
#     365: {},
#     366: {},
#     367: {},
#     368: {},
#     369: {'No history': 1, 'History': 1},
#     370: {},
#     371: {'No history': 1, 'History': 1},
#     372: {'No history': 1},
#     373: {'No history': 1},
#     374: {},
#     375: {'No history': 1, 'History': 1},
#     376: {'No history': 0, 'History': 0},
#     377: {},
#     378: {},
#     379: {},
#     380: {},
#     381: {'No history': 1, 'History': 1},
#     382: {},
#     383: {},
#     384: {'No history': 1, 'History': 1},
#     385: {},
#     386: {},
#     387: {},
#     388: {},
#     389: {},
#     390: {'History': 0},
#     391: {},
#     392: {'No history': 1, 'History': 1},
#     393: {'No history': 0, 'History': 0},
#     394: {},
#     395: {'No history': 0, 'History': 0},
#     396: {},
#     397: {},
#     398: {'No history': 0, 'History': 0},
#     399: {'No history': 1, 'History': 1},
#     400: {},
#     401: {},
#     402: {'No history': 0},
#     403: {},
#     404: {},
#     405: {},
#     406: {},
#     407: {'No history': 1, 'History': 1},
#     408: {},
#     409: {'History': 1},
#     410: {},
#     411: {},
#     412: {},
#     413: {'No history': 0, 'History': 0},
#     414: {},
#     415: {},
#     416: {},
#     417: {},
#     418: {'No history': 0, 'History': 0},
#     419: {'No history': 1, 'History': 1},
#     420: {},
#     421: {},
#     422: {},
#     423: {'No history': 1},
#     424: {},
#     425: {},
#     426: {},
#     427: {},
#     428: {'No history': 0, 'History': 0},
#     429: {'No history': 1, 'History': 0},
#     430: {'No history': 1},
#     431: {},
#     432: {},
#     433: {'No history': 0, 'History': 0},
#     434: {},
#     435: {'History': 1},
#     436: {'No history': 0, 'History': 0},
#     437: {},
#     438: {'No history': 1, 'History': 1},
#     439: {'No history': 1, 'History': 1},
#     440: {},
#     441: {},
#     442: {},
#     443: {'No history': 0, 'History': 0},
#     444: {'History': 1},
#     445: {'No history': 0, 'History': 0},
#     446: {},
#     447: {},
#     448: {'No history': 1, 'History': 1},
#     449: {'History': 0},
#     450: {},
#     451: {},
#     452: {},
#     453: {'No history': 1},
#     454: {'No history': 1},
#     455: {},
#     456: {},
#     457: {},
#     458: {},
#     459: {},
#     460: {},
#     461: {'No history': 0, 'History': 0},
#     462: {},
#     463: {},
#     464: {},
#     465: {'No history': 1, 'History': 1},
#     466: {'No history': 1, 'History': 1},
#     467: {'No history': 1},
#     468: {'History': 0},
#     469: {'No history': 1, 'History': 1},
#     470: {'History': 1},
#     471: {'No history': 1},
#     472: {},
#     473: {'No history': 1, 'History': 1},
#     474: {'No history': 1, 'History': 1},
#     475: {},
#     476: {},
#     477: {},
#     478: {'No history': 1, 'History': 1},
#     479: {},
#     480: {'No history': 1, 'History': 1},
#     481: {'History': 1},
#     482: {},
#     483: {},
#     484: {},
#     485: {'No history': 1, 'History': 1},
#     486: {'No history': 1, 'History': 0},
#     487: {},
#     488: {},
#     489: {'No history': 1, 'History': 1},
#     490: {},
#     491: {},
#     492: {},
#     493: {},
#     494: {},
#     495: {},
#     496: {},
#     497: {'History': 1},
#     498: {},
#     499: {'No history': 0, 'History': 1},
#     500: {},
#     501: {'No history': 0, 'History': 0},
#     502: {'No history': 0, 'History': 0},
#     503: {'No history': 0, 'History': 0},
#     504: {},
#     505: {'No history': 1, 'History': 1},
#     506: {},
#     507: {'No history': 1, 'History': 1},
#     508: {'No history': 0, 'History': 0},
#     509: {'No history': 1, 'History': 1},
#     510: {},
#     511: {'History': 0},
#     512: {},
#     513: {},
#     514: {},
#     515: {'No history': 0},
#     516: {},
#     517: {},
#     518: {'No history': 1},
#     519: {'No history': 0},
#     520: {'History': 0},
#     521: {},
#     522: {'No history': 0, 'History': 0},
#     523: {},
#     524: {},
#     525: {},
#     526: {},
#     527: {},
#     528: {},
#     529: {},
#     530: {},
#     531: {},
#     532: {},
#     533: {},
#     534: {},
#     535: {},
#     536: {},
#     537: {},
#     538: {'No history': 1},
#     539: {},
#     540: {},
#     541: {},
#     542: {},
#     543: {'No history': 0, 'History': 0},
#     544: {},
#     545: {'History': 0},
#     546: {},
#     547: {},
#     548: {'History': 1},
#     549: {'No history': 1, 'History': 1},
#     550: {},
#     551: {},
#     552: {},
#     553: {},
#     554: {'No history': 1},
#     555: {'No history': 1},
#     556: {},
#     557: {},
#     558: {},
#     559: {'No history': 0, 'History': 0},
#     560: {},
#     561: {'No history': 0},
#     562: {},
#     563: {'No history': 1, 'History': 1},
#     564: {'No history': 0, 'History': 0},
#     565: {'No history': 0, 'History': 1},
#     566: {},
#     567: {},
#     568: {},
#     569: {},
#     570: {},
#     571: {},
#     572: {'History': 0},
#     573: {},
#     574: {},
#     575: {'No history': 1, 'History': 1},
#     576: {'No history': 1, 'History': 1},
#     577: {'History': 1},
#     578: {},
#     579: {},
#     580: {},
#     581: {},
#     582: {},
#     583: {},
#     584: {},
#     585: {},
#     586: {},
#     587: {'No history': 0, 'History': 0},
#     588: {},
#     589: {'No history': 1},
#     590: {},
#     591: {'History': 0},
#     592: {},
#     593: {'No history': 1},
#     594: {},
#     595: {},
#     596: {'History': 1},
#     597: {'History': 1},
#     598: {},
#     599: {},
#     600: {},
#     601: {},
#     602: {},
#     603: {'No history': 1, 'History': 1},
#     604: {'No history': 0, 'History': 0},
#     605: {'History': 1},
#     606: {},
#     607: {'No history': 0, 'History': 0},
#     608: {},
#     609: {'History': 0},
#     610: {},
#     611: {},
#     612: {'History': 1},
#     613: {},
#     614: {'No history': 1, 'History': 1},
#     615: {},
#     616: {},
#     617: {'No history': 1, 'History': 0},
#     618: {},
#     619: {'No history': 1, 'History': 1},
#     620: {},
#     621: {'History': 0},
#     622: {'History': 0},
#     623: {'No history': 1, 'History': 1},
#     624: {'No history': 1, 'History': 0},
#     625: {'No history': 1, 'History': 1},
#     626: {},
#     627: {'No history': 1, 'History': 1},
#     628: {},
#     629: {'History': 1},
#     630: {'No history': 1, 'History': 1},
#     631: {},
#     632: {'No history': 1},
#     633: {'No history': 0, 'History': 0},
#     634: {'No history': 1},
#     635: {},
#     636: {'No history': 1},
#     637: {},
#     638: {},
#     639: {},
#     640: {'No history': 1, 'History': 1},
#     641: {'No history': 1, 'History': 1},
#     642: {},
#     643: {'No history': 0, 'History': 1},
#     644: {},
#     645: {},
#     646: {},
#     647: {'No history': 1, 'History': 1},
#     648: {},
#     649: {'History': 0},
#     650: {},
#     651: {},
#     652: {},
#     653: {},
#     654: {},
#     655: {},
#     656: {},
#     657: {'No history': 0, 'History': 0},
#     658: {},
#     659: {'No history': 1, 'History': 1},
#     660: {},
#     661: {'No history': 1, 'History': 1},
#     662: {},
#     663: {},
#     664: {'History': 1},
#     665: {},
#     666: {'No history': 1},
#     667: {},
#     668: {},
#     669: {'No history': 1},
#     670: {},
#     671: {},
#     672: {},
#     673: {},
#     674: {'No history': 0, 'History': 1},
#     675: {},
#     676: {'No history': 0, 'History': 0},
#     677: {},
#     678: {'No history': 1},
#     679: {'History': 0},
#     680: {},
#     681: {'No history': 0, 'History': 0},
#     682: {'No history': 1, 'History': 1},
#     683: {},
#     684: {'No history': 1, 'History': 1},
#     685: {},
#     686: {'No history': 0},
#     687: {},
#     688: {},
#     689: {'No history': 1, 'History': 1},
#     690: {},
#     691: {},
#     692: {},
#     693: {},
#     694: {},
#     695: {'No history': 1},
#     696: {'No history': 1, 'History': 1},
#     697: {},
#     698: {},
#     699: {'No history': 0, 'History': 0},
#     700: {'No history': 1, 'History': 1},
#     701: {},
#     702: {},
#     703: {'No history': 1},
#     704: {'No history': 0},
#     705: {'No history': 1},
#     706: {'No history': 0, 'History': 0},
#     707: {'No history': 1, 'History': 1},
#     708: {},
#     709: {},
#     710: {'No history': 0},
#     711: {},
#     712: {'No history': 1, 'History': 1},
#     713: {},
#     714: {'No history': 0},
#     715: {'No history': 1, 'History': 0},
#     716: {'No history': 0, 'History': 1},
#     717: {},
#     718: {},
#     719: {'History': 1},
#     720: {'History': 1},
#     721: {'History': 0},
#     722: {},
#     723: {},
#     724: {},
#     725: {'History': 0},
#     726: {'History': 0},
#     727: {'History': 0},
#     728: {'No history': 1, 'History': 0},
#     729: {'No history': 0, 'History': 0},
#     730: {},
#     731: {'No history': 0, 'History': 0},
#     732: {'No history': 1, 'History': 1},
#     733: {},
#     734: {},
#     735: {'No history': 1},
#     736: {'No history': 1},
#     737: {},
#     738: {'No history': 1},
#     739: {},
#     740: {},
#     741: {},
#     742: {},
#     743: {'No history': 1, 'History': 0},
#     744: {},
#     745: {},
#     746: {'No history': 1, 'History': 1},
#     747: {},
#     748: {'No history': 1},
#     749: {'No history': 0, 'History': 0},
#     750: {'No history': 1, 'History': 0},
#     751: {},
#     752: {'No history': 1, 'History': 1},
#     753: {},
#     754: {},
#     755: {'History': 0},
#     756: {},
#     757: {'No history': 1, 'History': 1},
#     758: {'No history': 1, 'History': 1},
#     759: {'No history': 0, 'History': 0},
#     760: {},
#     761: {'No history': 1},
#     762: {},
#     763: {'No history': 1, 'History': 1},
#     764: {'History': 0},
#     765: {},
#     766: {},
#     767: {},
#     768: {},
#     769: {},
#     770: {'No history': 0, 'History': 1},
#     771: {},
#     772: {},
#     773: {'History': 1},
#     774: {'No history': 1, 'History': 1},
#     775: {'No history': 1, 'History': 0},
#     776: {'No history': 1},
#     777: {},
#     778: {'No history': 1, 'History': 1},
#     779: {'No history': 1, 'History': 1},
#     780: {'No history': 1, 'History': 1},
#     781: {'No history': 1, 'History': 1},
#     782: {'No history': 1, 'History': 1},
#     783: {'No history': 1, 'History': 1},
#     784: {'No history': 1, 'History': 1},
#     785: {'No history': 1, 'History': 1},
#     786: {'No history': 1, 'History': 1},
#     787: {'No history': 1, 'History': 1},
#     788: {'No history': 0, 'History': 0},
#     789: {'History': 1},
#     790: {},
#     791: {'History': 1},
#     792: {'No history': 1, 'History': 1},
#     793: {'No history': 0, 'History': 0},
#     794: {'No history': 1},
#     795: {'No history': 0, 'History': 1},
#     796: {},
#     797: {},
#     798: {},
#     799: {'No history': 0, 'History': 0},
#     800: {'No history': 1},
#     801: {},
#     802: {'No history': 1},
#     803: {},
#     804: {},
#     805: {'No history': 1, 'History': 1},
#     806: {'No history': 1},
#     807: {},
#     808: {'No history': 1},
#     809: {'No history': 1, 'History': 0},
#     810: {'No history': 0, 'History': 1},
#     811: {},
#     812: {'No history': 1, 'History': 1},
#     813: {},
#     814: {},
#     815: {},
#     816: {},
#     817: {},
#     818: {'No history': 0, 'History': 1},
#     819: {},
#     820: {'History': 0},
#     821: {'No history': 1, 'History': 1},
#     822: {'No history': 0},
#     823: {},
#     824: {'No history': 1, 'History': 1},
#     825: {},
#     826: {'History': 1},
#     827: {},
#     828: {'No history': 1},
#     829: {'No history': 1, 'History': 1},
#     830: {'History': 0},
#     831: {},
#     832: {},
#     833: {'No history': 0, 'History': 0},
#     834: {'History': 1},
#     835: {},
#     836: {},
#     837: {},
#     838: {'No history': 1},
#     839: {'No history': 0},
#     840: {},
#     841: {},
#     842: {},
#     843: {'No history': 0},
#     844: {},
#     845: {},
#     846: {'No history': 1, 'History': 1},
#     847: {},
#     848: {'No history': 1},
#     849: {},
#     850: {},
#     851: {},
#     852: {'No history': 1, 'History': 1},
#     853: {'History': 1},
#     854: {},
#     855: {},
#     856: {},
#     857: {'No history': 1, 'History': 1},
#     858: {},
#     859: {'No history': 0, 'History': 0},
#     860: {},
#     861: {'History': 0},
#     862: {'History': 0},
#     863: {},
#     864: {},
#     865: {'No history': 0, 'History': 1},
#     866: {},
#     867: {},
#     868: {'No history': 1, 'History': 1},
#     869: {'History': 1},
#     870: {},
#     871: {},
#     872: {},
#     873: {'No history': 0, 'History': 0},
#     874: {'History': 0},
#     875: {'No history': 1, 'History': 1},
#     876: {'No history': 0, 'History': 1},
#     877: {'No history': 1, 'History': 0},
#     878: {'No history': 1},
#     879: {'No history': 1, 'History': 1},
#     880: {},
#     881: {'No history': 1, 'History': 1},
#     882: {},
#     883: {},
#     884: {},
#     885: {},
#     886: {'History': 1},
#     887: {'No history': 1, 'History': 1},
#     888: {},
#     889: {},
#     890: {'No history': 1},
#     891: {},
#     892: {'History': 1},
#     893: {'No history': 0, 'History': 1},
#     894: {'No history': 0, 'History': 0},
#     895: {},
#     896: {'No history': 1, 'History': 0},
#     897: {},
#     898: {'No history': 0, 'History': 0},
#     899: {'No history': 1, 'History': 1},
#     900: {'No history': 1, 'History': 1},
#     901: {},
#     902: {'No history': 0},
#     903: {},
#     904: {},
#     905: {'No history': 1},
#     906: {'No history': 0, 'History': 0},
#     907: {},
#     908: {'No history': 0, 'History': 1},
#     909: {},
#     910: {'No history': 0, 'History': 1},
#     911: {},
#     912: {'No history': 1, 'History': 1},
#     913: {'History': 0},
#     914: {'No history': 0, 'History': 0},
#     915: {},
#     916: {'No history': 0, 'History': 0},
#     917: {'No history': 1},
#     918: {'No history': 1},
#     919: {'No history': 0, 'History': 0},
#     920: {},
#     921: {'No history': 1, 'History': 1},
#     922: {'No history': 1, 'History': 1},
#     923: {},
#     924: {'History': 1},
#     925: {'No history': 0},
#     926: {'History': 1},
#     927: {'No history': 1},
#     928: {},
#     929: {'No history': 0, 'History': 1},
#     930: {'No history': 1, 'History': 1},
#     931: {},
#     932: {'History': 0},
#     933: {'No history': 0},
#     934: {},
#     935: {},
#     936: {'No history': 1, 'History': 1},
#     937: {},
#     938: {},
#     939: {'No history': 1, 'History': 0},
#     940: {},
#     941: {'No history': 1, 'History': 1},
#     942: {},
#     943: {},
#     944: {'No history': 0, 'History': 0},
#     945: {},
#     946: {},
#     947: {},
#     948: {},
#     949: {'History': 1},
#     950: {'No history': 0, 'History': 0},
#     951: {'No history': 1, 'History': 0},
#     952: {},
#     953: {'No history': 0, 'History': 0},
#     954: {},
#     955: {'No history': 0, 'History': 0},
#     956: {'No history': 1, 'History': 1},
#     957: {'No history': 1, 'History': 1},
#     958: {},
#     959: {'No history': 0, 'History': 0},
#     960: {'No history': 1, 'History': 1},
#     961: {'History': 1},
#     962: {'No history': 1},
#     963: {'No history': 1, 'History': 1},
#     964: {'No history': 1, 'History': 1},
#     965: {'No history': 0},
#     966: {'No history': 1, 'History': 0},
#     967: {},
#     968: {'No history': 1},
#     969: {},
#     970: {},
#     971: {'No history': 1, 'History': 1},
#     972: {},
#     973: {},
#     974: {},
#     975: {'No history': 1, 'History': 1},
#     976: {},
#     977: {'No history': 1},
#     978: {},
#     979: {},
#     980: {},
#     981: {},
#     982: {},
#     983: {'No history': 0},
#     984: {'No history': 0},
#     985: {'No history': 0, 'History': 0},
#     986: {'No history': 1},
#     987: {},
#     988: {'History': 1},
#     989: {'No history': 1, 'History': 1},
#     990: {},
#     991: {},
#     992: {'No history': 1, 'History': 1},
#     993: {},
#     994: {'No history': 1, 'History': 1},
#     995: {'History': 1},
#     996: {},
#     997: {},
#     998: {},
#     999: {'No history': 0},
#     ...},
#    {0: {'No history': 0, 'History': 0},
#     1: {'No history': 1, 'History': 0},
#     2: {},
#     3: {},
#     4: {'History': 1},
#     5: {},
#     6: {'No history': 1, 'History': 1},
#     7: {'No history': 0, 'History': 0},
#     8: {},
#     9: {'No history': 0},
#     10: {},
#     11: {'No history': 1, 'History': 1},
#     12: {'No history': 1, 'History': 1},
#     13: {'No history': 1, 'History': 1},
#     14: {'No history': 0},
#     15: {'No history': 0, 'History': 1},
#     16: {'No history': 1, 'History': 1},
#     17: {'No history': 1, 'History': 1},
#     18: {'No history': 1, 'History': 1},
#     19: {'No history': 1},
#     20: {'No history': 0, 'History': 0},
#     21: {'No history': 0, 'History': 0},
#     22: {},
#     23: {'No history': 1, 'History': 1},
#     24: {},
#     25: {'No history': 1},
#     26: {'No history': 1, 'History': 1},
#     27: {},
#     28: {},
#     29: {'No history': 0, 'History': 0},
#     30: {'History': 1},
#     31: {'No history': 1, 'History': 1},
#     32: {},
#     33: {'No history': 0},
#     34: {},
#     35: {'No history': 0, 'History': 0},
#     36: {'History': 1},
#     37: {},
#     38: {'No history': 0, 'History': 1},
#     39: {'No history': 1, 'History': 1},
#     40: {'No history': 1, 'History': 0},
#     41: {'History': 1},
#     42: {'No history': 1, 'History': 1},
#     43: {'No history': 1, 'History': 1},
#     44: {'No history': 0, 'History': 0},
#     45: {'No history': 1, 'History': 0},
#     46: {'No history': 0, 'History': 0},
#     47: {'No history': 0, 'History': 0},
#     48: {'No history': 1, 'History': 1},
#     49: {'No history': 1, 'History': 1},
#     50: {'No history': 1, 'History': 1},
#     51: {},
#     52: {},
#     53: {},
#     54: {'No history': 0, 'History': 1},
#     55: {},
#     56: {'History': 1},
#     57: {},
#     58: {'No history': 1, 'History': 1},
#     59: {'No history': 1, 'History': 1},
#     60: {},
#     61: {'History': 0},
#     62: {},
#     63: {},
#     64: {'No history': 1, 'History': 1},
#     65: {'No history': 0, 'History': 0},
#     66: {'History': 0},
#     67: {},
#     68: {},
#     69: {},
#     70: {'No history': 1, 'History': 1},
#     71: {'No history': 1, 'History': 1},
#     72: {'No history': 1},
#     73: {'History': 1},
#     74: {'History': 1},
#     75: {'No history': 1, 'History': 1},
#     76: {},
#     77: {'History': 1},
#     78: {'No history': 0, 'History': 0},
#     79: {'No history': 0},
#     80: {},
#     81: {},
#     82: {},
#     83: {},
#     84: {},
#     85: {'No history': 0, 'History': 1},
#     86: {},
#     87: {'No history': 1, 'History': 0},
#     88: {},
#     89: {},
#     90: {},
#     91: {},
#     92: {'History': 1},
#     93: {'No history': 1, 'History': 1},
#     94: {'No history': 0, 'History': 0},
#     95: {'No history': 1},
#     96: {'No history': 1},
#     97: {'No history': 1, 'History': 1},
#     98: {'No history': 1, 'History': 1},
#     99: {'History': 1},
#     100: {'No history': 0, 'History': 0},
#     101: {'History': 1},
#     102: {'No history': 0},
#     103: {'No history': 1, 'History': 1},
#     104: {'No history': 1, 'History': 1},
#     105: {'No history': 1, 'History': 1},
#     106: {'No history': 1, 'History': 1},
#     107: {'No history': 1, 'History': 1},
#     108: {'No history': 1, 'History': 1},
#     109: {'No history': 0, 'History': 0},
#     110: {'No history': 1},
#     111: {'History': 0},
#     112: {'No history': 0},
#     113: {},
#     114: {},
#     115: {'No history': 0, 'History': 0},
#     116: {'No history': 1, 'History': 1},
#     117: {},
#     118: {'History': 1},
#     119: {},
#     120: {'History': 1},
#     121: {'No history': 1},
#     122: {},
#     123: {'No history': 0, 'History': 1},
#     124: {},
#     125: {},
#     126: {},
#     127: {},
#     128: {'No history': 1, 'History': 1},
#     129: {'History': 1},
#     130: {},
#     131: {'History': 0},
#     132: {'History': 1},
#     133: {'No history': 1},
#     134: {},
#     135: {'No history': 1, 'History': 0},
#     136: {'No history': 1, 'History': 1},
#     137: {'No history': 0, 'History': 0},
#     138: {},
#     139: {},
#     140: {'No history': 1, 'History': 1},
#     141: {'No history': 1, 'History': 1},
#     142: {},
#     143: {},
#     144: {'No history': 1, 'History': 0},
#     145: {},
#     146: {'No history': 1, 'History': 0},
#     147: {'No history': 0, 'History': 0},
#     148: {'No history': 1},
#     149: {'No history': 0, 'History': 0},
#     150: {'No history': 1, 'History': 1},
#     151: {'No history': 0, 'History': 0},
#     152: {'No history': 1, 'History': 0},
#     153: {'No history': 0, 'History': 0},
#     154: {},
#     155: {'No history': 0, 'History': 0},
#     156: {},
#     157: {'No history': 1, 'History': 1},
#     158: {'No history': 1, 'History': 1},
#     159: {},
#     160: {'No history': 0, 'History': 1},
#     161: {'No history': 0, 'History': 1},
#     162: {},
#     163: {'No history': 1, 'History': 1},
#     164: {'History': 1},
#     165: {},
#     166: {},
#     167: {},
#     168: {'No history': 0, 'History': 1},
#     169: {'No history': 1, 'History': 1},
#     170: {'No history': 1, 'History': 1},
#     171: {'No history': 0},
#     172: {'No history': 1, 'History': 1},
#     173: {'No history': 1, 'History': 1},
#     174: {'No history': 0, 'History': 1},
#     175: {'No history': 1, 'History': 1},
#     176: {},
#     177: {'No history': 1, 'History': 1},
#     178: {'No history': 1, 'History': 1},
#     179: {'No history': 1, 'History': 1},
#     180: {},
#     181: {},
#     182: {'No history': 1, 'History': 1},
#     183: {'No history': 1, 'History': 1},
#     184: {},
#     185: {'No history': 1},
#     186: {'No history': 0, 'History': 1},
#     187: {'No history': 0, 'History': 0},
#     188: {},
#     189: {'No history': 1, 'History': 1},
#     190: {'No history': 1, 'History': 1},
#     191: {},
#     192: {},
#     193: {'No history': 1, 'History': 1},
#     194: {'History': 1},
#     195: {'No history': 1, 'History': 0},
#     196: {'No history': 0},
#     197: {'No history': 1, 'History': 1},
#     198: {'History': 0},
#     199: {'No history': 0, 'History': 0},
#     200: {'No history': 0, 'History': 1},
#     201: {'No history': 1, 'History': 1},
#     202: {'No history': 0},
#     203: {'No history': 1},
#     204: {'No history': 0},
#     205: {'No history': 0, 'History': 0},
#     206: {},
#     207: {},
#     208: {},
#     209: {'History': 0},
#     210: {'No history': 1, 'History': 0},
#     211: {'No history': 1},
#     212: {},
#     213: {},
#     214: {'No history': 0, 'History': 0},
#     215: {},
#     216: {},
#     217: {'No history': 0, 'History': 0},
#     218: {'No history': 0},
#     219: {},
#     220: {'No history': 0, 'History': 0},
#     221: {},
#     222: {'No history': 0},
#     223: {},
#     224: {},
#     225: {},
#     226: {'No history': 0, 'History': 0},
#     227: {'History': 1},
#     228: {'No history': 1},
#     229: {},
#     230: {},
#     231: {'No history': 1, 'History': 1},
#     232: {'No history': 1, 'History': 1},
#     233: {},
#     234: {},
#     235: {},
#     236: {},
#     237: {},
#     238: {},
#     239: {'No history': 1, 'History': 1},
#     240: {'No history': 0, 'History': 0},
#     241: {'No history': 0, 'History': 0},
#     242: {'No history': 1, 'History': 1},
#     243: {},
#     244: {'No history': 1},
#     245: {'No history': 1, 'History': 1},
#     246: {},
#     247: {},
#     248: {'History': 1},
#     249: {'No history': 1, 'History': 1},
#     250: {'No history': 1, 'History': 1},
#     251: {'No history': 0, 'History': 1},
#     252: {},
#     253: {'No history': 0, 'History': 1},
#     254: {'No history': 1, 'History': 1},
#     255: {'No history': 1, 'History': 0},
#     256: {'No history': 1, 'History': 1},
#     257: {},
#     258: {'No history': 1, 'History': 1},
#     259: {'No history': 1, 'History': 1},
#     260: {},
#     261: {},
#     262: {},
#     263: {'No history': 1, 'History': 1},
#     264: {},
#     265: {},
#     266: {'History': 1},
#     267: {'No history': 1},
#     268: {},
#     269: {'No history': 0, 'History': 0},
#     270: {'History': 1},
#     271: {'No history': 0},
#     272: {'No history': 0},
#     273: {'No history': 0},
#     274: {'History': 1},
#     275: {},
#     276: {},
#     277: {'History': 0},
#     278: {'No history': 0},
#     279: {'No history': 0, 'History': 0},
#     280: {'No history': 0},
#     281: {'History': 0},
#     282: {'History': 1},
#     283: {'No history': 0},
#     284: {'No history': 0, 'History': 0},
#     285: {'No history': 1},
#     286: {},
#     287: {},
#     288: {'No history': 1, 'History': 1},
#     289: {'No history': 1, 'History': 0},
#     290: {'No history': 0},
#     291: {'No history': 1},
#     292: {},
#     293: {'No history': 0},
#     294: {'No history': 0},
#     295: {'No history': 0, 'History': 1},
#     296: {'History': 1},
#     297: {'No history': 0, 'History': 0},
#     298: {'No history': 0},
#     299: {'No history': 0},
#     300: {'No history': 0, 'History': 0},
#     301: {'History': 1},
#     302: {'History': 1},
#     303: {'No history': 1, 'History': 0},
#     304: {},
#     305: {'No history': 1, 'History': 1},
#     306: {'No history': 0, 'History': 0},
#     307: {'No history': 1, 'History': 1},
#     308: {'No history': 1},
#     309: {'History': 1},
#     310: {'No history': 1, 'History': 1},
#     311: {'No history': 1, 'History': 1},
#     312: {},
#     313: {'History': 1},
#     314: {},
#     315: {'History': 1},
#     316: {'No history': 1, 'History': 1},
#     317: {'No history': 0},
#     318: {'History': 1},
#     319: {'No history': 0},
#     320: {'No history': 1, 'History': 1},
#     321: {'No history': 1, 'History': 1},
#     322: {},
#     323: {},
#     324: {},
#     325: {},
#     326: {},
#     327: {'No history': 0, 'History': 0},
#     328: {},
#     329: {},
#     330: {},
#     331: {'No history': 0},
#     332: {},
#     333: {},
#     334: {},
#     335: {},
#     336: {},
#     337: {},
#     338: {'No history': 0},
#     339: {'No history': 1, 'History': 0},
#     340: {'No history': 1},
#     341: {},
#     342: {'No history': 0, 'History': 0},
#     343: {},
#     344: {'No history': 1},
#     345: {'No history': 1, 'History': 0},
#     346: {'No history': 0, 'History': 1},
#     347: {'No history': 1, 'History': 1},
#     348: {},
#     349: {},
#     350: {},
#     351: {},
#     352: {},
#     353: {'No history': 1, 'History': 1},
#     354: {},
#     355: {'No history': 1, 'History': 1},
#     356: {'History': 1},
#     357: {'No history': 1},
#     358: {},
#     359: {'No history': 0, 'History': 0},
#     360: {},
#     361: {'History': 1},
#     362: {'No history': 0},
#     363: {},
#     364: {},
#     365: {},
#     366: {'No history': 1},
#     367: {'No history': 1},
#     368: {'No history': 0},
#     369: {'No history': 1, 'History': 1},
#     370: {},
#     371: {'No history': 1, 'History': 1},
#     372: {'No history': 1},
#     373: {'No history': 1},
#     374: {},
#     375: {'No history': 1},
#     376: {},
#     377: {},
#     378: {},
#     379: {},
#     380: {},
#     381: {'No history': 1, 'History': 1},
#     382: {'No history': 1, 'History': 1},
#     383: {},
#     384: {'No history': 1, 'History': 1},
#     385: {},
#     386: {},
#     387: {},
#     388: {},
#     389: {},
#     390: {'No history': 0, 'History': 0},
#     391: {},
#     392: {'No history': 1, 'History': 1},
#     393: {'No history': 0, 'History': 0},
#     394: {},
#     395: {'No history': 0, 'History': 0},
#     396: {},
#     397: {},
#     398: {'No history': 0, 'History': 0},
#     399: {'No history': 1},
#     400: {},
#     401: {'History': 1},
#     402: {},
#     403: {},
#     404: {},
#     405: {'No history': 1},
#     406: {},
#     407: {'No history': 1, 'History': 1},
#     408: {},
#     409: {'History': 1},
#     410: {},
#     411: {},
#     412: {},
#     413: {},
#     414: {},
#     415: {},
#     416: {},
#     417: {},
#     418: {'No history': 0, 'History': 0},
#     419: {'No history': 1, 'History': 1},
#     420: {},
#     421: {'No history': 0},
#     422: {},
#     423: {'No history': 1},
#     424: {},
#     425: {},
#     426: {},
#     427: {},
#     428: {'No history': 0},
#     429: {'No history': 0, 'History': 0},
#     430: {'History': 1},
#     431: {},
#     432: {},
#     433: {},
#     434: {'No history': 0},
#     435: {},
#     436: {},
#     437: {},
#     438: {'No history': 1, 'History': 1},
#     439: {'No history': 1, 'History': 1},
#     440: {},
#     441: {'No history': 0},
#     442: {},
#     443: {'No history': 0, 'History': 0},
#     444: {'No history': 1, 'History': 1},
#     445: {'No history': 0, 'History': 0},
#     446: {},
#     447: {},
#     448: {'No history': 1, 'History': 1},
#     449: {},
#     450: {'No history': 0, 'History': 0},
#     451: {},
#     452: {},
#     453: {'History': 0},
#     454: {'No history': 0},
#     455: {'History': 0},
#     456: {},
#     457: {},
#     458: {},
#     459: {},
#     460: {'No history': 1},
#     461: {'History': 0},
#     462: {},
#     463: {},
#     464: {},
#     465: {'No history': 1, 'History': 1},
#     466: {'No history': 1, 'History': 1},
#     467: {},
#     468: {'No history': 1, 'History': 1},
#     469: {'No history': 1, 'History': 1},
#     470: {'History': 1},
#     471: {'No history': 1},
#     472: {},
#     473: {'No history': 0, 'History': 0},
#     474: {'History': 1},
#     475: {},
#     476: {},
#     477: {},
#     478: {'History': 1},
#     479: {'No history': 1},
#     480: {'No history': 1, 'History': 1},
#     481: {},
#     482: {},
#     483: {},
#     484: {},
#     485: {'No history': 1, 'History': 1},
#     486: {'History': 0},
#     487: {},
#     488: {},
#     489: {'No history': 1, 'History': 1},
#     490: {},
#     491: {},
#     492: {},
#     493: {'No history': 0},
#     494: {'No history': 0},
#     495: {},
#     496: {},
#     497: {'No history': 1},
#     498: {'No history': 0, 'History': 1},
#     499: {'No history': 0},
#     500: {},
#     501: {'History': 0},
#     502: {'No history': 0, 'History': 0},
#     503: {'No history': 1, 'History': 1},
#     504: {'No history': 0, 'History': 0},
#     505: {'No history': 1, 'History': 1},
#     506: {'History': 0},
#     507: {'No history': 1, 'History': 1},
#     508: {'No history': 0, 'History': 0},
#     509: {},
#     510: {},
#     511: {'No history': 0, 'History': 0},
#     512: {},
#     513: {},
#     514: {},
#     515: {'No history': 0},
#     516: {},
#     517: {},
#     518: {},
#     519: {},
#     520: {'History': 0},
#     521: {},
#     522: {'No history': 0},
#     523: {},
#     524: {},
#     525: {},
#     526: {'No history': 0, 'History': 0},
#     527: {},
#     528: {},
#     529: {},
#     530: {},
#     531: {},
#     532: {},
#     533: {},
#     534: {},
#     535: {},
#     536: {},
#     537: {},
#     538: {'No history': 0, 'History': 0},
#     539: {},
#     540: {},
#     541: {},
#     542: {},
#     543: {},
#     544: {},
#     545: {'History': 0},
#     546: {},
#     547: {},
#     548: {'No history': 0},
#     549: {'No history': 1, 'History': 1},
#     550: {},
#     551: {'No history': 1},
#     552: {},
#     553: {},
#     554: {'No history': 1},
#     555: {'No history': 1},
#     556: {},
#     557: {},
#     558: {},
#     559: {'No history': 0, 'History': 0},
#     560: {},
#     561: {},
#     562: {},
#     563: {'No history': 1},
#     564: {'No history': 0, 'History': 0},
#     565: {'No history': 0, 'History': 1},
#     566: {},
#     567: {},
#     568: {'No history': 0},
#     569: {},
#     570: {},
#     571: {},
#     572: {'History': 1},
#     573: {},
#     574: {},
#     575: {'History': 1},
#     576: {'History': 0},
#     577: {'History': 1},
#     578: {'No history': 0},
#     579: {},
#     580: {},
#     581: {},
#     582: {},
#     583: {},
#     584: {},
#     585: {},
#     586: {},
#     587: {'No history': 0, 'History': 0},
#     588: {},
#     589: {'No history': 1},
#     590: {},
#     591: {},
#     592: {},
#     593: {'No history': 1},
#     594: {},
#     595: {},
#     596: {'No history': 1, 'History': 1},
#     597: {'No history': 1},
#     598: {},
#     599: {},
#     600: {},
#     601: {'No history': 0, 'History': 0},
#     602: {},
#     603: {'No history': 1, 'History': 1},
#     604: {'No history': 1, 'History': 0},
#     605: {'History': 0},
#     606: {},
#     607: {'No history': 0, 'History': 0},
#     608: {},
#     609: {'History': 0},
#     610: {},
#     611: {},
#     612: {'History': 1},
#     613: {},
#     614: {'No history': 1, 'History': 1},
#     615: {},
#     616: {},
#     617: {'No history': 1, 'History': 0},
#     618: {'History': 0},
#     619: {'History': 1},
#     620: {},
#     621: {'History': 0},
#     622: {'History': 0},
#     623: {'History': 0},
#     624: {'No history': 1, 'History': 0},
#     625: {'No history': 0, 'History': 1},
#     626: {},
#     627: {'History': 1},
#     628: {},
#     629: {'No history': 1, 'History': 1},
#     630: {'No history': 0, 'History': 0},
#     631: {},
#     632: {'No history': 1},
#     633: {},
#     634: {'No history': 1},
#     635: {},
#     636: {'No history': 1},
#     637: {},
#     638: {},
#     639: {},
#     640: {'No history': 1, 'History': 1},
#     641: {'No history': 0, 'History': 0},
#     642: {},
#     643: {'No history': 1, 'History': 1},
#     644: {},
#     645: {},
#     646: {},
#     647: {'No history': 0, 'History': 1},
#     648: {},
#     649: {'No history': 0, 'History': 0},
#     650: {},
#     651: {},
#     652: {},
#     653: {'No history': 1, 'History': 1},
#     654: {},
#     655: {},
#     656: {},
#     657: {'History': 0},
#     658: {},
#     659: {'No history': 1, 'History': 1},
#     660: {},
#     661: {'No history': 1},
#     662: {'No history': 0},
#     663: {},
#     664: {'History': 1},
#     665: {},
#     666: {},
#     667: {'No history': 0},
#     668: {},
#     669: {'History': 1},
#     670: {},
#     671: {},
#     672: {'History': 1},
#     673: {},
#     674: {'No history': 0, 'History': 1},
#     675: {},
#     676: {'No history': 0, 'History': 0},
#     677: {},
#     678: {'No history': 1, 'History': 1},
#     679: {'No history': 1, 'History': 1},
#     680: {},
#     681: {'No history': 0, 'History': 0},
#     682: {'No history': 1, 'History': 1},
#     683: {},
#     684: {'No history': 1, 'History': 1},
#     685: {},
#     686: {'History': 1},
#     687: {},
#     688: {},
#     689: {'No history': 1, 'History': 1},
#     690: {},
#     691: {},
#     692: {},
#     693: {},
#     694: {},
#     695: {'No history': 1},
#     696: {'No history': 1, 'History': 1},
#     697: {},
#     698: {},
#     699: {'History': 0},
#     700: {'No history': 1, 'History': 1},
#     701: {'No history': 0},
#     702: {},
#     703: {'No history': 1},
#     704: {'No history': 1, 'History': 1},
#     705: {},
#     706: {'No history': 0},
#     707: {'No history': 1, 'History': 1},
#     708: {},
#     709: {},
#     710: {'No history': 0},
#     711: {},
#     712: {'No history': 1},
#     713: {'No history': 1},
#     714: {'No history': 0, 'History': 1},
#     715: {'No history': 1, 'History': 1},
#     716: {},
#     717: {},
#     718: {},
#     719: {'No history': 1, 'History': 1},
#     720: {'No history': 0, 'History': 1},
#     721: {'History': 0},
#     722: {},
#     723: {},
#     724: {'No history': 1, 'History': 1},
#     725: {},
#     726: {'History': 0},
#     727: {},
#     728: {'No history': 1, 'History': 0},
#     729: {'No history': 0, 'History': 1},
#     730: {},
#     731: {'History': 1},
#     732: {'No history': 1, 'History': 1},
#     733: {},
#     734: {'History': 0},
#     735: {'No history': 1},
#     736: {},
#     737: {},
#     738: {'No history': 1},
#     739: {'No history': 1},
#     740: {},
#     741: {'History': 1},
#     742: {},
#     743: {'No history': 1, 'History': 0},
#     744: {},
#     745: {},
#     746: {'No history': 1, 'History': 1},
#     747: {},
#     748: {'No history': 1},
#     749: {'No history': 1, 'History': 1},
#     750: {'No history': 1, 'History': 1},
#     751: {},
#     752: {'No history': 1, 'History': 0},
#     753: {},
#     754: {},
#     755: {},
#     756: {},
#     757: {'No history': 0, 'History': 0},
#     758: {'No history': 1, 'History': 1},
#     759: {'No history': 0, 'History': 0},
#     760: {},
#     761: {'No history': 1},
#     762: {},
#     763: {'No history': 1, 'History': 1},
#     764: {'History': 1},
#     765: {},
#     766: {},
#     767: {},
#     768: {},
#     769: {},
#     770: {'No history': 1, 'History': 1},
#     771: {},
#     772: {},
#     773: {'History': 1},
#     774: {'History': 1},
#     775: {},
#     776: {'No history': 1, 'History': 1},
#     777: {},
#     778: {'No history': 1, 'History': 1},
#     779: {'No history': 1, 'History': 1},
#     780: {'No history': 1, 'History': 1},
#     781: {'No history': 1},
#     782: {'History': 0},
#     783: {'No history': 1, 'History': 1},
#     784: {'No history': 1, 'History': 1},
#     785: {'No history': 1, 'History': 1},
#     786: {'History': 0},
#     787: {'No history': 1, 'History': 0},
#     788: {'No history': 0, 'History': 0},
#     789: {'No history': 1, 'History': 1},
#     790: {},
#     791: {'No history': 1},
#     792: {'No history': 1, 'History': 1},
#     793: {'No history': 0},
#     794: {'No history': 1},
#     795: {'No history': 0, 'History': 0},
#     796: {},
#     797: {},
#     798: {},
#     799: {'No history': 0, 'History': 0},
#     800: {'No history': 1},
#     801: {},
#     802: {'No history': 0, 'History': 0},
#     803: {},
#     804: {},
#     805: {'No history': 1, 'History': 1},
#     806: {'No history': 1, 'History': 1},
# ...
#     323: {},
#     324: {},
#     325: {},
#     326: {},
#     327: {'No history': 0, 'History': 0},
#     328: {},
#     329: {},
#     330: {},
#     331: {'No history': 0},
#     332: {},
#     333: {'No history': 0},
#     334: {},
#     335: {},
#     336: {},
#     337: {},
#     338: {'History': 1},
#     339: {'No history': 1},
#     340: {'History': 1},
#     341: {},
#     342: {'No history': 1},
#     343: {},
#     344: {'No history': 1},
#     345: {'No history': 1},
#     346: {'No history': 1, 'History': 1},
#     347: {'No history': 1, 'History': 1},
#     348: {},
#     349: {},
#     350: {},
#     351: {},
#     352: {},
#     353: {'No history': 1, 'History': 1},
#     354: {},
#     355: {'No history': 1, 'History': 1},
#     356: {'History': 0},
#     357: {'No history': 1, 'History': 1},
#     358: {},
#     359: {'No history': 0, 'History': 0},
#     360: {},
#     361: {'History': 1},
#     362: {'No history': 0},
#     363: {},
#     364: {'History': 1},
#     365: {'No history': 1},
#     366: {},
#     367: {},
#     368: {'No history': 0},
#     369: {'No history': 1, 'History': 1},
#     370: {},
#     371: {'No history': 1, 'History': 1},
#     372: {'No history': 1, 'History': 1},
#     373: {'No history': 1},
#     374: {},
#     375: {'No history': 1, 'History': 1},
#     376: {'History': 1},
#     377: {},
#     378: {},
#     379: {},
#     380: {},
#     381: {'No history': 1, 'History': 1},
#     382: {},
#     383: {},
#     384: {'No history': 1, 'History': 1},
#     385: {},
#     386: {},
#     387: {},
#     388: {},
#     389: {},
#     390: {},
#     391: {},
#     392: {'No history': 1, 'History': 1},
#     393: {'No history': 0, 'History': 0},
#     394: {},
#     395: {'No history': 0, 'History': 0},
#     396: {},
#     397: {},
#     398: {'No history': 1},
#     399: {'No history': 1},
#     400: {},
#     401: {'No history': 1, 'History': 1},
#     402: {'No history': 0},
#     403: {},
#     404: {},
#     405: {},
#     406: {},
#     407: {'No history': 1, 'History': 1},
#     408: {},
#     409: {'History': 1},
#     410: {},
#     411: {},
#     412: {},
#     413: {'No history': 1},
#     414: {},
#     415: {},
#     416: {},
#     417: {},
#     418: {'No history': 0, 'History': 0},
#     419: {'No history': 1, 'History': 1},
#     420: {},
#     421: {'No history': 0, 'History': 1},
#     422: {},
#     423: {},
#     424: {},
#     425: {},
#     426: {},
#     427: {},
#     428: {'No history': 0, 'History': 0},
#     429: {'No history': 1, 'History': 0},
#     430: {'No history': 1, 'History': 1},
#     431: {},
#     432: {},
#     433: {},
#     434: {},
#     435: {'No history': 1},
#     436: {'History': 0},
#     437: {},
#     438: {'No history': 1, 'History': 1},
#     439: {'No history': 1, 'History': 1},
#     440: {},
#     441: {},
#     442: {},
#     443: {'No history': 1, 'History': 1},
#     444: {'No history': 1, 'History': 1},
#     445: {'No history': 0, 'History': 0},
#     446: {},
#     447: {},
#     448: {'No history': 1},
#     449: {},
#     450: {'No history': 1, 'History': 1},
#     451: {},
#     452: {'No history': 1},
#     453: {},
#     454: {'No history': 1},
#     455: {},
#     456: {},
#     457: {},
#     458: {'History': 1},
#     459: {},
#     460: {'No history': 1, 'History': 1},
#     461: {},
#     462: {},
#     463: {},
#     464: {},
#     465: {'No history': 1, 'History': 1},
#     466: {'No history': 1, 'History': 1},
#     467: {'No history': 1},
#     468: {'No history': 1},
#     469: {'No history': 1, 'History': 1},
#     470: {'History': 1},
#     471: {'No history': 1, 'History': 1},
#     472: {},
#     473: {'No history': 1, 'History': 1},
#     474: {'No history': 1, 'History': 1},
#     475: {},
#     476: {'History': 1},
#     477: {},
#     478: {'No history': 1, 'History': 1},
#     479: {'No history': 1},
#     480: {'No history': 1, 'History': 1},
#     481: {'History': 1},
#     482: {'History': 1},
#     483: {},
#     484: {},
#     485: {'No history': 1, 'History': 1},
#     486: {'History': 0},
#     487: {},
#     488: {},
#     489: {'No history': 1},
#     490: {},
#     491: {},
#     492: {'No history': 0},
#     493: {},
#     494: {'No history': 0},
#     495: {},
#     496: {'No history': 0},
#     497: {'History': 1},
#     498: {},
#     499: {'No history': 0},
#     500: {},
#     501: {'History': 1},
#     502: {'No history': 0, 'History': 0},
#     503: {'No history': 1, 'History': 1},
#     504: {'History': 1},
#     505: {'No history': 1, 'History': 1},
#     506: {'History': 0},
#     507: {'No history': 1},
#     508: {'No history': 0, 'History': 0},
#     509: {'No history': 1, 'History': 1},
#     510: {},
#     511: {},
#     512: {},
#     513: {},
#     514: {},
#     515: {'No history': 0},
#     516: {},
#     517: {},
#     518: {'No history': 1},
#     519: {'No history': 0},
#     520: {'History': 0},
#     521: {},
#     522: {},
#     523: {},
#     524: {},
#     525: {},
#     526: {},
#     527: {},
#     528: {},
#     529: {},
#     530: {},
#     531: {},
#     532: {},
#     533: {},
#     534: {},
#     535: {},
#     536: {},
#     537: {},
#     538: {},
#     539: {},
#     540: {},
#     541: {},
#     542: {},
#     543: {'History': 1},
#     544: {},
#     545: {'History': 0},
#     546: {},
#     547: {},
#     548: {},
#     549: {'No history': 1, 'History': 1},
#     550: {},
#     551: {'No history': 1},
#     552: {},
#     553: {},
#     554: {'No history': 1},
#     555: {'No history': 1},
#     556: {},
#     557: {},
#     558: {},
#     559: {'No history': 0, 'History': 1},
#     560: {},
#     561: {},
#     562: {},
#     563: {'No history': 1, 'History': 1},
#     564: {'No history': 0, 'History': 0},
#     565: {'No history': 0, 'History': 1},
#     566: {},
#     567: {},
#     568: {},
#     569: {},
#     570: {},
#     571: {},
#     572: {'History': 0},
#     573: {},
#     574: {},
#     575: {'No history': 1, 'History': 1},
#     576: {'No history': 1, 'History': 1},
#     577: {'History': 1},
#     578: {},
#     579: {},
#     580: {},
#     581: {},
#     582: {},
#     583: {},
#     584: {},
#     585: {},
#     586: {},
#     587: {'No history': 1, 'History': 1},
#     588: {},
#     589: {'No history': 1},
#     590: {},
#     591: {'History': 0},
#     592: {},
#     593: {'No history': 1},
#     594: {},
#     595: {},
#     596: {},
#     597: {'No history': 1, 'History': 1},
#     598: {},
#     599: {},
#     600: {},
#     601: {'No history': 0},
#     602: {},
#     603: {'No history': 1, 'History': 1},
#     604: {'No history': 0},
#     605: {},
#     606: {},
#     607: {'No history': 0, 'History': 0},
#     608: {},
#     609: {},
#     610: {},
#     611: {},
#     612: {'History': 1},
#     613: {},
#     614: {'No history': 1, 'History': 1},
#     615: {},
#     616: {},
#     617: {'No history': 1},
#     618: {},
#     619: {'No history': 1, 'History': 1},
#     620: {},
#     621: {'History': 0},
#     622: {'History': 0},
#     623: {'No history': 1, 'History': 1},
#     624: {'No history': 1, 'History': 0},
#     625: {'No history': 1, 'History': 1},
#     626: {},
#     627: {'No history': 1, 'History': 1},
#     628: {},
#     629: {'History': 1},
#     630: {'No history': 1, 'History': 1},
#     631: {},
#     632: {'No history': 1, 'History': 1},
#     633: {},
#     634: {'No history': 1},
#     635: {},
#     636: {'No history': 1},
#     637: {},
#     638: {},
#     639: {},
#     640: {'No history': 1, 'History': 1},
#     641: {'No history': 1, 'History': 1},
#     642: {},
#     643: {'No history': 1},
#     644: {},
#     645: {},
#     646: {},
#     647: {'No history': 1, 'History': 1},
#     648: {},
#     649: {'No history': 1, 'History': 0},
#     650: {},
#     651: {},
#     652: {},
#     653: {'No history': 1},
#     654: {},
#     655: {},
#     656: {},
#     657: {'History': 0},
#     658: {},
#     659: {'No history': 1, 'History': 1},
#     660: {},
#     661: {'No history': 1},
#     662: {},
#     663: {},
#     664: {'History': 1},
#     665: {},
#     666: {},
#     667: {'History': 0},
#     668: {},
#     669: {},
#     670: {},
#     671: {},
#     672: {},
#     673: {},
#     674: {'No history': 0, 'History': 1},
#     675: {},
#     676: {'No history': 0, 'History': 0},
#     677: {},
#     678: {'No history': 1, 'History': 1},
#     679: {},
#     680: {},
#     681: {'No history': 1, 'History': 1},
#     682: {'History': 1},
#     683: {},
#     684: {'No history': 1, 'History': 1},
#     685: {},
#     686: {'History': 1},
#     687: {},
#     688: {},
#     689: {'No history': 1, 'History': 1},
#     690: {},
#     691: {},
#     692: {},
#     693: {'No history': 0},
#     694: {},
#     695: {'No history': 1},
#     696: {'No history': 1, 'History': 1},
#     697: {},
#     698: {},
#     699: {'No history': 1},
#     700: {'No history': 1, 'History': 1},
#     701: {},
#     702: {},
#     703: {},
#     704: {},
#     705: {'No history': 1},
#     706: {'No history': 0, 'History': 0},
#     707: {'No history': 1, 'History': 1},
#     708: {},
#     709: {},
#     710: {'No history': 0},
#     711: {},
#     712: {'No history': 1, 'History': 1},
#     713: {'History': 1},
#     714: {},
#     715: {'No history': 1, 'History': 1},
#     716: {},
#     717: {},
#     718: {},
#     719: {'History': 1},
#     720: {'No history': 0, 'History': 1},
#     721: {'History': 1},
#     722: {},
#     723: {},
#     724: {'No history': 1, 'History': 1},
#     725: {'No history': 1, 'History': 1},
#     726: {'History': 1},
#     727: {'History': 1},
#     728: {'No history': 1},
#     729: {'No history': 1, 'History': 1},
#     730: {},
#     731: {'History': 1},
#     732: {'No history': 1, 'History': 1},
#     733: {},
#     734: {},
#     735: {'No history': 1},
#     736: {'No history': 1},
#     737: {},
#     738: {'No history': 1, 'History': 1},
#     739: {'No history': 1},
#     740: {},
#     741: {'History': 1},
#     742: {'No history': 0},
#     743: {'No history': 1, 'History': 0},
#     744: {},
#     745: {},
#     746: {'No history': 1, 'History': 1},
#     747: {},
#     748: {'No history': 1, 'History': 1},
#     749: {'No history': 1, 'History': 1},
#     750: {'No history': 1, 'History': 1},
#     751: {},
#     752: {'No history': 1, 'History': 1},
#     753: {},
#     754: {},
#     755: {'No history': 1, 'History': 1},
#     756: {},
#     757: {'No history': 1, 'History': 1},
#     758: {'No history': 1, 'History': 1},
#     759: {'No history': 0, 'History': 0},
#     760: {},
#     761: {'No history': 1},
#     762: {},
#     763: {'No history': 1, 'History': 1},
#     764: {'History': 1},
#     765: {'History': 0},
#     766: {},
#     767: {},
#     768: {},
#     769: {},
#     770: {'No history': 1, 'History': 1},
#     771: {},
#     772: {},
#     773: {'No history': 1, 'History': 1},
#     774: {'No history': 1, 'History': 1},
#     775: {},
#     776: {'No history': 1},
#     777: {},
#     778: {'No history': 1, 'History': 1},
#     779: {'No history': 1, 'History': 1},
#     780: {'No history': 1, 'History': 1},
#     781: {'No history': 1},
#     782: {'No history': 1, 'History': 1},
#     783: {'No history': 1, 'History': 1},
#     784: {'No history': 1, 'History': 1},
#     785: {'No history': 1, 'History': 1},
#     786: {'No history': 1, 'History': 1},
#     787: {'No history': 1, 'History': 1},
#     788: {'No history': 1, 'History': 1},
#     789: {'No history': 1, 'History': 1},
#     790: {},
#     791: {'No history': 1},
#     792: {'No history': 1, 'History': 1},
#     793: {'No history': 0, 'History': 0},
#     794: {'No history': 1, 'History': 1},
#     795: {'No history': 1, 'History': 1},
#     796: {},
#     797: {},
#     798: {},
#     799: {'No history': 0, 'History': 0},
#     800: {'No history': 1},
#     801: {},
#     802: {'No history': 1},
#     803: {},
#     804: {},
#     805: {'No history': 1, 'History': 1},
#     806: {'No history': 1, 'History': 1},
#     807: {},
#     808: {'No history': 1, 'History': 1},
#     809: {'No history': 1, 'History': 0},
#     810: {'No history': 0, 'History': 1},
#     811: {},
#     812: {'No history': 1, 'History': 1},
#     813: {},
#     814: {},
#     815: {},
#     816: {},
#     817: {},
#     818: {'No history': 0, 'History': 1},
#     819: {},
#     820: {'History': 1},
#     821: {'No history': 1, 'History': 1},
#     822: {'No history': 0, 'History': 0},
#     823: {},
#     824: {'No history': 1, 'History': 1},
#     825: {},
#     826: {'No history': 1, 'History': 1},
#     827: {},
#     828: {'No history': 1},
#     829: {'No history': 1, 'History': 1},
#     830: {'No history': 1, 'History': 1},
#     831: {},
#     832: {},
#     833: {'No history': 0},
#     834: {'History': 1},
#     835: {},
#     836: {},
#     837: {},
#     838: {'No history': 1, 'History': 1},
#     839: {'No history': 0},
#     840: {},
#     841: {},
#     842: {},
#     843: {'No history': 1},
#     844: {},
#     845: {},
#     846: {'No history': 1, 'History': 1},
#     847: {},
#     848: {'No history': 1},
#     849: {},
#     850: {},
#     851: {},
#     852: {'No history': 1, 'History': 1},
#     853: {},
#     854: {},
#     855: {},
#     856: {},
#     857: {'No history': 1, 'History': 1},
#     858: {},
#     859: {'History': 0},
#     860: {},
#     861: {'No history': 1, 'History': 1},
#     862: {'No history': 1, 'History': 1},
#     863: {},
#     864: {},
#     865: {'No history': 1, 'History': 0},
#     866: {},
#     867: {},
#     868: {'No history': 0, 'History': 1},
#     869: {'History': 1},
#     870: {},
#     871: {},
#     872: {},
#     873: {},
#     874: {},
#     875: {'No history': 1},
#     876: {'No history': 0, 'History': 1},
#     877: {'No history': 1},
#     878: {'No history': 1, 'History': 1},
#     879: {'No history': 1, 'History': 1},
#     880: {},
#     881: {'No history': 1, 'History': 1},
#     882: {'No history': 1},
#     883: {},
#     884: {'History': 1},
#     885: {},
#     886: {'No history': 1, 'History': 1},
#     887: {'No history': 1, 'History': 1},
#     888: {},
#     889: {},
#     890: {'No history': 1},
#     891: {},
#     892: {'History': 1},
#     893: {'No history': 0, 'History': 0},
#     894: {'No history': 0, 'History': 0},
#     895: {'No history': 1},
#     896: {'No history': 1, 'History': 1},
#     897: {},
#     898: {'No history': 0, 'History': 0},
#     899: {'No history': 1, 'History': 1},
#     900: {'No history': 1, 'History': 1},
#     901: {},
#     902: {'History': 1},
#     903: {},
#     904: {},
#     905: {'No history': 1},
#     906: {'History': 0},
#     907: {},
#     908: {'No history': 1, 'History': 1},
#     909: {},
#     910: {'No history': 0},
#     911: {},
#     912: {'No history': 1, 'History': 1},
#     913: {'History': 1},
#     914: {'No history': 0, 'History': 0},
#     915: {},
#     916: {'No history': 0},
#     917: {'No history': 1},
#     918: {},
#     919: {'No history': 0},
#     920: {'History': 1},
#     921: {'No history': 1, 'History': 1},
#     922: {'No history': 1, 'History': 1},
#     923: {},
#     924: {'History': 1},
#     925: {},
#     926: {},
#     927: {},
#     928: {},
#     929: {'No history': 0, 'History': 1},
#     930: {'No history': 1, 'History': 1},
#     931: {},
#     932: {},
#     933: {'No history': 1},
#     934: {},
#     935: {},
#     936: {'No history': 1, 'History': 1},
#     937: {},
#     938: {},
#     939: {'No history': 1, 'History': 1},
#     940: {},
#     941: {'No history': 1, 'History': 1},
#     942: {},
#     943: {},
#     944: {'No history': 1, 'History': 0},
#     945: {},
#     946: {},
#     947: {},
#     948: {},
#     949: {'History': 1},
#     950: {'No history': 0, 'History': 0},
#     951: {'No history': 1, 'History': 0},
#     952: {'History': 1},
#     953: {'No history': 0},
#     954: {},
#     955: {'No history': 0, 'History': 0},
#     956: {'No history': 1, 'History': 1},
#     957: {'No history': 1, 'History': 1},
#     958: {},
#     959: {'No history': 0, 'History': 0},
#     960: {'No history': 1, 'History': 1},
#     961: {'History': 1},
#     962: {'No history': 1},
#     963: {'No history': 1, 'History': 1},
#     964: {'No history': 1, 'History': 1},
#     965: {'No history': 1},
#     966: {'History': 0},
#     967: {'History': 1},
#     968: {'No history': 1},
#     969: {},
#     970: {'No history': 1},
#     971: {'No history': 1, 'History': 1},
#     972: {},
#     973: {},
#     974: {'No history': 0},
#     975: {'No history': 1, 'History': 1},
#     976: {'No history': 1},
#     977: {'No history': 1, 'History': 1},
#     978: {},
#     979: {},
#     980: {},
#     981: {},
#     982: {},
#     983: {'History': 1},
#     984: {'No history': 0},
#     985: {'No history': 1, 'History': 1},
#     986: {'No history': 1},
#     987: {},
#     988: {'History': 1},
#     989: {'No history': 1, 'History': 1},
#     990: {},
#     991: {},
#     992: {'No history': 1, 'History': 1},
#     993: {},
#     994: {'No history': 1, 'History': 1},
#     995: {'History': 1},
#     996: {},
#     997: {},
#     998: {'No history': 1},
#     999: {},
#     ...}],
#   'changed_seg_ids': [[], [], []]}}

# %%
accs_hist, accs_nohist, lengths = print_accs('pos_tag_noun', print_res=True)
# Out:
# -------------------------
# Experiment: pos_tag_noun
# -------------------------
# History accuracies:
# hT_nhT: mean=0.8315235494315655, std=0.0023116591707591436
# hT_nhF: mean=0.7261812826845699, std=0.0290001510092636
# hF_nhT: mean=0.14428903207781096, std=0.026641228934751793
# hF_nhF: mean=0.08563093300724485, std=0.014880056213418497
# only_h: mean=0.5913959004930277, std=0.011703386411389429
# only_nh: mean=0.47606033442483425, std=0.01796632105488694
# nothing: mean=0.460973517580149, std=0.011748919740860533
# all: mean=0.6375590356589163, std=0.003093686584471045
# h_nh_all: mean=0.7008557290687705, std=0.002031957563361028
#
# No history accuracies:
# hT_nhT: mean=0.8001368925393565, std=0.009549828672806886
# hT_nhF: mean=0.1452758581624561, std=0.01829871869600966
# hF_nhT: mean=0.5884023512317548, std=0.0192176926784259
# hF_nhF: mean=0.06637107420609677, std=0.009552447218358127
# only_h: mean=0.5387970413133681, std=0.03644913960804485
# only_nh: mean=0.6013373462907038, std=0.015281029412988733
# nothing: mean=0.4580518057965668, std=0.008565232646610622
# all: mean=0.6274136509784809, std=0.002011480238043273
# h_nh_all: mean=0.672443175847753, std=0.006737704756982291
#
# Number of items per condition:
# hT_nhT: mean=1702.0, std=0.0
# hT_nhF: mean=112.0, std=0.0
# hF_nhT: mean=121.0, std=0.0
# hF_nhF: mean=248.0, std=0.0
# only_h: mean=681.0, std=0.0
# only_nh: mean=787.0, std=0.0
# nothing: mean=3150.0, std=0.0
# all: mean=6801.0, std=0.0
# h_nh_all: mean=2183.0, std=0.0
# -------------------------

# %% [markdown]
# Load the experiment_names variables with the shuffle, game and image perturbation results

# %%
# POS distribution results
experiment_names = pickle.load(open( "experiment_names_game_img_shuf.p", "rb" ) )
experiment_names
# Out:
# {'standard': {'segments_file': 'data/test_chains.json',
#   'chains_file': 'data/test_segments.json',
#   'split': 'test',
#   'accs_hist': [],
#   'accs_nohist': [],
#   'lengths': [],
#   'dataframe': [],
#   'changed_seg_ids': []},
#  'shuffle': {'segments_file': 'data/test_shuffle_chains.json',
#   'chains_file': 'data/test_shuffle_segments.json',
#   'split': 'test_shuffle',
#   'accs_hist': [{'hT_nhT': 0.9495450785773366,
#     'hT_nhF': 0.9102564102564102,
#     'hF_nhT': 0.313953488372093,
#     'hF_nhF': 0.20588235294117646,
#     'only_h': 0.7477272727272727,
#     'only_nh': 0.796875,
#     'nothing': 0.8132352941176471,
#     'all': 0.8112084063047286,
#     'h_nh_all': 0.830200907323396},
#    {'hT_nhT': 0.9526627218934911,
#     'hT_nhF': 0.8414634146341463,
#     'hF_nhT': 0.3157894736842105,
#     'hF_nhF': 0.25,
#     'only_h': 0.7706013363028953,
#     'only_nh': 0.764102564102564,
#     'nothing': 0.7877094972067039,
#     'all': 0.8097731239092496,
#     'h_nh_all': 0.837873754152824},
#    {'hT_nhT': 0.9585798816568047,
#     'hT_nhF': 0.8333333333333334,
#     'hF_nhT': 0.22857142857142856,
#     'hF_nhF': 0.2155688622754491,
#     'only_h': 0.7699316628701595,
#     'only_nh': 0.7405660377358491,
#     'nothing': 0.8050139275766016,
#     'all': 0.8105557497378539,
#     'h_nh_all': 0.8351206434316354}],
#   'accs_nohist': [{'hT_nhT': 1.0,
#     'hT_nhF': 0.0,
#     'hF_nhT': 1.0,
#     'hF_nhF': 0.0,
#     'only_h': nan,
#     'only_nh': 0.7306226175349428,
#     'nothing': nan,
#     'all': 0.8074074074074075,
#     'h_nh_all': 0.8350893266147503},
#    {'hT_nhT': 1.0,
#     'hT_nhF': 0.0,
#     'hF_nhT': 1.0,
#     'hF_nhF': 0.0,
#     'only_h': nan,
#     'only_nh': 0.7306226175349428,
#     'nothing': nan,
#     'all': 0.8074074074074075,
#     'h_nh_all': 0.8350893266147503},
#    {'hT_nhT': 1.0,
#     'hT_nhF': 0.0,
#     'hF_nhT': 1.0,
#     'hF_nhF': 0.0,
#     'only_h': nan,
#     'only_nh': 0.7306226175349428,
#     'nothing': nan,
#     'all': 0.8074074074074075,
#     'h_nh_all': 0.8350893266147503}],
#   'lengths': [{'hT_nhT': 1702,
#     'hT_nhF': 112,
#     'hF_nhT': 121,
#     'hF_nhF': 248,
#     'only_h': 681,
#     'only_nh': 787,
#     'nothing': 3150,
#     'all': 6801,
#     'h_nh_all': 2183},
#    {'hT_nhT': 1702,
#     'hT_nhF': 112,
#     'hF_nhT': 121,
#     'hF_nhF': 248,
#     'only_h': 681,
#     'only_nh': 787,
#     'nothing': 3150,
#     'all': 6801,
#     'h_nh_all': 2183},
#    {'hT_nhT': 1702,
#     'hT_nhF': 112,
#     'hF_nhT': 121,
#     'hF_nhF': 248,
#     'only_h': 681,
#     'only_nh': 787,
#     'nothing': 3150,
#     'all': 6801,
#     'h_nh_all': 2183}],
#   'dataframe': [{0: {'No history': 0, 'History': 1},
#     1: {'No history': 1, 'History': 1},
#     2: {},
#     3: {'No history': 1},
#     4: {'History': 1},
#     5: {'History': 1},
#     6: {'No history': 1, 'History': 1},
#     7: {'No history': 1},
#     8: {},
#     9: {'History': 0},
#     10: {'History': 1},
#     11: {'No history': 1, 'History': 1},
#     12: {'No history': 1},
#     13: {'No history': 1, 'History': 1},
#     14: {'No history': 1},
#     15: {'No history': 1, 'History': 1},
#     16: {'No history': 1, 'History': 0},
#     17: {'No history': 1, 'History': 0},
#     18: {'No history': 1},
#     19: {'No history': 1},
#     20: {'No history': 1},
#     21: {'No history': 1, 'History': 1},
#     22: {},
#     23: {'No history': 1, 'History': 1},
#     24: {},
#     25: {},
#     26: {'No history': 1, 'History': 1},
#     27: {'History': 1},
#     28: {},
#     29: {'No history': 1, 'History': 1},
#     30: {'History': 1},
#     31: {'No history': 1, 'History': 1},
#     32: {},
#     33: {},
#     34: {},
#     35: {'No history': 1, 'History': 1},
#     36: {'No history': 1, 'History': 1},
#     37: {},
#     38: {},
#     39: {'No history': 1, 'History': 0},
#     40: {'No history': 1, 'History': 1},
#     41: {'No history': 1, 'History': 1},
#     42: {'No history': 1, 'History': 1},
#     43: {'History': 1},
#     44: {'No history': 0, 'History': 1},
#     45: {'No history': 1, 'History': 1},
#     46: {'No history': 1, 'History': 1},
#     47: {'No history': 1, 'History': 1},
#     48: {'No history': 1, 'History': 1},
#     49: {'No history': 1, 'History': 1},
#     50: {'History': 1},
#     51: {},
#     52: {},
#     53: {'History': 1},
#     54: {'No history': 1},
#     55: {},
#     56: {'No history': 1, 'History': 1},
#     57: {},
#     58: {'History': 1},
#     59: {'No history': 1, 'History': 1},
#     60: {},
#     61: {},
#     62: {'History': 1},
#     63: {'No history': 1},
#     64: {'No history': 1, 'History': 1},
#     65: {'No history': 0},
#     66: {},
#     67: {'History': 1},
#     68: {},
#     69: {'History': 1},
#     70: {'No history': 1, 'History': 1},
#     71: {'No history': 1, 'History': 1},
#     72: {},
#     73: {'No history': 1, 'History': 0},
#     74: {'No history': 1},
#     75: {'No history': 1},
#     76: {'History': 1},
#     77: {'No history': 1, 'History': 1},
#     78: {'No history': 0},
#     79: {'No history': 1},
#     80: {},
#     81: {},
#     82: {'History': 0},
#     83: {'History': 1},
#     84: {},
#     85: {},
#     86: {},
#     87: {'No history': 1},
#     88: {},
#     89: {},
#     90: {'History': 1},
#     91: {},
#     92: {'History': 1},
#     93: {'No history': 1, 'History': 1},
#     94: {'No history': 1, 'History': 1},
#     95: {'No history': 1},
#     96: {'No history': 1, 'History': 1},
#     97: {'No history': 1, 'History': 1},
#     98: {'No history': 1, 'History': 1},
#     99: {'History': 1},
#     100: {'No history': 1},
#     101: {'No history': 1, 'History': 1},
#     102: {'No history': 1, 'History': 1},
#     103: {'No history': 1},
#     104: {'No history': 1},
#     105: {'No history': 1, 'History': 1},
#     106: {'No history': 1, 'History': 1},
#     107: {'History': 1},
#     108: {'No history': 1, 'History': 1},
#     109: {'No history': 0},
#     110: {},
#     111: {'No history': 1, 'History': 0},
#     112: {'No history': 0},
#     113: {'History': 1},
#     114: {},
#     115: {'No history': 0},
#     116: {'History': 1},
#     117: {'History': 0},
#     118: {'No history': 1, 'History': 1},
#     119: {'History': 1},
#     120: {'History': 1},
#     121: {'No history': 1},
#     122: {},
#     123: {'No history': 0},
#     124: {},
#     125: {},
#     126: {},
#     127: {},
#     128: {'No history': 1, 'History': 1},
#     129: {},
#     130: {},
#     131: {},
#     132: {'No history': 1, 'History': 1},
#     133: {'No history': 1},
#     134: {},
#     135: {'No history': 0, 'History': 1},
#     136: {'No history': 1},
#     137: {'No history': 0, 'History': 0},
#     138: {},
#     139: {},
#     140: {'No history': 1, 'History': 1},
#     141: {'No history': 1, 'History': 1},
#     142: {'History': 1},
#     143: {'No history': 1, 'History': 0},
#     144: {'No history': 1, 'History': 0},
#     145: {'No history': 0, 'History': 1},
#     146: {'No history': 1, 'History': 1},
#     147: {'No history': 0, 'History': 1},
#     148: {'No history': 1, 'History': 1},
#     149: {'History': 1},
#     150: {'No history': 1},
#     151: {'No history': 1, 'History': 0},
#     152: {'No history': 1},
#     153: {'History': 0},
#     154: {'History': 1},
#     155: {'No history': 0},
#     156: {},
#     157: {'No history': 1, 'History': 1},
#     158: {'No history': 1},
#     159: {},
#     160: {'No history': 0, 'History': 1},
#     161: {},
#     162: {'No history': 1, 'History': 0},
#     163: {'No history': 1, 'History': 1},
#     164: {'No history': 1, 'History': 0},
#     165: {},
#     166: {},
#     167: {},
#     168: {'No history': 0},
#     169: {'No history': 1, 'History': 1},
#     170: {'No history': 1, 'History': 1},
#     171: {'No history': 1, 'History': 1},
#     172: {'No history': 1, 'History': 1},
#     173: {'No history': 1},
#     174: {'No history': 0, 'History': 1},
#     175: {},
#     176: {},
#     177: {'No history': 1},
#     178: {'No history': 1, 'History': 1},
#     179: {'No history': 1, 'History': 1},
#     180: {'History': 0},
#     181: {},
#     182: {'No history': 1, 'History': 1},
#     183: {'No history': 1, 'History': 1},
#     184: {},
#     185: {'No history': 1},
#     186: {'No history': 0},
#     187: {'No history': 1, 'History': 1},
#     188: {},
#     189: {'History': 0},
#     190: {'No history': 1, 'History': 0},
#     191: {},
#     192: {'History': 1},
#     193: {'No history': 1, 'History': 1},
#     194: {},
#     195: {'No history': 1, 'History': 1},
#     196: {'No history': 1},
#     197: {'No history': 1, 'History': 1},
#     198: {'No history': 1, 'History': 1},
#     199: {'No history': 1, 'History': 1},
#     200: {'No history': 1, 'History': 1},
#     201: {'No history': 1, 'History': 1},
#     202: {'History': 1},
#     203: {'No history': 1, 'History': 1},
#     204: {'No history': 0, 'History': 1},
#     205: {'No history': 0, 'History': 1},
#     206: {},
#     207: {},
#     208: {},
#     209: {},
#     210: {'No history': 1, 'History': 0},
#     211: {'No history': 1, 'History': 0},
#     212: {},
#     213: {},
#     214: {'No history': 0},
#     215: {},
#     216: {},
#     217: {'No history': 0, 'History': 1},
#     218: {'No history': 0, 'History': 0},
#     219: {},
#     220: {'No history': 1, 'History': 1},
#     221: {'No history': 1, 'History': 1},
#     222: {'No history': 1, 'History': 0},
#     223: {},
#     224: {},
#     225: {},
#     226: {'No history': 0},
#     227: {},
#     228: {'No history': 1, 'History': 0},
#     229: {},
#     230: {},
#     231: {'No history': 1},
#     232: {'No history': 1},
#     233: {'History': 1},
#     234: {},
#     235: {},
#     236: {'History': 1},
#     237: {'History': 1},
#     238: {},
#     239: {'No history': 1},
#     240: {'No history': 1, 'History': 1},
#     241: {'No history': 0, 'History': 0},
#     242: {'No history': 1, 'History': 1},
#     243: {'No history': 1},
#     244: {'No history': 1, 'History': 1},
#     245: {'No history': 1, 'History': 1},
#     246: {},
#     247: {},
#     248: {'No history': 1},
#     249: {'No history': 1, 'History': 1},
#     250: {'No history': 1, 'History': 1},
#     251: {'No history': 1, 'History': 1},
#     252: {'History': 1},
#     253: {'No history': 1, 'History': 0},
#     254: {'No history': 1, 'History': 1},
#     255: {'No history': 1, 'History': 1},
#     256: {'No history': 1, 'History': 1},
#     257: {},
#     258: {'No history': 1, 'History': 1},
#     259: {'No history': 1, 'History': 0},
#     260: {},
#     261: {'No history': 1, 'History': 1},
#     262: {'No history': 1, 'History': 1},
#     263: {'No history': 1},
#     264: {'History': 1},
#     265: {},
#     266: {'No history': 1, 'History': 1},
#     267: {'No history': 1},
#     268: {'No history': 1, 'History': 1},
#     269: {'No history': 1, 'History': 1},
#     270: {'No history': 1, 'History': 1},
#     271: {'No history': 1},
#     272: {'No history': 0, 'History': 1},
#     273: {'No history': 1, 'History': 0},
#     274: {'History': 1},
#     275: {'History': 1},
#     276: {},
#     277: {'No history': 1},
#     278: {'History': 1},
#     279: {'No history': 1},
#     280: {'No history': 0},
#     281: {'History': 1},
#     282: {'History': 1},
#     283: {'No history': 0, 'History': 0},
#     284: {'No history': 0, 'History': 0},
#     285: {'History': 1},
#     286: {},
#     287: {},
#     288: {'No history': 1},
#     289: {'No history': 1},
#     290: {'No history': 0},
#     291: {'No history': 1},
#     292: {},
#     293: {'No history': 0},
#     294: {'No history': 1},
#     295: {'History': 1},
#     296: {'History': 1},
#     297: {'No history': 0, 'History': 0},
#     298: {'No history': 1},
#     299: {'No history': 1, 'History': 1},
#     300: {'No history': 1, 'History': 1},
#     301: {'History': 1},
#     302: {'No history': 1, 'History': 1},
#     303: {'History': 1},
#     304: {'History': 1},
#     305: {'History': 0},
#     306: {'No history': 1, 'History': 1},
#     307: {'No history': 1},
#     308: {'No history': 1, 'History': 1},
#     309: {'History': 1},
#     310: {'No history': 1, 'History': 1},
#     311: {'No history': 1, 'History': 1},
#     312: {},
#     313: {'No history': 1, 'History': 1},
#     314: {'No history': 1, 'History': 1},
#     315: {'No history': 1, 'History': 1},
#     316: {'No history': 1, 'History': 1},
#     317: {'No history': 1},
#     318: {'No history': 1, 'History': 1},
#     319: {'No history': 1},
#     320: {'No history': 1, 'History': 1},
#     321: {'No history': 1, 'History': 1},
#     322: {},
#     323: {},
#     324: {},
#     325: {},
#     326: {},
#     327: {'No history': 0},
#     328: {},
#     329: {},
#     330: {},
#     331: {'No history': 0},
#     332: {},
#     333: {'No history': 0},
#     334: {},
#     335: {},
#     336: {},
#     337: {'History': 0},
#     338: {},
#     339: {'No history': 1},
#     340: {'History': 1},
#     341: {},
#     342: {'No history': 1},
#     343: {},
#     344: {'No history': 1},
#     345: {'No history': 1},
#     346: {'No history': 1},
#     347: {'No history': 1, 'History': 1},
#     348: {},
#     349: {},
#     350: {},
#     351: {'History': 1},
#     352: {'History': 1},
#     353: {'No history': 1},
#     354: {'History': 1},
#     355: {'No history': 1, 'History': 1},
#     356: {},
#     357: {'No history': 1, 'History': 0},
#     358: {'History': 1},
#     359: {'No history': 0, 'History': 1},
#     360: {},
#     361: {},
#     362: {'No history': 0, 'History': 1},
#     363: {},
#     364: {},
#     365: {'No history': 1, 'History': 0},
#     366: {},
#     367: {},
#     368: {'No history': 0},
#     369: {'No history': 1, 'History': 1},
#     370: {},
#     371: {'No history': 1, 'History': 1},
#     372: {'No history': 1, 'History': 1},
#     373: {'No history': 1, 'History': 1},
#     374: {},
#     375: {'No history': 1},
#     376: {},
#     377: {'History': 1},
#     378: {},
#     379: {},
#     380: {},
#     381: {'No history': 1},
#     382: {},
#     383: {'History': 1},
#     384: {'No history': 1, 'History': 1},
#     385: {},
#     386: {},
#     387: {},
#     388: {},
#     389: {},
#     390: {'History': 0},
#     391: {},
#     392: {'No history': 1, 'History': 1},
#     393: {'No history': 0},
#     394: {},
#     395: {'No history': 0},
#     396: {},
#     397: {},
#     398: {'No history': 1, 'History': 0},
#     399: {'No history': 1, 'History': 1},
#     400: {},
#     401: {'No history': 1},
#     402: {'No history': 0},
#     403: {},
#     404: {},
#     405: {},
#     406: {},
#     407: {'No history': 1, 'History': 1},
#     408: {},
#     409: {},
#     410: {},
#     411: {},
#     412: {},
#     413: {'No history': 1},
#     414: {},
#     415: {},
#     416: {'History': 1},
#     417: {},
#     418: {'No history': 0, 'History': 0},
#     419: {'No history': 1},
#     420: {},
#     421: {'No history': 0, 'History': 1},
#     422: {},
#     423: {},
#     424: {},
#     425: {'History': 1},
#     426: {},
#     427: {},
#     428: {'No history': 0, 'History': 0},
#     429: {'No history': 1},
#     430: {'No history': 1, 'History': 1},
#     431: {},
#     432: {'History': 0},
#     433: {},
#     434: {},
#     435: {},
#     436: {'History': 0},
#     437: {'History': 0},
#     438: {'No history': 1, 'History': 1},
#     439: {'No history': 1},
#     440: {'History': 1},
#     441: {},
#     442: {},
#     443: {'No history': 1},
#     444: {'No history': 1, 'History': 1},
#     445: {'No history': 0},
#     446: {},
#     447: {},
#     448: {'No history': 1},
#     449: {},
#     450: {'No history': 1, 'History': 1},
#     451: {},
#     452: {'No history': 1},
#     453: {},
#     454: {},
#     455: {},
#     456: {'History': 1},
#     457: {},
#     458: {'History': 1},
#     459: {},
#     460: {'History': 1},
#     461: {},
#     462: {},
#     463: {},
#     464: {},
#     465: {'No history': 1, 'History': 1},
#     466: {'No history': 1, 'History': 1},
#     467: {'No history': 1},
#     468: {'No history': 1},
#     469: {'No history': 1, 'History': 1},
#     470: {'History': 1},
#     471: {'No history': 1},
#     472: {},
#     473: {'No history': 1, 'History': 1},
#     474: {'No history': 1, 'History': 1},
#     475: {},
#     476: {'History': 1},
#     477: {'History': 1},
#     478: {'No history': 1, 'History': 1},
#     479: {'No history': 1},
#     480: {'No history': 1, 'History': 1},
#     481: {},
#     482: {},
#     483: {},
#     484: {'History': 1},
#     485: {'No history': 1},
#     486: {'History': 1},
#     487: {'History': 1},
#     488: {},
#     489: {'No history': 1},
#     490: {'History': 1},
#     491: {},
#     492: {'No history': 0},
#     493: {},
#     494: {'No history': 0},
#     495: {},
#     496: {'No history': 0},
#     497: {'History': 0},
#     498: {},
#     499: {'No history': 0},
#     500: {},
#     501: {},
#     502: {'No history': 0, 'History': 0},
#     503: {'No history': 1},
#     504: {},
#     505: {'No history': 1, 'History': 1},
#     506: {},
#     507: {'No history': 1},
#     508: {'No history': 0, 'History': 0},
#     509: {'No history': 1, 'History': 1},
#     510: {},
#     511: {},
#     512: {'History': 1},
#     513: {'History': 1},
#     514: {},
#     515: {'No history': 0},
#     516: {},
#     517: {'History': 1},
#     518: {'No history': 1},
#     519: {'No history': 0},
#     520: {'History': 0},
#     521: {},
#     522: {},
#     523: {},
#     524: {},
#     525: {},
#     526: {},
#     527: {},
#     528: {},
#     529: {},
#     530: {},
#     531: {},
#     532: {},
#     533: {},
#     534: {},
#     535: {},
#     536: {},
#     537: {},
#     538: {},
#     539: {},
#     540: {},
#     541: {},
#     542: {},
#     543: {'History': 1},
#     544: {},
#     545: {},
#     546: {},
#     547: {},
#     548: {},
#     549: {'No history': 1, 'History': 1},
#     550: {},
#     551: {'No history': 1},
#     552: {},
#     553: {'History': 0},
#     554: {'No history': 1},
#     555: {'No history': 1},
#     556: {},
#     557: {},
#     558: {},
#     559: {'No history': 0, 'History': 1},
#     560: {'History': 1},
#     561: {'History': 0},
#     562: {},
#     563: {'No history': 1},
#     564: {'No history': 0},
#     565: {'No history': 0},
#     566: {},
#     567: {},
#     568: {},
#     569: {},
#     570: {},
#     571: {},
#     572: {},
#     573: {},
#     574: {},
#     575: {'No history': 1, 'History': 1},
#     576: {'No history': 1, 'History': 1},
#     577: {'History': 1},
#     578: {'No history': 0},
#     579: {},
#     580: {},
#     581: {'History': 0},
#     582: {},
#     583: {},
#     584: {},
#     585: {},
#     586: {},
#     587: {'No history': 1},
#     588: {},
#     589: {'No history': 1},
#     590: {},
#     591: {'History': 0},
#     592: {},
#     593: {'No history': 1},
#     594: {'History': 1},
#     595: {},
#     596: {},
#     597: {'No history': 1},
#     598: {},
#     599: {},
#     600: {'History': 1},
#     601: {'No history': 0},
#     602: {},
#     603: {'No history': 1, 'History': 1},
#     604: {'No history': 0, 'History': 0},
#     605: {},
#     606: {},
#     607: {'No history': 0},
#     608: {},
#     609: {},
#     610: {'History': 0},
#     611: {},
#     612: {'History': 1},
#     613: {},
#     614: {'No history': 1, 'History': 1},
#     615: {},
#     616: {},
#     617: {'No history': 1},
#     618: {},
#     619: {'No history': 1, 'History': 1},
#     620: {},
#     621: {'History': 0},
#     622: {'History': 0},
#     623: {'No history': 1},
#     624: {'No history': 1, 'History': 0},
#     625: {'No history': 1, 'History': 1},
#     626: {},
#     627: {'No history': 1, 'History': 1},
#     628: {},
#     629: {'History': 1},
#     630: {'No history': 1, 'History': 1},
#     631: {},
#     632: {'No history': 1, 'History': 1},
#     633: {},
#     634: {'No history': 1},
#     635: {'History': 1},
#     636: {'No history': 1},
#     637: {},
#     638: {'History': 1},
#     639: {},
#     640: {'No history': 1},
#     641: {'No history': 1},
#     642: {'History': 1},
#     643: {'No history': 1},
#     644: {},
#     645: {},
#     646: {},
#     647: {'No history': 1, 'History': 1},
#     648: {},
#     649: {'No history': 1, 'History': 0},
#     650: {},
#     651: {},
#     652: {},
#     653: {'No history': 1},
#     654: {'History': 1},
#     655: {},
#     656: {},
#     657: {},
#     658: {},
#     659: {'No history': 1, 'History': 1},
#     660: {},
#     661: {'No history': 1},
#     662: {},
#     663: {},
#     664: {'History': 1},
#     665: {'History': 0},
#     666: {},
#     667: {},
#     668: {},
#     669: {},
#     670: {},
#     671: {},
#     672: {},
#     673: {},
#     674: {'No history': 0},
#     675: {},
#     676: {'No history': 0, 'History': 0},
#     677: {},
#     678: {'No history': 1, 'History': 1},
#     679: {'History': 1},
#     680: {},
#     681: {'No history': 1, 'History': 1},
#     682: {'History': 1},
#     683: {},
#     684: {'No history': 1, 'History': 1},
#     685: {},
#     686: {},
#     687: {'History': 1},
#     688: {},
#     689: {'No history': 1, 'History': 1},
#     690: {},
#     691: {},
#     692: {},
#     693: {},
#     694: {},
#     695: {'No history': 1, 'History': 1},
#     696: {'No history': 1, 'History': 1},
#     697: {'History': 1},
#     698: {},
#     699: {'No history': 1},
#     700: {'No history': 1},
#     701: {},
#     702: {},
#     703: {},
#     704: {'No history': 1},
#     705: {'No history': 1},
#     706: {'No history': 0},
#     707: {'No history': 1, 'History': 1},
#     708: {},
#     709: {'History': 1},
#     710: {'No history': 0},
#     711: {},
#     712: {'No history': 1},
#     713: {},
#     714: {},
#     715: {'No history': 1, 'History': 1},
#     716: {},
#     717: {},
#     718: {},
#     719: {'History': 1},
#     720: {'No history': 0, 'History': 1},
#     721: {},
#     722: {},
#     723: {},
#     724: {'No history': 1, 'History': 1},
#     725: {'No history': 1, 'History': 1},
#     726: {},
#     727: {},
#     728: {'No history': 1, 'History': 0},
#     729: {'No history': 1, 'History': 1},
#     730: {},
#     731: {'History': 1},
#     732: {'No history': 1, 'History': 1},
#     733: {'History': 1},
#     734: {},
#     735: {'No history': 1},
#     736: {'No history': 1},
#     737: {},
#     738: {'No history': 1, 'History': 1},
#     739: {'No history': 1},
#     740: {'History': 1},
#     741: {},
#     742: {'No history': 0, 'History': 1},
#     743: {'No history': 1},
#     744: {},
#     745: {},
#     746: {'No history': 1, 'History': 1},
#     747: {},
#     748: {'No history': 1, 'History': 1},
#     749: {'No history': 1, 'History': 1},
#     750: {'No history': 1, 'History': 1},
#     751: {'History': 1},
#     752: {'No history': 1},
#     753: {},
#     754: {},
#     755: {'No history': 1, 'History': 1},
#     756: {},
#     757: {'No history': 1, 'History': 1},
#     758: {'No history': 1, 'History': 1},
#     759: {'No history': 0},
#     760: {'History': 1},
#     761: {'No history': 1},
#     762: {},
#     763: {'No history': 1, 'History': 1},
#     764: {'History': 1},
#     765: {},
#     766: {},
#     767: {},
#     768: {},
#     769: {},
#     770: {'No history': 1},
#     771: {},
#     772: {'History': 0},
#     773: {'No history': 1, 'History': 1},
#     774: {'No history': 1},
#     775: {},
#     776: {'No history': 1, 'History': 1},
#     777: {},
#     778: {'No history': 1},
#     779: {'No history': 1},
#     780: {'No history': 1, 'History': 1},
#     781: {'No history': 1, 'History': 1},
#     782: {'No history': 1, 'History': 1},
#     783: {'No history': 1, 'History': 1},
#     784: {'No history': 1, 'History': 1},
#     785: {'No history': 1, 'History': 1},
#     786: {'History': 1},
#     787: {'No history': 1, 'History': 0},
#     788: {'No history': 1, 'History': 1},
#     789: {'No history': 1, 'History': 1},
#     790: {'History': 1},
#     791: {'No history': 1, 'History': 1},
#     792: {'No history': 1, 'History': 1},
#     793: {'No history': 1, 'History': 1},
#     794: {'No history': 1, 'History': 1},
#     795: {'No history': 1, 'History': 1},
#     796: {},
#     797: {},
#     798: {},
#     799: {'No history': 0, 'History': 1},
#     800: {'No history': 1},
#     801: {},
#     802: {},
#     803: {},
#     804: {},
#     805: {'No history': 1, 'History': 1},
#     806: {'No history': 1, 'History': 0},
#     807: {},
#     808: {'No history': 1, 'History': 0},
#     809: {'No history': 1},
#     810: {'No history': 0},
#     811: {'History': 1},
#     812: {'No history': 1, 'History': 1},
#     813: {},
#     814: {},
#     815: {},
#     816: {},
#     817: {},
#     818: {'No history': 0},
#     819: {},
#     820: {'No history': 0, 'History': 1},
#     821: {'No history': 1, 'History': 1},
#     822: {'No history': 0, 'History': 0},
#     823: {},
#     824: {'No history': 1, 'History': 1},
#     825: {'History': 1},
#     826: {'No history': 1, 'History': 1},
#     827: {},
#     828: {'No history': 1},
#     829: {'No history': 1, 'History': 1},
#     830: {'No history': 1},
#     831: {},
#     832: {},
#     833: {'No history': 0},
#     834: {},
#     835: {},
#     836: {'History': 1},
#     837: {},
#     838: {'No history': 1},
#     839: {'No history': 0},
#     840: {},
#     841: {},
#     842: {},
#     843: {},
#     844: {},
#     845: {},
#     846: {'No history': 1},
#     847: {},
#     848: {'No history': 1},
#     849: {'History': 1},
#     850: {},
#     851: {},
#     852: {'No history': 1},
#     853: {},
#     854: {},
#     855: {'History': 1},
#     856: {},
#     857: {'No history': 1, 'History': 1},
#     858: {},
#     859: {'History': 0},
#     860: {},
#     861: {'No history': 1, 'History': 1},
#     862: {'No history': 1, 'History': 1},
#     863: {},
#     864: {},
#     865: {'No history': 0, 'History': 0},
#     866: {},
#     867: {},
#     868: {'No history': 1, 'History': 1},
#     869: {},
#     870: {},
#     871: {},
#     872: {},
#     873: {},
#     874: {},
#     875: {'No history': 1, 'History': 1},
#     876: {'No history': 0},
#     877: {'No history': 1, 'History': 1},
#     878: {'No history': 1},
#     879: {'No history': 1},
#     880: {},
#     881: {'No history': 1, 'History': 1},
#     882: {'No history': 1, 'History': 1},
#     883: {},
#     884: {'History': 1},
#     885: {},
#     886: {'No history': 1, 'History': 1},
#     887: {'No history': 1, 'History': 1},
#     888: {},
#     889: {},
#     890: {'No history': 1, 'History': 1},
#     891: {},
#     892: {'History': 1},
#     893: {'No history': 0},
#     894: {'No history': 0, 'History': 0},
#     895: {'No history': 1},
#     896: {'No history': 1, 'History': 1},
#     897: {},
#     898: {'No history': 0},
#     899: {'No history': 1},
#     900: {'No history': 1},
#     901: {'History': 1},
#     902: {},
#     903: {'History': 1},
#     904: {'History': 1},
#     905: {'No history': 1, 'History': 0},
#     906: {'History': 0},
#     907: {},
#     908: {'No history': 1},
#     909: {'History': 0},
#     910: {'No history': 0},
#     911: {'History': 1},
#     912: {'No history': 1, 'History': 1},
#     913: {'History': 1},
#     914: {'No history': 0, 'History': 0},
#     915: {},
#     916: {'No history': 0, 'History': 1},
#     917: {'No history': 1},
#     918: {'History': 1},
#     919: {'No history': 0},
#     920: {'History': 1},
#     921: {'No history': 1, 'History': 1},
#     922: {'No history': 1, 'History': 1},
#     923: {},
#     924: {},
#     925: {},
#     926: {},
#     927: {},
#     928: {},
#     929: {'No history': 0, 'History': 1},
#     930: {'No history': 1},
#     931: {},
#     932: {},
#     933: {'No history': 1},
#     934: {},
#     935: {'History': 1},
#     936: {'No history': 1},
#     937: {'History': 1},
#     938: {},
#     939: {'No history': 1, 'History': 1},
#     940: {},
#     941: {'No history': 1},
#     942: {},
#     943: {},
#     944: {'No history': 1, 'History': 0},
#     945: {},
#     946: {},
#     947: {},
#     948: {},
#     949: {'History': 1},
#     950: {'No history': 0, 'History': 1},
#     951: {'No history': 1},
#     952: {'History': 1},
#     953: {'No history': 0},
#     954: {},
#     955: {'No history': 0, 'History': 0},
#     956: {'No history': 1, 'History': 1},
#     957: {'No history': 1, 'History': 1},
#     958: {'History': 1},
#     959: {'No history': 0, 'History': 0},
#     960: {'No history': 1, 'History': 0},
#     961: {'History': 0},
#     962: {'No history': 1},
#     963: {'No history': 1, 'History': 1},
#     964: {'No history': 1, 'History': 1},
#     965: {'No history': 1},
#     966: {'History': 0},
#     967: {},
#     968: {'No history': 1},
#     969: {},
#     970: {'No history': 1, 'History': 1},
#     971: {'No history': 1},
#     972: {},
#     973: {},
#     974: {'No history': 0},
#     975: {'No history': 1, 'History': 1},
#     976: {},
#     977: {'No history': 1, 'History': 1},
#     978: {},
#     979: {},
#     980: {},
#     981: {},
#     982: {},
#     983: {'History': 1},
#     984: {'No history': 0},
#     985: {'No history': 1, 'History': 1},
#     986: {'No history': 1, 'History': 1},
#     987: {},
#     988: {'History': 1},
#     989: {'No history': 1},
#     990: {'History': 1},
#     991: {},
#     992: {'No history': 1, 'History': 1},
#     993: {},
#     994: {'No history': 1, 'History': 1},
#     995: {},
#     996: {},
#     997: {},
#     998: {'No history': 1},
#     999: {},
#     ...},
#    {0: {'No history': 0, 'History': 1},
#     1: {'No history': 1, 'History': 1},
#     2: {},
#     3: {'No history': 1, 'History': 1},
#     4: {'History': 0},
#     5: {'History': 1},
#     6: {'No history': 1, 'History': 1},
#     7: {'No history': 1},
#     8: {},
#     9: {},
#     10: {'History': 1},
#     11: {'No history': 1, 'History': 1},
#     12: {'No history': 1},
#     13: {'No history': 1, 'History': 1},
#     14: {'No history': 1},
#     15: {'No history': 1},
#     16: {'No history': 1, 'History': 0},
#     17: {'No history': 1, 'History': 1},
#     18: {'No history': 1},
#     19: {'No history': 1, 'History': 0},
#     20: {'No history': 1},
#     21: {'No history': 1, 'History': 1},
#     22: {'History': 1},
#     23: {'No history': 1, 'History': 1},
#     24: {},
#     25: {},
#     26: {'No history': 1, 'History': 1},
#     27: {'History': 1},
#     28: {},
#     29: {'No history': 1, 'History': 1},
#     30: {},
#     31: {'No history': 1, 'History': 1},
#     32: {},
#     33: {},
#     34: {},
#     35: {'No history': 1, 'History': 1},
#     36: {'No history': 1, 'History': 1},
#     37: {},
#     38: {'History': 1},
#     39: {'No history': 1, 'History': 0},
#     40: {'No history': 1, 'History': 1},
#     41: {'No history': 1, 'History': 1},
#     42: {'No history': 1, 'History': 1},
#     43: {},
#     44: {'No history': 0, 'History': 1},
#     45: {'No history': 1, 'History': 1},
#     46: {'No history': 1, 'History': 1},
#     47: {'No history': 1, 'History': 1},
#     48: {'No history': 1},
#     49: {'No history': 1, 'History': 1},
#     50: {'History': 1},
#     51: {},
#     52: {},
#     53: {'History': 1},
#     54: {'No history': 1, 'History': 1},
#     55: {},
#     56: {'No history': 1, 'History': 1},
#     57: {},
#     58: {'History': 1},
#     59: {'No history': 1, 'History': 1},
#     60: {},
#     61: {},
#     62: {'History': 1},
#     63: {'No history': 1, 'History': 1},
#     64: {'No history': 1},
#     65: {'No history': 0},
#     66: {},
#     67: {'History': 1},
#     68: {'History': 1},
#     69: {'History': 1},
#     70: {'No history': 1},
#     71: {'No history': 1},
#     72: {},
#     73: {'No history': 1, 'History': 0},
#     74: {'No history': 1},
#     75: {'No history': 1, 'History': 1},
#     76: {'History': 1},
#     77: {'No history': 1, 'History': 1},
#     78: {'No history': 0},
#     79: {'No history': 1},
#     80: {},
#     81: {},
#     82: {'History': 0},
#     83: {},
#     84: {},
#     85: {'History': 1},
#     86: {},
#     87: {'No history': 1},
#     88: {},
#     89: {},
#     90: {},
#     91: {'History': 1},
#     92: {'History': 1},
#     93: {'No history': 1, 'History': 1},
#     94: {'No history': 1, 'History': 1},
#     95: {'No history': 1, 'History': 1},
#     96: {'No history': 1},
#     97: {'No history': 1, 'History': 1},
#     98: {'No history': 1},
#     99: {'History': 1},
#     100: {'No history': 1},
#     101: {'No history': 1, 'History': 1},
#     102: {'No history': 1, 'History': 1},
#     103: {'No history': 1, 'History': 1},
#     104: {'No history': 1},
#     105: {'No history': 1, 'History': 1},
#     106: {'No history': 1, 'History': 1},
#     107: {'History': 1},
#     108: {'No history': 1, 'History': 1},
#     109: {'No history': 0, 'History': 0},
#     110: {},
#     111: {'No history': 1},
#     112: {'No history': 0},
#     113: {'History': 1},
#     114: {},
#     115: {'No history': 0, 'History': 1},
#     116: {'History': 1},
#     117: {},
#     118: {'No history': 1, 'History': 1},
#     119: {},
#     120: {'History': 1},
#     121: {'No history': 1},
#     122: {'History': 0},
#     123: {'No history': 0},
#     124: {},
#     125: {},
#     126: {},
#     127: {},
#     128: {'No history': 1},
#     129: {},
#     130: {},
#     131: {},
#     132: {'No history': 1, 'History': 1},
#     133: {'No history': 1, 'History': 1},
#     134: {},
#     135: {'No history': 0, 'History': 1},
#     136: {'No history': 1, 'History': 1},
#     137: {'No history': 0, 'History': 0},
#     138: {},
#     139: {},
#     140: {'No history': 1, 'History': 1},
#     141: {'No history': 1, 'History': 1},
#     142: {},
#     143: {'No history': 1, 'History': 0},
#     144: {'No history': 1, 'History': 0},
#     145: {'No history': 0},
#     146: {'No history': 1},
#     147: {'No history': 0, 'History': 1},
#     148: {'No history': 1},
#     149: {'History': 1},
#     150: {'No history': 1, 'History': 1},
#     151: {'No history': 1, 'History': 1},
#     152: {'No history': 1},
#     153: {'History': 1},
#     154: {},
#     155: {'No history': 0, 'History': 0},
#     156: {'History': 1},
#     157: {'No history': 1, 'History': 1},
#     158: {'No history': 1},
#     159: {},
#     160: {'No history': 0},
#     161: {},
#     162: {'No history': 1, 'History': 0},
#     163: {'No history': 1, 'History': 1},
#     164: {'No history': 1, 'History': 0},
#     165: {'History': 1},
#     166: {'History': 0},
#     167: {},
#     168: {'No history': 0},
#     169: {'No history': 1},
#     170: {'No history': 1, 'History': 1},
#     171: {'No history': 1},
#     172: {'No history': 1, 'History': 1},
#     173: {'No history': 1, 'History': 1},
#     174: {'No history': 0},
#     175: {'History': 0},
#     176: {'History': 1},
#     177: {'No history': 1, 'History': 1},
#     178: {'No history': 1, 'History': 1},
#     179: {'No history': 1, 'History': 1},
#     180: {},
#     181: {'History': 1},
#     182: {'No history': 1, 'History': 1},
#     183: {'No history': 1},
#     184: {},
#     185: {'No history': 1},
#     186: {'No history': 0, 'History': 1},
#     187: {'No history': 1, 'History': 1},
#     188: {'History': 1},
#     189: {'History': 1},
#     190: {'No history': 1, 'History': 1},
#     191: {},
#     192: {},
#     193: {'No history': 1, 'History': 1},
#     194: {'History': 0},
#     195: {'No history': 1, 'History': 1},
#     196: {'No history': 1},
#     197: {'No history': 1, 'History': 1},
#     198: {'No history': 1, 'History': 1},
#     199: {'No history': 1, 'History': 1},
#     200: {'No history': 1},
#     201: {'No history': 1, 'History': 1},
#     202: {'History': 1},
#     203: {'No history': 1, 'History': 1},
#     204: {'No history': 0},
#     205: {'No history': 0, 'History': 0},
#     206: {},
#     207: {},
#     208: {},
#     209: {'History': 1},
#     210: {'No history': 1, 'History': 0},
#     211: {'No history': 1, 'History': 1},
#     212: {},
#     213: {},
#     214: {'No history': 0, 'History': 0},
#     215: {},
#     216: {'History': 1},
#     217: {'No history': 0, 'History': 1},
#     218: {'No history': 0},
#     219: {},
#     220: {'No history': 1},
#     221: {'No history': 1, 'History': 0},
#     222: {'No history': 1, 'History': 0},
#     223: {},
#     224: {},
#     225: {},
#     226: {'No history': 0},
#     227: {},
#     228: {'No history': 1},
#     229: {},
#     230: {'History': 1},
#     231: {'No history': 1},
#     232: {'No history': 1, 'History': 1},
#     233: {'History': 1},
#     234: {},
#     235: {},
#     236: {},
#     237: {},
#     238: {'History': 0},
#     239: {'No history': 1},
#     240: {'No history': 1, 'History': 1},
#     241: {'No history': 0},
#     242: {'No history': 1, 'History': 1},
#     243: {'No history': 1},
#     244: {'No history': 1, 'History': 1},
#     245: {'No history': 1},
#     246: {},
#     247: {},
#     248: {'No history': 1, 'History': 1},
#     249: {'No history': 1, 'History': 1},
#     250: {'No history': 1, 'History': 1},
#     251: {'No history': 1, 'History': 1},
#     252: {'History': 1},
#     253: {'No history': 1, 'History': 0},
#     254: {'No history': 1, 'History': 1},
#     255: {'No history': 1, 'History': 1},
#     256: {'No history': 1, 'History': 1},
#     257: {'History': 0},
#     258: {'No history': 1, 'History': 1},
#     259: {'No history': 1, 'History': 0},
#     260: {'History': 1},
#     261: {'No history': 1, 'History': 1},
#     262: {'No history': 1, 'History': 1},
#     263: {'No history': 1, 'History': 1},
#     264: {'History': 1},
#     265: {'History': 1},
#     266: {'No history': 1, 'History': 1},
#     267: {'No history': 1},
#     268: {'No history': 1},
#     269: {'No history': 1},
#     270: {'No history': 1, 'History': 1},
#     271: {'No history': 1},
#     272: {'No history': 0, 'History': 1},
#     273: {'No history': 1},
#     274: {},
#     275: {'History': 1},
#     276: {'History': 0},
#     277: {'No history': 1},
#     278: {'History': 1},
#     279: {'No history': 1},
#     280: {'No history': 0},
#     281: {},
#     282: {'History': 1},
#     283: {'No history': 0, 'History': 0},
#     284: {'No history': 0, 'History': 0},
#     285: {},
#     286: {},
#     287: {},
#     288: {'No history': 1, 'History': 1},
#     289: {'No history': 1},
#     290: {'No history': 0},
#     291: {'No history': 1, 'History': 1},
#     292: {},
#     293: {'No history': 0},
#     294: {'No history': 1, 'History': 1},
#     295: {'History': 1},
#     296: {'History': 1},
#     297: {'No history': 0, 'History': 0},
#     298: {'No history': 1},
#     299: {'No history': 1, 'History': 1},
#     300: {'No history': 1},
#     301: {'History': 1},
#     302: {'No history': 1},
#     303: {'History': 0},
#     304: {'History': 1},
#     305: {'History': 1},
#     306: {'No history': 1, 'History': 1},
#     307: {'No history': 1},
#     308: {'No history': 1, 'History': 1},
#     309: {'History': 1},
#     310: {'No history': 1, 'History': 1},
#     311: {'No history': 1, 'History': 1},
#     312: {},
#     313: {'No history': 1, 'History': 1},
#     314: {'No history': 1, 'History': 1},
#     315: {'No history': 1, 'History': 1},
#     316: {'No history': 1, 'History': 1},
#     317: {'No history': 1, 'History': 1},
#     318: {'No history': 1, 'History': 1},
#     319: {'No history': 1},
#     320: {'No history': 1, 'History': 1},
#     321: {'No history': 1, 'History': 1},
#     322: {},
#     323: {},
#     324: {},
#     325: {},
#     326: {},
#     327: {'No history': 0},
#     328: {},
#     329: {},
#     330: {},
#     331: {'No history': 0},
#     332: {},
#     333: {'No history': 0},
#     334: {},
#     335: {},
#     336: {},
#     337: {'History': 0},
#     338: {'History': 1},
#     339: {'No history': 1},
#     340: {'History': 1},
#     341: {},
#     342: {'No history': 1},
#     343: {},
#     344: {'No history': 1, 'History': 1},
#     345: {'No history': 1},
#     346: {'No history': 1},
#     347: {'No history': 1, 'History': 1},
#     348: {},
#     349: {},
#     350: {},
#     351: {'History': 1},
#     352: {},
#     353: {'No history': 1},
#     354: {'History': 1},
#     355: {'No history': 1},
#     356: {'History': 0},
#     357: {'No history': 1, 'History': 1},
#     358: {},
#     359: {'No history': 0},
#     360: {},
#     361: {'History': 0},
#     362: {'No history': 0},
#     363: {},
#     364: {'History': 1},
#     365: {'No history': 1},
#     366: {},
#     367: {},
#     368: {'No history': 0, 'History': 1},
#     369: {'No history': 1, 'History': 1},
#     370: {},
#     371: {'No history': 1, 'History': 1},
#     372: {'No history': 1, 'History': 1},
#     373: {'No history': 1, 'History': 1},
#     374: {},
#     375: {'No history': 1},
#     376: {},
#     377: {'History': 1},
#     378: {},
#     379: {},
#     380: {},
#     381: {'No history': 1},
#     382: {},
#     383: {'History': 1},
#     384: {'No history': 1, 'History': 1},
#     385: {},
#     386: {},
#     387: {},
#     388: {},
#     389: {},
#     390: {},
#     391: {},
#     392: {'No history': 1, 'History': 1},
#     393: {'No history': 0},
#     394: {},
#     395: {'No history': 0},
#     396: {'History': 0},
#     397: {},
#     398: {'No history': 1, 'History': 0},
#     399: {'No history': 1},
#     400: {},
#     401: {'No history': 1, 'History': 1},
#     402: {'No history': 0},
#     403: {},
#     404: {},
#     405: {},
#     406: {},
#     407: {'No history': 1, 'History': 1},
#     408: {'History': 1},
#     409: {},
#     410: {},
#     411: {},
#     412: {},
#     413: {'No history': 1},
#     414: {},
#     415: {},
#     416: {},
#     417: {},
#     418: {'No history': 0, 'History': 0},
#     419: {'No history': 1},
#     420: {},
#     421: {'No history': 0, 'History': 1},
#     422: {},
#     423: {},
#     424: {'History': 0},
#     425: {'History': 1},
#     426: {},
#     427: {},
#     428: {'No history': 0, 'History': 0},
#     429: {'No history': 1},
#     430: {'No history': 1, 'History': 1},
#     431: {},
#     432: {},
#     433: {},
#     434: {},
#     435: {},
#     436: {'History': 0},
#     437: {},
#     438: {'No history': 1, 'History': 0},
#     439: {'No history': 1},
#     440: {'History': 1},
#     441: {},
#     442: {},
#     443: {'No history': 1},
#     444: {'No history': 1},
#     445: {'No history': 0, 'History': 1},
#     446: {},
#     447: {},
#     448: {'No history': 1, 'History': 1},
#     449: {},
#     450: {'No history': 1},
#     451: {},
#     452: {'No history': 1},
#     453: {'History': 1},
#     454: {},
#     455: {},
#     456: {},
#     457: {},
#     458: {},
#     459: {'History': 1},
#     460: {'History': 1},
#     461: {},
#     462: {},
#     463: {},
#     464: {},
#     465: {'No history': 1, 'History': 1},
#     466: {'No history': 1},
#     467: {'No history': 1},
#     468: {'No history': 1},
#     469: {'No history': 1},
#     470: {'History': 1},
#     471: {'No history': 1, 'History': 1},
#     472: {},
#     473: {'No history': 1, 'History': 1},
#     474: {'No history': 1},
#     475: {},
#     476: {'History': 1},
#     477: {},
#     478: {'No history': 1, 'History': 1},
#     479: {'No history': 1, 'History': 1},
#     480: {'No history': 1, 'History': 1},
#     481: {'History': 1},
#     482: {},
#     483: {'History': 1},
#     484: {'History': 1},
#     485: {'No history': 1, 'History': 1},
#     486: {'History': 1},
#     487: {},
#     488: {},
#     489: {'No history': 1},
#     490: {},
#     491: {},
#     492: {'No history': 0},
#     493: {},
#     494: {'No history': 0},
#     495: {},
#     496: {'No history': 0},
#     497: {'History': 0},
#     498: {},
#     499: {'No history': 0, 'History': 1},
#     500: {},
#     501: {'History': 1},
#     502: {'No history': 0},
#     503: {'No history': 1, 'History': 1},
#     504: {},
#     505: {'No history': 1, 'History': 1},
#     506: {'History': 0},
#     507: {'No history': 1},
#     508: {'No history': 0, 'History': 0},
#     509: {'No history': 1, 'History': 1},
#     510: {},
#     511: {},
#     512: {'History': 1},
#     513: {},
#     514: {},
#     515: {'No history': 0},
#     516: {},
#     517: {},
#     518: {'No history': 1},
#     519: {'No history': 0},
#     520: {'History': 0},
#     521: {},
#     522: {},
#     523: {},
#     524: {},
#     525: {},
#     526: {},
#     527: {},
#     528: {},
#     529: {},
#     530: {},
#     531: {},
#     532: {},
#     533: {},
#     534: {},
#     535: {},
#     536: {},
#     537: {},
#     538: {},
#     539: {},
#     540: {},
#     541: {},
#     542: {},
#     543: {'History': 1},
#     544: {},
#     545: {'History': 0},
#     546: {},
#     547: {},
#     548: {},
#     549: {'No history': 1, 'History': 1},
#     550: {},
#     551: {'No history': 1},
#     552: {},
#     553: {},
#     554: {'No history': 1},
#     555: {'No history': 1},
#     556: {},
#     557: {},
#     558: {},
#     559: {'No history': 0, 'History': 1},
#     560: {'History': 1},
#     561: {},
#     562: {},
#     563: {'No history': 1},
#     564: {'No history': 0},
#     565: {'No history': 0},
#     566: {},
#     567: {},
#     568: {},
#     569: {},
#     570: {'History': 0},
#     571: {},
#     572: {},
#     573: {},
#     574: {},
#     575: {'No history': 1, 'History': 1},
#     576: {'No history': 1, 'History': 1},
#     577: {'History': 1},
#     578: {'No history': 0},
#     579: {'History': 0},
#     580: {},
#     581: {},
#     582: {},
#     583: {},
#     584: {},
#     585: {},
#     586: {},
#     587: {'No history': 1},
#     588: {},
#     589: {'No history': 1},
#     590: {'History': 1},
#     591: {'History': 0},
#     592: {},
#     593: {'No history': 1},
#     594: {},
#     595: {},
#     596: {},
#     597: {'No history': 1, 'History': 1},
#     598: {},
#     599: {},
#     600: {},
#     601: {'No history': 0},
#     602: {},
#     603: {'No history': 1, 'History': 1},
#     604: {'No history': 0, 'History': 1},
#     605: {},
#     606: {},
#     607: {'No history': 0},
#     608: {},
#     609: {},
#     610: {'History': 0},
#     611: {},
#     612: {},
#     613: {},
#     614: {'No history': 1, 'History': 1},
#     615: {'History': 0},
#     616: {},
#     617: {'No history': 1},
#     618: {},
#     619: {'No history': 1, 'History': 1},
#     620: {},
#     621: {'History': 0},
#     622: {'History': 1},
#     623: {'No history': 1, 'History': 1},
#     624: {'No history': 1},
#     625: {'No history': 1, 'History': 1},
#     626: {},
#     627: {'No history': 1, 'History': 1},
#     628: {},
#     629: {'History': 0},
#     630: {'No history': 1, 'History': 1},
#     631: {},
#     632: {'No history': 1, 'History': 1},
#     633: {},
#     634: {'No history': 1, 'History': 0},
#     635: {'History': 1},
#     636: {'No history': 1},
#     637: {},
#     638: {},
#     639: {},
#     640: {'No history': 1},
#     641: {'No history': 1, 'History': 1},
#     642: {},
#     643: {'No history': 1},
#     644: {},
#     645: {},
#     646: {},
#     647: {'No history': 1, 'History': 1},
#     648: {},
#     649: {'No history': 1},
#     650: {},
#     651: {'History': 0},
#     652: {},
#     653: {'No history': 1},
#     654: {},
#     655: {},
#     656: {'History': 1},
#     657: {'History': 1},
#     658: {},
#     659: {'No history': 1},
#     660: {},
#     661: {'No history': 1},
#     662: {},
#     663: {},
#     664: {},
#     665: {'History': 0},
#     666: {},
#     667: {},
#     668: {},
#     669: {},
#     670: {},
#     671: {},
#     672: {'History': 1},
#     673: {},
#     674: {'No history': 0},
#     675: {},
#     676: {'No history': 0},
#     677: {},
#     678: {'No history': 1, 'History': 1},
#     679: {'History': 1},
#     680: {},
#     681: {'No history': 1, 'History': 1},
#     682: {'History': 1},
#     683: {'History': 1},
#     684: {'No history': 1, 'History': 1},
#     685: {},
#     686: {},
#     687: {'History': 1},
#     688: {'History': 0},
#     689: {'No history': 1},
#     690: {},
#     691: {},
#     692: {'History': 1},
#     693: {},
#     694: {},
#     695: {'No history': 1, 'History': 1},
#     696: {'No history': 1},
#     697: {'History': 1},
#     698: {},
#     699: {'No history': 1},
#     700: {'No history': 1},
#     701: {},
#     702: {},
#     703: {},
#     704: {'No history': 1},
#     705: {'No history': 1},
#     706: {'No history': 0},
#     707: {'No history': 1, 'History': 1},
#     708: {},
#     709: {'History': 1},
#     710: {'No history': 0},
#     711: {},
#     712: {'No history': 1},
#     713: {},
#     714: {},
#     715: {'No history': 1, 'History': 1},
#     716: {},
#     717: {},
#     718: {},
#     719: {'History': 1},
#     720: {'No history': 0, 'History': 1},
#     721: {},
#     722: {},
#     723: {},
#     724: {'No history': 1, 'History': 1},
#     725: {'No history': 1, 'History': 1},
#     726: {'History': 1},
#     727: {'History': 1},
#     728: {'No history': 1, 'History': 0},
#     729: {'No history': 1},
#     730: {},
#     731: {'History': 1},
#     732: {'No history': 1, 'History': 1},
#     733: {},
#     734: {},
#     735: {'No history': 1},
#     736: {'No history': 1, 'History': 1},
#     737: {},
#     738: {'No history': 1, 'History': 1},
#     739: {'No history': 1},
#     740: {},
#     741: {'History': 1},
#     742: {'No history': 0},
#     743: {'No history': 1},
#     744: {'History': 1},
#     745: {'History': 1},
#     746: {'No history': 1, 'History': 1},
#     747: {},
#     748: {'No history': 1, 'History': 1},
#     749: {'No history': 1},
#     750: {'No history': 1, 'History': 1},
#     751: {},
#     752: {'No history': 1},
#     753: {},
#     754: {},
#     755: {'No history': 1, 'History': 1},
#     756: {},
#     757: {'No history': 1, 'History': 1},
#     758: {'No history': 1, 'History': 1},
#     759: {'No history': 0},
#     760: {'History': 1},
#     761: {'No history': 1},
#     762: {'History': 0},
#     763: {'No history': 1, 'History': 1},
#     764: {'History': 1},
#     765: {},
#     766: {},
#     767: {},
#     768: {},
#     769: {},
#     770: {'No history': 1},
#     771: {},
#     772: {},
#     773: {'No history': 1},
#     774: {'No history': 1, 'History': 1},
#     775: {},
#     776: {'No history': 1, 'History': 1},
#     777: {'History': 1},
#     778: {'No history': 1},
#     779: {'No history': 1, 'History': 1},
#     780: {'No history': 1, 'History': 1},
#     781: {'No history': 1},
#     782: {'No history': 1, 'History': 1},
#     783: {'No history': 1, 'History': 1},
#     784: {'No history': 1, 'History': 1},
#     785: {'No history': 1, 'History': 1},
#     786: {'History': 1},
#     787: {'No history': 1, 'History': 0},
#     788: {'No history': 1, 'History': 1},
#     789: {'No history': 1, 'History': 1},
#     790: {'History': 1},
#     791: {'No history': 1, 'History': 1},
#     792: {'No history': 1},
#     793: {'No history': 1},
#     794: {'No history': 1, 'History': 1},
#     795: {'No history': 1, 'History': 1},
#     796: {},
#     797: {},
#     798: {},
#     799: {'No history': 0, 'History': 0},
#     800: {'No history': 1},
#     801: {},
#     802: {'History': 1},
#     803: {},
#     804: {},
#     805: {'No history': 1, 'History': 1},
#     806: {'No history': 1, 'History': 1},
#     807: {},
#     808: {'No history': 1},
#     809: {'No history': 1, 'History': 0},
# ...
#     402: {'No history': 0},
#     403: {},
#     404: {},
#     405: {},
#     406: {},
#     407: {'No history': 1, 'History': 1},
#     408: {},
#     409: {'History': 1},
#     410: {},
#     411: {},
#     412: {},
#     413: {'No history': 1},
#     414: {},
#     415: {},
#     416: {},
#     417: {},
#     418: {'No history': 0, 'History': 0},
#     419: {'No history': 1, 'History': 1},
#     420: {},
#     421: {'No history': 0, 'History': 1},
#     422: {},
#     423: {},
#     424: {},
#     425: {},
#     426: {},
#     427: {},
#     428: {'No history': 0, 'History': 0},
#     429: {'No history': 1, 'History': 0},
#     430: {'No history': 1, 'History': 1},
#     431: {},
#     432: {},
#     433: {},
#     434: {},
#     435: {},
#     436: {'History': 0},
#     437: {},
#     438: {'No history': 1, 'History': 1},
#     439: {'No history': 1},
#     440: {},
#     441: {},
#     442: {},
#     443: {'No history': 1, 'History': 1},
#     444: {'No history': 1, 'History': 1},
#     445: {'No history': 0, 'History': 0},
#     446: {},
#     447: {},
#     448: {'No history': 1},
#     449: {},
#     450: {'No history': 1, 'History': 1},
#     451: {},
#     452: {'No history': 1},
#     453: {'History': 1},
#     454: {},
#     455: {},
#     456: {},
#     457: {},
#     458: {},
#     459: {},
#     460: {'History': 1},
#     461: {},
#     462: {},
#     463: {},
#     464: {},
#     465: {'No history': 1, 'History': 1},
#     466: {'No history': 1, 'History': 1},
#     467: {'No history': 1},
#     468: {'No history': 1},
#     469: {'No history': 1, 'History': 1},
#     470: {'History': 1},
#     471: {'No history': 1, 'History': 1},
#     472: {},
#     473: {'No history': 1, 'History': 1},
#     474: {'No history': 1, 'History': 1},
#     475: {},
#     476: {'History': 1},
#     477: {},
#     478: {'No history': 1, 'History': 1},
#     479: {'No history': 1},
#     480: {'No history': 1, 'History': 1},
#     481: {'History': 1},
#     482: {},
#     483: {},
#     484: {},
#     485: {'No history': 1, 'History': 1},
#     486: {'History': 0},
#     487: {},
#     488: {},
#     489: {'No history': 1, 'History': 1},
#     490: {},
#     491: {},
#     492: {'No history': 0},
#     493: {},
#     494: {'No history': 0},
#     495: {},
#     496: {'No history': 0},
#     497: {'History': 1},
#     498: {},
#     499: {'No history': 0},
#     500: {},
#     501: {'History': 1},
#     502: {'No history': 0, 'History': 0},
#     503: {'No history': 1, 'History': 1},
#     504: {'History': 1},
#     505: {'No history': 1, 'History': 1},
#     506: {},
#     507: {'No history': 1},
#     508: {'No history': 0, 'History': 0},
#     509: {'No history': 1, 'History': 1},
#     510: {},
#     511: {},
#     512: {},
#     513: {},
#     514: {},
#     515: {'No history': 0},
#     516: {},
#     517: {},
#     518: {'No history': 1},
#     519: {'No history': 0},
#     520: {'History': 0},
#     521: {},
#     522: {},
#     523: {},
#     524: {},
#     525: {},
#     526: {},
#     527: {},
#     528: {},
#     529: {},
#     530: {},
#     531: {},
#     532: {},
#     533: {},
#     534: {},
#     535: {},
#     536: {},
#     537: {},
#     538: {},
#     539: {},
#     540: {},
#     541: {},
#     542: {},
#     543: {'History': 1},
#     544: {},
#     545: {'History': 0},
#     546: {},
#     547: {},
#     548: {},
#     549: {'No history': 1, 'History': 1},
#     550: {},
#     551: {'No history': 1},
#     552: {},
#     553: {},
#     554: {'No history': 1},
#     555: {'No history': 1},
#     556: {},
#     557: {},
#     558: {},
#     559: {'No history': 0, 'History': 1},
#     560: {},
#     561: {},
#     562: {},
#     563: {'No history': 1, 'History': 1},
#     564: {'No history': 0, 'History': 0},
#     565: {'No history': 0, 'History': 1},
#     566: {},
#     567: {},
#     568: {},
#     569: {},
#     570: {},
#     571: {},
#     572: {'History': 0},
#     573: {},
#     574: {},
#     575: {'No history': 1, 'History': 1},
#     576: {'No history': 1, 'History': 1},
#     577: {'History': 1},
#     578: {'No history': 0},
#     579: {},
#     580: {},
#     581: {},
#     582: {},
#     583: {},
#     584: {},
#     585: {},
#     586: {},
#     587: {'No history': 1, 'History': 1},
#     588: {},
#     589: {'No history': 1},
#     590: {},
#     591: {'History': 0},
#     592: {},
#     593: {'No history': 1},
#     594: {},
#     595: {},
#     596: {},
#     597: {'No history': 1, 'History': 1},
#     598: {},
#     599: {},
#     600: {},
#     601: {'No history': 0},
#     602: {},
#     603: {'No history': 1, 'History': 1},
#     604: {'No history': 0, 'History': 0},
#     605: {},
#     606: {},
#     607: {'No history': 0, 'History': 0},
#     608: {},
#     609: {},
#     610: {},
#     611: {},
#     612: {'History': 1},
#     613: {},
#     614: {'No history': 1, 'History': 1},
#     615: {},
#     616: {},
#     617: {'No history': 1},
#     618: {},
#     619: {'No history': 1, 'History': 1},
#     620: {},
#     621: {'History': 0},
#     622: {'History': 0},
#     623: {'No history': 1, 'History': 1},
#     624: {'No history': 1, 'History': 0},
#     625: {'No history': 1, 'History': 1},
#     626: {},
#     627: {'No history': 1, 'History': 1},
#     628: {},
#     629: {'History': 1},
#     630: {'No history': 1, 'History': 1},
#     631: {},
#     632: {'No history': 1, 'History': 1},
#     633: {},
#     634: {'No history': 1},
#     635: {},
#     636: {'No history': 1},
#     637: {},
#     638: {},
#     639: {},
#     640: {'No history': 1, 'History': 1},
#     641: {'No history': 1, 'History': 1},
#     642: {},
#     643: {'No history': 1},
#     644: {},
#     645: {},
#     646: {},
#     647: {'No history': 1, 'History': 1},
#     648: {},
#     649: {'No history': 1, 'History': 0},
#     650: {},
#     651: {},
#     652: {},
#     653: {'No history': 1},
#     654: {},
#     655: {},
#     656: {},
#     657: {'History': 0},
#     658: {},
#     659: {'No history': 1, 'History': 1},
#     660: {},
#     661: {'No history': 1},
#     662: {},
#     663: {},
#     664: {'History': 1},
#     665: {},
#     666: {},
#     667: {'History': 0},
#     668: {},
#     669: {},
#     670: {},
#     671: {},
#     672: {},
#     673: {},
#     674: {'No history': 0, 'History': 1},
#     675: {},
#     676: {'No history': 0, 'History': 0},
#     677: {},
#     678: {'No history': 1, 'History': 1},
#     679: {},
#     680: {},
#     681: {'No history': 1, 'History': 1},
#     682: {'History': 1},
#     683: {},
#     684: {'No history': 1, 'History': 1},
#     685: {},
#     686: {'History': 1},
#     687: {},
#     688: {},
#     689: {'No history': 1, 'History': 1},
#     690: {},
#     691: {},
#     692: {},
#     693: {},
#     694: {},
#     695: {'No history': 1},
#     696: {'No history': 1, 'History': 1},
#     697: {},
#     698: {},
#     699: {'No history': 1},
#     700: {'No history': 1, 'History': 1},
#     701: {},
#     702: {},
#     703: {},
#     704: {'No history': 1},
#     705: {'No history': 1},
#     706: {'No history': 0},
#     707: {'No history': 1, 'History': 1},
#     708: {},
#     709: {},
#     710: {'No history': 0},
#     711: {},
#     712: {'No history': 1, 'History': 1},
#     713: {},
#     714: {},
#     715: {'No history': 1, 'History': 1},
#     716: {},
#     717: {},
#     718: {},
#     719: {'History': 1},
#     720: {'No history': 0, 'History': 1},
#     721: {},
#     722: {},
#     723: {},
#     724: {'No history': 1, 'History': 1},
#     725: {'No history': 1, 'History': 1},
#     726: {'History': 1},
#     727: {'History': 1},
#     728: {'No history': 1},
#     729: {'No history': 1, 'History': 1},
#     730: {},
#     731: {'History': 1},
#     732: {'No history': 1, 'History': 1},
#     733: {},
#     734: {},
#     735: {'No history': 1},
#     736: {'No history': 1},
#     737: {},
#     738: {'No history': 1, 'History': 1},
#     739: {'No history': 1},
#     740: {},
#     741: {'History': 1},
#     742: {'No history': 0},
#     743: {'No history': 1, 'History': 0},
#     744: {},
#     745: {},
#     746: {'No history': 1, 'History': 1},
#     747: {},
#     748: {'No history': 1, 'History': 1},
#     749: {'No history': 1, 'History': 1},
#     750: {'No history': 1, 'History': 1},
#     751: {},
#     752: {'No history': 1, 'History': 1},
#     753: {},
#     754: {},
#     755: {'No history': 1, 'History': 1},
#     756: {},
#     757: {'No history': 1, 'History': 1},
#     758: {'No history': 1, 'History': 1},
#     759: {'No history': 0},
#     760: {},
#     761: {'No history': 1},
#     762: {},
#     763: {'No history': 1, 'History': 1},
#     764: {'History': 1},
#     765: {'History': 0},
#     766: {},
#     767: {},
#     768: {},
#     769: {},
#     770: {'No history': 1, 'History': 1},
#     771: {},
#     772: {},
#     773: {'No history': 1, 'History': 1},
#     774: {'No history': 1, 'History': 1},
#     775: {},
#     776: {'No history': 1},
#     777: {},
#     778: {'No history': 1, 'History': 1},
#     779: {'No history': 1, 'History': 1},
#     780: {'No history': 1, 'History': 1},
#     781: {'No history': 1},
#     782: {'No history': 1, 'History': 1},
#     783: {'No history': 1, 'History': 1},
#     784: {'No history': 1, 'History': 1},
#     785: {'No history': 1, 'History': 1},
#     786: {'History': 0},
#     787: {'No history': 1, 'History': 1},
#     788: {'No history': 1, 'History': 1},
#     789: {'No history': 1, 'History': 1},
#     790: {},
#     791: {'No history': 1},
#     792: {'No history': 1, 'History': 1},
#     793: {'No history': 1, 'History': 1},
#     794: {'No history': 1, 'History': 1},
#     795: {'No history': 1, 'History': 1},
#     796: {},
#     797: {},
#     798: {},
#     799: {'No history': 0, 'History': 0},
#     800: {'No history': 1},
#     801: {},
#     802: {},
#     803: {},
#     804: {},
#     805: {'No history': 1, 'History': 1},
#     806: {'No history': 1, 'History': 1},
#     807: {},
#     808: {'No history': 1, 'History': 1},
#     809: {'No history': 1, 'History': 0},
#     810: {'No history': 0, 'History': 1},
#     811: {},
#     812: {'No history': 1, 'History': 1},
#     813: {},
#     814: {},
#     815: {},
#     816: {},
#     817: {},
#     818: {'No history': 0, 'History': 1},
#     819: {},
#     820: {'No history': 0, 'History': 1},
#     821: {'No history': 1, 'History': 1},
#     822: {'No history': 0, 'History': 0},
#     823: {},
#     824: {'No history': 1, 'History': 1},
#     825: {},
#     826: {'No history': 1, 'History': 1},
#     827: {},
#     828: {'No history': 1},
#     829: {'No history': 1, 'History': 1},
#     830: {'No history': 1},
#     831: {},
#     832: {},
#     833: {'No history': 0},
#     834: {},
#     835: {},
#     836: {},
#     837: {},
#     838: {'No history': 1, 'History': 1},
#     839: {'No history': 0},
#     840: {},
#     841: {},
#     842: {},
#     843: {},
#     844: {},
#     845: {},
#     846: {'No history': 1, 'History': 1},
#     847: {},
#     848: {'No history': 1},
#     849: {},
#     850: {},
#     851: {},
#     852: {'No history': 1, 'History': 1},
#     853: {},
#     854: {},
#     855: {},
#     856: {},
#     857: {'No history': 1, 'History': 1},
#     858: {},
#     859: {'History': 0},
#     860: {},
#     861: {'No history': 1, 'History': 1},
#     862: {'No history': 1, 'History': 1},
#     863: {},
#     864: {},
#     865: {'No history': 0, 'History': 0},
#     866: {},
#     867: {},
#     868: {'No history': 1, 'History': 1},
#     869: {},
#     870: {},
#     871: {},
#     872: {},
#     873: {},
#     874: {},
#     875: {'No history': 1},
#     876: {'No history': 0, 'History': 1},
#     877: {'No history': 1},
#     878: {'No history': 1, 'History': 1},
#     879: {'No history': 1, 'History': 1},
#     880: {},
#     881: {'No history': 1, 'History': 1},
#     882: {'No history': 1},
#     883: {},
#     884: {'History': 1},
#     885: {},
#     886: {'No history': 1, 'History': 1},
#     887: {'No history': 1, 'History': 1},
#     888: {},
#     889: {},
#     890: {'No history': 1, 'History': 1},
#     891: {},
#     892: {'History': 1},
#     893: {'No history': 0, 'History': 0},
#     894: {'No history': 0, 'History': 0},
#     895: {'No history': 1},
#     896: {'No history': 1, 'History': 1},
#     897: {},
#     898: {'No history': 0, 'History': 0},
#     899: {'No history': 1, 'History': 1},
#     900: {'No history': 1, 'History': 1},
#     901: {},
#     902: {'History': 1},
#     903: {},
#     904: {},
#     905: {'No history': 1},
#     906: {'History': 0},
#     907: {},
#     908: {'No history': 1, 'History': 1},
#     909: {},
#     910: {'No history': 0},
#     911: {},
#     912: {'No history': 1, 'History': 1},
#     913: {'History': 1},
#     914: {'No history': 0, 'History': 0},
#     915: {},
#     916: {'No history': 0},
#     917: {'No history': 1},
#     918: {},
#     919: {'No history': 0},
#     920: {'History': 1},
#     921: {'No history': 1, 'History': 1},
#     922: {'No history': 1, 'History': 1},
#     923: {},
#     924: {'History': 1},
#     925: {},
#     926: {},
#     927: {},
#     928: {},
#     929: {'No history': 0, 'History': 1},
#     930: {'No history': 1, 'History': 1},
#     931: {},
#     932: {},
#     933: {'No history': 1},
#     934: {},
#     935: {},
#     936: {'No history': 1, 'History': 1},
#     937: {},
#     938: {},
#     939: {'No history': 1, 'History': 1},
#     940: {},
#     941: {'No history': 1, 'History': 1},
#     942: {},
#     943: {},
#     944: {'No history': 1, 'History': 0},
#     945: {},
#     946: {},
#     947: {},
#     948: {},
#     949: {'History': 1},
#     950: {'No history': 0, 'History': 0},
#     951: {'No history': 1, 'History': 0},
#     952: {'History': 1},
#     953: {'No history': 0},
#     954: {},
#     955: {'No history': 0, 'History': 0},
#     956: {'No history': 1, 'History': 1},
#     957: {'No history': 1, 'History': 1},
#     958: {},
#     959: {'No history': 0, 'History': 0},
#     960: {'No history': 1, 'History': 1},
#     961: {'History': 1},
#     962: {'No history': 1},
#     963: {'No history': 1, 'History': 1},
#     964: {'No history': 1, 'History': 1},
#     965: {'No history': 1},
#     966: {'History': 0},
#     967: {'History': 1},
#     968: {'No history': 1},
#     969: {},
#     970: {'No history': 1},
#     971: {'No history': 1, 'History': 1},
#     972: {},
#     973: {},
#     974: {'No history': 0},
#     975: {'No history': 1, 'History': 1},
#     976: {},
#     977: {'No history': 1, 'History': 1},
#     978: {},
#     979: {},
#     980: {},
#     981: {},
#     982: {},
#     983: {'History': 1},
#     984: {'No history': 0},
#     985: {'No history': 1, 'History': 1},
#     986: {'No history': 1},
#     987: {},
#     988: {'History': 1},
#     989: {'No history': 1, 'History': 1},
#     990: {},
#     991: {},
#     992: {'No history': 1, 'History': 1},
#     993: {},
#     994: {'No history': 1, 'History': 1},
#     995: {'History': 1},
#     996: {},
#     997: {},
#     998: {'No history': 1},
#     999: {},
#     ...}],
#   'changed_seg_ids': [[143,
#     162,
#     166,
#     333,
#     570,
#     1268,
#     1475,
#     1648,
#     1641,
#     1690,
#     1681,
#     1763,
#     1783,
#     1782,
#     1872,
#     1891,
#     2056,
#     2102,
#     2283,
#     2284,
#     2391,
#     2404,
#     2445,
#     2568,
#     2646,
#     2703,
#     2838,
#     3259,
#     3260,
#     3262,
#     3717,
#     3730,
#     3732,
#     3809,
#     3964,
#     3967,
#     4006,
#     4201,
#     4243,
#     4238,
#     4454,
#     4784,
#     4820,
#     4960,
#     5174,
#     5382,
#     5383,
#     5414,
#     5421,
#     5607,
#     5839,
#     5845,
#     5899,
#     6012,
#     6010,
#     6086,
#     6135,
#     6143,
#     6216,
#     6269,
#     6452,
#     6468,
#     6485,
#     6707,
#     6747],
#    [143,
#     162,
#     166,
#     333,
#     570,
#     1268,
#     1475,
#     1648,
#     1641,
#     1690,
#     1681,
#     1763,
#     1783,
#     1782,
#     1872,
#     1891,
#     2056,
#     2102,
#     2283,
#     2284,
#     2391,
#     2404,
#     2445,
#     2568,
#     2646,
#     2703,
#     2838,
#     3259,
#     3260,
#     3262,
#     3717,
#     3730,
#     3732,
#     3809,
#     3964,
#     3967,
#     4006,
#     4201,
#     4243,
#     4238,
#     4454,
#     4784,
#     4820,
#     4960,
#     5174,
#     5382,
#     5383,
#     5414,
#     5421,
#     5607,
#     5839,
#     5845,
#     5899,
#     6012,
#     6010,
#     6086,
#     6135,
#     6143,
#     6216,
#     6269,
#     6452,
#     6468,
#     6485,
#     6707,
#     6747],
#    [143,
#     162,
#     166,
#     333,
#     570,
#     1268,
#     1475,
#     1648,
#     1641,
#     1690,
#     1681,
#     1763,
#     1783,
#     1782,
#     1872,
#     1891,
#     2056,
#     2102,
#     2283,
#     2284,
#     2391,
#     2404,
#     2445,
#     2568,
#     2646,
#     2703,
#     2838,
#     3259,
#     3260,
#     3262,
#     3717,
#     3730,
#     3732,
#     3809,
#     3964,
#     3967,
#     4006,
#     4201,
#     4243,
#     4238,
#     4454,
#     4784,
#     4820,
#     4960,
#     5174,
#     5382,
#     5383,
#     5414,
#     5421,
#     5607,
#     5839,
#     5845,
#     5899,
#     6012,
#     6010,
#     6086,
#     6135,
#     6143,
#     6216,
#     6269,
#     6452,
#     6468,
#     6485,
#     6707,
#     6747]]}}

# %%
accs_hist, accs_nohist, lengths = print_accs('games_1', print_res=True)
# Out:
# -------------------------
# Experiment: games_1
# -------------------------
# History accuracies:
# hT_nhT: mean=0.8478170492942049, std=0.010975076255744046
# hT_nhF: mean=0.8789473684210526, std=0.026139762150440976
# hF_nhT: mean=0.6587301587301587, std=0.13654484550861315
# hF_nhF: mean=0.4573308270676692, std=0.0867526853584771
# only_h: mean=0.726657275850704, std=0.04543568320924143
# only_nh: mean=0.7039744422785358, std=0.04494058099209574
# nothing: mean=0.6828759752488566, std=0.015298028897250897
# all: mean=0.7593866102389187, std=0.009367899398709956
# h_nh_all: mean=0.802449408388266, std=0.022417615609436795
#
# No history accuracies:
# hT_nhT: mean=0.8217848817848817, std=0.012300136214438864
# hT_nhF: mean=0.4934886235195832, std=0.0922644494043011
# hF_nhT: mean=0.9, std=0.04714045207910316
# hF_nhF: mean=0.4685286154074404, std=0.08502480665156516
# only_h: mean=0.6285478727259549, std=0.05779060527559155
# only_nh: mean=0.7073181358708913, std=0.030192710227003452
# nothing: mean=0.6383580543455153, std=0.03225884174737626
# all: mean=0.7215436622498581, std=0.015820561266705856
# h_nh_all: mean=0.7693914766609802, std=0.024642956705143604
#
# Number of items per condition:
# hT_nhT: mean=488.0, std=0.0
# hT_nhF: mean=32.0, std=0.0
# hF_nhT: mean=21.0, std=0.0
# hF_nhF: mean=72.0, std=0.0
# only_h: mean=175.0, std=0.0
# only_nh: mean=231.0, std=0.0
# nothing: mean=309.0, std=0.0
# all: mean=0.0, std=0.0
# h_nh_all: mean=0.0, std=0.0
# -------------------------

# %% [markdown]
# ### Plot the accuracies of the games and image perturbations
# Change the plot_conds list to select the conditions you want to display.
#
# Only displays the accuracies for the history model, because the conditions are based on the results without history, and the segments themselves are not perturbed in the game and image experiment, so the results from the no history model will be the same as in the original dataset

# %% [markdown]
# Plot the results including the errorbar

# %%
hist_means = {condition:[] for condition in accs_hist}
hist_stds = {condition:[] for condition in accs_hist}

nohist_means = {condition:[] for condition in accs_hist}
colors = ['blue', 'orange', 'green', 'red', 'purple']
x_range = list(range(1,6))
plot_conds = ['hT_nhT', 'hT_nhF','hF_nhT','hF_nhF', 'all']
plot_conds = ['all']
plot_conds = ['h_nh_all']
plot_conds = ['hT_nhT']
# plot_conds = ['hT_nhF']
plot_conds = ['hT_nhF', 'hT_nhT', 'h_nh_all']
# plot_conds = ['hF_nhF', 'hF_nhT']

# Create the hist_means dictionary
for i in range(5):
    experiment = 'games_'+str(i)
    accs_hist, accs_nohist, lengths = print_accs(experiment, print_res=False)
    for condition in accs_hist:
        hist_means[condition].append(accs_hist[condition].mean())
        hist_stds[condition].append(accs_hist[condition].std())
    
# Plot the game lines
for i in range(len(plot_conds)):
    condition = list(plot_conds)[i]
    if condition == 'h_nh_all':
        plt.plot(x_range, hist_means[condition], marker='o', label='game: all', color=colors[i])
    else:
        plt.plot(x_range, hist_means[condition], marker='o', label='game: '+condition.replace('_', ', '), color=colors[i])
    plt.fill_between(x_range, np.array(hist_means[condition])-np.array(hist_stds[condition]), np.array(hist_means[condition])+np.array(hist_stds[condition]),
                     color=colors[i], alpha=.2)

plt.title("Accuracy for game exchange experiment per round")
plt.ylabel('Accuracy')
plt.xlabel('Round')
plt.legend()
# plt.show()


# Create dicts with the mean accuracies
hist_means = {condition:[] for condition in accs_hist}
hist_stds = {condition:[] for condition in accs_hist}
for i in range(5):
    experiment = 'imgs_'+str(i)
    accs_hist, accs_nohist, lengths = print_accs(experiment, print_res=False)
    for condition in accs_hist:
        hist_means[condition].append(accs_hist[condition].mean())
        hist_stds[condition].append(accs_hist[condition].std())
# Plot the images mean accuracies
for i in range(len(plot_conds)):
    condition = list(plot_conds)[i]
    if condition == 'h_nh_all':
        plt.plot(x_range, hist_means[condition], marker='x', label='image: all', color=colors[i], linestyle='--')
    else:
        plt.plot(x_range, hist_means[condition], marker='x', label='image: '+condition.replace('_', ', '), color=colors[i], linestyle='--')
    plt.fill_between(x_range, np.array(hist_means[condition])-np.array(hist_stds[condition]), np.array(hist_means[condition])+np.array(hist_stds[condition]),
                    color=colors[i], alpha=.2)

# Plot the standard results (i.e. 0 or 1)
    if condition == 'h_nh_all':
        plt.hlines(accs_hist_orig[condition]+(i*.02), 1, 5, color=colors[i], label='standard: all')

    else:
        plt.hlines(accs_hist_orig[condition]+(i*.02), 1, 5, color=colors[i], label='standard: '+condition.replace('_', ', '))

# Plot the random baseline
# plt.hlines(1/6, 1, 5, color='black', label='random')
# plt.hlines(1/12, 1, 5, color='black')
    
plt.title("Accuracy per rank on segments initially correctly predicted\n with history for the game and image exchange experiment")
plt.ylabel('Accuracy')
plt.xlabel('Rank')
plt.legend()
plt.legend(bbox_to_anchor=(1.0, 1.00))
plt.tight_layout()
plt.savefig("newacc_img_game_cor.png")
plt.show()

# %%
hist_means = {condition:[] for condition in accs_hist}
hist_stds = {condition:[] for condition in accs_hist}

nohist_means = {condition:[] for condition in accs_hist}
colors = ['blue', 'orange', 'green', 'red', 'purple']
x_range = list(range(1,6))
plot_conds = ['hT_nhT', 'hT_nhF','hF_nhT','hF_nhF', 'all']
plot_conds = ['all']
plot_conds = ['h_nh_all']
plot_conds = ['hT_nhT']
# plot_conds = ['hT_nhF']
# plot_conds = ['hT_nhF', 'hT_nhT']
plot_conds = ['hF_nhF', 'hF_nhT', 'h_nh_all']

# Create the hist_means dictionary
for i in range(5):
    experiment = 'games_'+str(i)
    accs_hist, accs_nohist, lengths = print_accs(experiment, print_res=False)
    for condition in accs_hist:
        hist_means[condition].append(accs_hist[condition].mean())
        hist_stds[condition].append(accs_hist[condition].std())
    
# Plot the game lines
for i in range(len(plot_conds)):
    condition = list(plot_conds)[i]
    if condition == 'h_nh_all':
        plt.plot(x_range, hist_means[condition], marker='o', label='game: all', color=colors[i])
    else:
        plt.plot(x_range, hist_means[condition], marker='o', label='game: '+condition.replace('_', ', '), color=colors[i])
    plt.fill_between(x_range, np.array(hist_means[condition])-np.array(hist_stds[condition]), np.array(hist_means[condition])+np.array(hist_stds[condition]),
                     color=colors[i], alpha=.2)

plt.title("Accuracy for game exchange experiment per round")
plt.ylabel('Accuracy')
plt.xlabel('Round')
plt.legend()
# plt.show()


# Create dicts with the mean accuracies
hist_means = {condition:[] for condition in accs_hist}
hist_stds = {condition:[] for condition in accs_hist}
for i in range(5):
    experiment = 'imgs_'+str(i)
    accs_hist, accs_nohist, lengths = print_accs(experiment, print_res=False)
    for condition in accs_hist:
        hist_means[condition].append(accs_hist[condition].mean())
        hist_stds[condition].append(accs_hist[condition].std())
    
# Plot the images mean accuracies
for i in range(len(plot_conds)):
    condition = list(plot_conds)[i]
    if condition == 'h_nh_all':
        plt.plot(x_range, hist_means[condition], marker='x', label='image: all', color=colors[i], linestyle='--')
    else:
        plt.plot(x_range, hist_means[condition], marker='x', label='image: '+condition.replace('_', ', '), color=colors[i], linestyle='--')
    plt.fill_between(x_range, np.array(hist_means[condition])-np.array(hist_stds[condition]), np.array(hist_means[condition])+np.array(hist_stds[condition]),
                    color=colors[i], alpha=.2)

# Plot the standard results (i.e. 0 or 1)
for i in range(len(plot_conds)):
    condition = list(plot_conds)[i]
    if condition == 'h_nh_all':
        plt.hlines(accs_hist_orig[condition]+(i*.02), 1, 5, color=colors[i], label='standard: all')

    else:
        plt.hlines(accs_hist_orig[condition]+(i*.02), 1, 5, color=colors[i], label='standard: '+condition.replace('_', ', '))

# Plot the random baseline
# plt.hlines(1/6, 1, 5, color='black', label='random')
# plt.hlines(1/12, 1, 5, color='black')
    
plt.title("Accuracy per rank on segments initially incorrectly predicted\n with history for the game and image exchange experiment")
plt.ylabel('Accuracy')
plt.xlabel('Rank')
plt.legend()
plt.legend(bbox_to_anchor=(1.0, 1.00))
plt.tight_layout()
plt.savefig("newacc_img_game_incor.png")
plt.show()
